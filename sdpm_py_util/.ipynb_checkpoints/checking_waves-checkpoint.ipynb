# %%
from datetime import datetime, timezone, timedelta
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
#import glob
#import netCDF4 as nc
import xarray as xr
# import grib2io

#import cfgrib
import urllib
#import pygrib

sys.path.append('../sdpm_py_util')
sys.path.append('../web_util')

#import init_funs as initfuns
#import ocn_functions as ocnfuns
import plotting_functions as pltfuns
#import atm_functions as atmfuns
#import hind_functions as hindfuns
import grid_functions as grdfuns
#import web_functions as webfuns
from get_PFM_info import get_PFM_info

#import pickle
#import os
import subprocess

# %%
# make new waves 

import swan_functions as swanfuns 

# to make bnd waves file, need: 
# 1) cdip_ncs_to_dict_hind from swan_functions.py

swanfuns.cdip_ncs_to_dict_hind(modinfo_pkl_full)

# 2) mk_swan_bnd_file from swan_functions.py

mk_swan_bnd_file(fout,pkl_fnm)


# 3) if wind waves, also mk_swan_wnd_file from swan_functions.py
# Out:
# Now making dictionary of cdip data...
# ...done.
#
# CDIP data saved as pickle file

# %%
# next, lets check the pickle file; 
wv_pkl = '/project/vboatwright/PFM_dir/simulations/LV4/Forc/LV4_swan_bnd.pkl' 
def load_pickle_file(file_path):
    import pickle
    import os 
    """
    Loads data from a pickle file.
    Args:
        file_path (str): The path to the pickle file.
    Returns:
        object: The unpickled object, or None if an error occurs.
    """
    try:
        with open(file_path, 'rb') as file:
            data = pickle.load(file)
        return data
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

waves = load_pickle_file(wv_pkl)
waves
# Out:
# {'f': array([0.04  , 0.045 , 0.05  , 0.055 , 0.06  , 0.065 , 0.07  , 0.075 ,
#         0.08  , 0.085 , 0.09  , 0.095 , 0.1013, 0.11  , 0.12  , 0.13  ,
#         0.14  , 0.15  , 0.16  , 0.17  , 0.18  , 0.19  , 0.2   , 0.21  ,
#         0.22  , 0.23  , 0.24  , 0.25  , 0.26  ], dtype=float32),
#  'dir': array([155., 160., 165., 170., 175., 180., 185., 190., 195., 200., 205.,
#         210., 215., 220., 225., 230., 235., 240., 245., 250., 255., 260.,
#         265., 270., 275., 280., 285., 290., 295., 300., 305., 310., 315.,
#         320., 325., 330., 335., 340., 345., 350., 355., 360.],
#        dtype=float32),
#  'time': array([datetime.datetime(2024, 11, 2, 0, 0),
#         datetime.datetime(2024, 11, 2, 1, 0),
#         datetime.datetime(2024, 11, 2, 2, 0),
#         datetime.datetime(2024, 11, 2, 3, 0),
#         datetime.datetime(2024, 11, 2, 4, 0),
#         datetime.datetime(2024, 11, 2, 5, 0),
#         datetime.datetime(2024, 11, 2, 6, 0),
#         datetime.datetime(2024, 11, 2, 7, 0),
#         datetime.datetime(2024, 11, 2, 8, 0),
#         datetime.datetime(2024, 11, 2, 9, 0),
#         datetime.datetime(2024, 11, 2, 10, 0),
#         datetime.datetime(2024, 11, 2, 11, 0),
#         datetime.datetime(2024, 11, 2, 12, 0),
#         datetime.datetime(2024, 11, 2, 13, 0),
#         datetime.datetime(2024, 11, 2, 14, 0),
#         datetime.datetime(2024, 11, 2, 15, 0),
#         datetime.datetime(2024, 11, 2, 16, 0),
#         datetime.datetime(2024, 11, 2, 17, 0),
#         datetime.datetime(2024, 11, 2, 18, 0),
#         datetime.datetime(2024, 11, 2, 19, 0),
#         datetime.datetime(2024, 11, 2, 20, 0),
#         datetime.datetime(2024, 11, 2, 21, 0),
#         datetime.datetime(2024, 11, 2, 22, 0),
#         datetime.datetime(2024, 11, 2, 23, 0),
#         datetime.datetime(2024, 11, 3, 0, 0)], dtype=object),
#  'lats': array([32.42150116, 32.4211998 , 32.42079926, 32.42020035, 32.41949844,
#         32.41870117, 32.41790009, 32.41699982, 32.41609955, 32.41500092,
#         32.41450119, 32.41389847, 32.41320038, 32.41249847, 32.41180038,
#         32.41139984, 32.41049957, 32.4095993 , 32.40890121, 32.40840149,
#         32.40790176, 32.40729904, 32.40670013, 32.40650177, 32.40620041,
#         32.40650177, 32.40790176, 32.40930176, 32.41059875, 32.41199875,
#         32.41329956, 32.41460037, 32.41579819, 32.417099  , 32.41830063,
#         32.41960144, 32.42079926, 32.42200089, 32.42369843, 32.42599869,
#         32.42819977, 32.43040085, 32.43259811, 32.43470001, 32.4367981 ,
#         32.43889999, 32.4408989 , 32.44250107, 32.44549942, 32.44850159,
#         32.45130157, 32.45510101, 32.45890045, 32.46390152, 32.46889877,
#         32.47259903, 32.47629929, 32.48600006, 32.4978981 , 32.5094986 ,
#         32.52080154, 32.5304985 , 32.53630066, 32.54000092, 32.55289841,
#         32.5646019 , 32.57749939, 32.59149933, 32.60680008, 32.62369919,
#         32.63339996, 32.64410019, 32.65019989, 32.65610123, 32.66239929,
#         32.66960144, 32.68460083, 32.70140076, 32.72380066, 32.73182685,
#         32.73302172]),
#  'lons': array([-117.10810089, -117.11049652, -117.11360168, -117.11759949,
#         -117.12249756, -117.12789917, -117.13369751, -117.13990021,
#         -117.14679718, -117.15440369, -117.15809631, -117.16249847,
#         -117.167099  , -117.17199707, -117.1772995 , -117.18009949,
#         -117.186203  , -117.19300079, -117.19730377, -117.20110321,
#         -117.20510101, -117.20909882, -117.21330261, -117.21499634,
#         -117.21679688, -117.21690369, -117.21710205, -117.2173996 ,
#         -117.21759796, -117.21790314, -117.2181015 , -117.21839905,
#         -117.21859741, -117.21890259, -117.21910095, -117.21929932,
#         -117.21949768, -117.21980286, -117.2201004 , -117.22049713,
#         -117.22090149, -117.2213974 , -117.22180176, -117.22219849,
#         -117.22260284, -117.22290039, -117.22329712, -117.22360229,
#         -117.22419739, -117.22480011, -117.22530365, -117.22599792,
#         -117.22669983, -117.22769928, -117.22859955, -117.22930145,
#         -117.23000336, -117.23179626, -117.23410034, -117.23619843,
#         -117.23840332, -117.24019623, -117.24130249, -117.24199677,
#         -117.24440002, -117.24659729, -117.24909973, -117.25170135,
#         -117.25460052, -117.25769806, -117.25959778, -117.26159668,
#         -117.26270294, -117.26380157, -117.26499939, -117.2664032 ,
#         -117.26920319, -117.2723999 , -117.2766037 , -117.27809185,
#         -117.26958959]),
#  'Spp': array([[[[1.74030941e-08, 2.08407585e-08, 2.54040646e-08, ...,
#            1.43639269e-08, 1.23983126e-08, 1.08444498e-08],
#           [3.29903060e-07, 3.90890165e-07, 4.70688917e-07, ...,
#            3.07203919e-07, 2.64766044e-07, 2.31197987e-07],
#           [1.33144113e-06, 1.57731120e-06, 1.89895411e-06, ...,
#            1.24292478e-06, 1.07115125e-06, 9.35284731e-07],
#           ...,
#           [2.34665421e-07, 2.65643166e-07, 3.04520853e-07, ...,
#            7.53298707e-07, 6.05341427e-07, 4.96355483e-07],
#           [2.26696912e-07, 2.57055177e-07, 2.95222122e-07, ...,
#            7.04837817e-07, 5.67044310e-07, 4.65457532e-07],
#           [2.16681855e-07, 2.46101592e-07, 2.83153213e-07, ...,
#            6.54090002e-07, 5.26722033e-07, 4.32759180e-07]],
#
#          [[1.88058511e-08, 2.25304095e-08, 2.74770304e-08, ...,
#            1.53940451e-08, 1.32920146e-08, 1.16298331e-08],
#           [3.91998640e-07, 4.64854310e-07, 5.60258627e-07, ...,
#            3.57351041e-07, 3.08314100e-07, 2.69487799e-07],
#           [1.49631398e-06, 1.77358277e-06, 2.13648173e-06, ...,
#            1.37751363e-06, 1.18798152e-06, 1.03796913e-06],
#           ...,
#           [2.36236900e-07, 2.67688819e-07, 3.07196643e-07, ...,
#            7.38471897e-07, 5.94339610e-07, 4.88002513e-07],
#           [2.28799934e-07, 2.59732758e-07, 2.98662229e-07, ...,
#            6.90939942e-07, 5.56780776e-07, 4.57706221e-07],
#           [2.19050790e-07, 2.49109348e-07, 2.87010380e-07, ...,
#            6.40092026e-07, 5.16393982e-07, 4.24967538e-07]],
#
#          [[1.79428596e-08, 2.15039293e-08, 2.62352611e-08, ...,
#            1.45875170e-08, 1.25993314e-08, 1.10267750e-08],
#           [4.36771614e-07, 5.17968772e-07, 6.24301606e-07, ...,
#            3.97994654e-07, 3.43381856e-07, 3.00140897e-07],
#           [1.62179549e-06, 1.92294624e-06, 2.31722879e-06, ...,
#            1.48109416e-06, 1.27781220e-06, 1.11685904e-06],
#           ...,
#           [2.37831486e-07, 2.69743595e-07, 3.09863111e-07, ...,
#            7.26136932e-07, 5.85181169e-07, 4.81048460e-07],
#           [2.30380181e-07, 2.61802256e-07, 3.01386194e-07, ...,
#            6.77480045e-07, 5.46736487e-07, 4.50040517e-07],
#           [2.21385605e-07, 2.52067736e-07, 2.90799136e-07, ...,
#            6.27871316e-07, 5.07365939e-07, 4.18151387e-07]],
#
#          ...,
#
#          [[2.35554753e-09, 2.82306245e-09, 3.44448869e-09, ...,
#            1.94429073e-09, 1.67721226e-09, 1.46625390e-09],
#           [1.80215011e-07, 2.14694779e-07, 2.60034057e-07, ...,
#            1.45287871e-07, 1.26140804e-07, 1.10891868e-07],
#           [9.55620180e-07, 1.13411988e-06, 1.36793756e-06, ...,
#            8.41144754e-07, 7.27334850e-07, 6.37018502e-07],
#           ...,
#           [3.84547832e-07, 4.38107577e-07, 5.05746698e-07, ...,
#            1.06606137e-06, 8.62907939e-07, 7.12219162e-07],
#           [3.61236289e-07, 4.12530767e-07, 4.77468063e-07, ...,
#            9.52273354e-07, 7.72565841e-07, 6.38988070e-07],
#           [3.33745106e-07, 3.81954152e-07, 4.43123469e-07, ...,
#            8.42220174e-07, 6.84581209e-07, 5.67206826e-07]],
#
#          [[2.14141549e-09, 2.56555999e-09, 3.12913340e-09, ...,
#            1.78056347e-09, 1.53544866e-09, 1.34189893e-09],
#           [1.63660005e-07, 1.95060196e-07, 2.36375556e-07, ...,
#            1.31306592e-07, 1.14006539e-07, 1.00229371e-07],
#           [9.26153120e-07, 1.09957637e-06, 1.32682828e-06, ...,
#            8.07320589e-07, 6.98420422e-07, 6.11962662e-07],
#           ...,
#           [4.19420559e-07, 4.77700041e-07, 5.51288338e-07, ...,
#            1.17835862e-06, 9.52776588e-07, 7.85660234e-07],
#           [3.98027055e-07, 4.54407200e-07, 5.25770929e-07, ...,
#            1.06402376e-06, 8.62260379e-07, 7.12482404e-07],
#           [3.69821862e-07, 4.23087272e-07, 4.90657442e-07, ...,
#            9.48159823e-07, 7.69737426e-07, 6.37077108e-07]],
#
#          [[2.69596789e-09, 3.22885496e-09, 3.93665145e-09, ...,
#            2.25742935e-09, 1.94605443e-09, 1.70025238e-09],
#           [1.49404570e-07, 1.78125262e-07, 2.15934236e-07, ...,
#            1.19804909e-07, 1.04000144e-07, 9.14171920e-08],
#           [9.00617636e-07, 1.06975449e-06, 1.29149078e-06, ...,
#            7.76423406e-07, 6.72044621e-07, 5.89137187e-07],
#           ...,
#           [4.64345305e-07, 5.28628277e-07, 6.09775896e-07, ...,
#            1.33054743e-06, 1.07414894e-06, 8.84545614e-07],
#           [4.41855804e-07, 5.04176683e-07, 5.83033341e-07, ...,
#            1.20716686e-06, 9.76620299e-07, 8.05803836e-07],
#           [4.13037327e-07, 4.72234774e-07, 5.47298953e-07, ...,
#            1.08528229e-06, 8.79415438e-07, 7.26674330e-07]]],
#
#
#         [[[1.44548062e-08, 1.75345960e-08, 2.16892850e-08, ...,
#            9.76395231e-09, 8.48454018e-09, 7.46828377e-09],
#           [5.48422918e-07, 6.59808734e-07, 8.08096217e-07, ...,
#            3.82193832e-07, 3.33215013e-07, 2.94113136e-07],
#           [2.03030618e-06, 2.44298053e-06, 2.99247722e-06, ...,
#            1.41347721e-06, 1.23232246e-06, 1.08770439e-06],
#           ...,
#           [2.56318458e-07, 2.90850011e-07, 3.34291087e-07, ...,
#            7.81806193e-07, 6.29673821e-07, 5.17384763e-07],
#           [2.49369918e-07, 2.83471593e-07, 3.26452948e-07, ...,
#            7.35552192e-07, 5.93129357e-07, 4.87910995e-07],
#           [2.39440396e-07, 2.72658838e-07, 3.14606041e-07, ...,
#            6.84650331e-07, 5.52643939e-07, 4.55051691e-07]],
#
#          [[2.01825578e-08, 2.44915039e-08, 3.03071062e-08, ...,
#            1.35679148e-08, 1.17915775e-08, 1.03805027e-08],
#           [7.11734003e-07, 8.57414534e-07, 1.05161484e-06, ...,
#            4.81143616e-07, 4.20078521e-07, 3.71268072e-07],
#           [2.32073171e-06, 2.79410096e-06, 3.42476596e-06, ...,
#            1.59128513e-06, 1.38838516e-06, 1.22629933e-06],
#           ...,
#           [2.58620105e-07, 2.93766902e-07, 3.38023824e-07, ...,
#            7.67658605e-07, 6.19244247e-07, 5.09523204e-07],
#           [2.51349547e-07, 2.86059873e-07, 3.29856732e-07, ...,
#            7.19504328e-07, 5.81162965e-07, 4.78784727e-07],
#           [2.42117665e-07, 2.76077003e-07, 3.19014390e-07, ...,
#            6.69513213e-07, 5.41433110e-07, 4.46563291e-07]],
#
#          [[2.36367637e-08, 2.86902093e-08, 3.55128691e-08, ...,
#            1.58403530e-08, 1.37675764e-08, 1.21209549e-08],
#           [8.04164699e-07, 9.68706104e-07, 1.18803246e-06, ...,
#            5.44133627e-07, 4.75060176e-07, 4.19849414e-07],
#           [2.67461041e-06, 3.22159872e-06, 3.95067673e-06, ...,
#            1.81546386e-06, 1.58471573e-06, 1.40030977e-06],
#           ...,
#           [2.61539640e-07, 2.97368075e-07, 3.42523606e-07, ...,
#            7.57816224e-07, 6.12119948e-07, 5.04262857e-07],
#           [2.55835317e-07, 2.91485236e-07, 3.36514717e-07, ...,
#            7.12723022e-07, 5.76540572e-07, 4.75608772e-07],
#           [2.46178956e-07, 2.81062142e-07, 3.25221492e-07, ...,
#            6.60206069e-07, 5.34792662e-07, 4.41742742e-07]],
#
#          ...,
#
#          [[1.94661665e-09, 2.36329223e-09, 2.92630231e-09, ...,
#            1.32416211e-09, 1.14937004e-09, 1.01071518e-09],
#           [2.44111249e-07, 2.94657809e-07, 3.62131033e-07, ...,
#            1.54619087e-07, 1.35478544e-07, 1.20128462e-07],
#           [1.39721203e-06, 1.68174688e-06, 2.06052505e-06, ...,
#            9.47765841e-07, 8.27757958e-07, 7.31783416e-07],
#           ...,
#           [4.20476226e-07, 4.80286474e-07, 5.56024816e-07, ...,
#            1.10604913e-06, 8.97267228e-07, 7.42100838e-07],
#           [3.95400235e-07, 4.52777641e-07, 5.25626604e-07, ...,
#            9.87464205e-07, 8.02931083e-07, 6.65494497e-07],
#           [3.67105798e-07, 4.21333198e-07, 4.90350601e-07, ...,
#            8.76212766e-07, 7.13857787e-07, 5.92728270e-07]],
#
#          [[3.02225200e-09, 3.66791197e-09, 4.53995996e-09, ...,
#            2.06781525e-09, 1.79445958e-09, 1.57765745e-09],
#           [2.12065444e-07, 2.56052630e-07, 3.14800872e-07, ...,
#            1.34376634e-07, 1.17714855e-07, 1.04356573e-07],
#           [1.32137632e-06, 1.59086744e-06, 1.94970494e-06, ...,
#            8.90755757e-07, 7.78200103e-07, 6.88161776e-07],
#           ...,
#           [4.54057215e-07, 5.18464390e-07, 6.00007070e-07, ...,
#            1.21236781e-06, 9.82363986e-07, 8.11655866e-07],
#           [4.30527422e-07, 4.92813683e-07, 5.71876171e-07, ...,
#            1.09254358e-06, 8.87274666e-07, 7.34611149e-07],
#           [4.01115869e-07, 4.60156997e-07, 5.35278048e-07, ...,
#            9.74918862e-07, 7.93186985e-07, 6.57811881e-07]],
#
#          [[4.49028104e-09, 5.44759926e-09, 6.74000855e-09, ...,
#            3.09063353e-09, 2.68146771e-09, 2.35700859e-09],
#           [1.89873305e-07, 2.29282691e-07, 2.81936991e-07, ...,
#            1.21036550e-07, 1.05973477e-07, 9.39036440e-08],
#           [1.25912118e-06, 1.51646680e-06, 1.85925524e-06, ...,
#            8.41548001e-07, 7.35504159e-07, 6.50645802e-07],
#           ...,
#           [4.97071085e-07, 5.67281234e-07, 6.56141026e-07, ...,
#            1.35634741e-06, 1.09718223e-06, 9.05201148e-07],
#           [4.72137913e-07, 5.40109454e-07, 6.26351891e-07, ...,
#            1.22729489e-06, 9.94907737e-07, 8.22430309e-07],
#           [4.41786682e-07, 5.06448941e-07, 5.88679313e-07, ...,
#            1.10330200e-06, 8.95836081e-07, 7.41642623e-07]]],
#
#
#         [[[3.45232891e-08, 4.27166853e-08, 5.41061453e-08, ...,
#            2.01020480e-08, 1.74449006e-08, 1.53441118e-08],
#           [1.75834828e-06, 2.14197121e-06, 2.66094321e-06, ...,
#            1.02671663e-06, 8.99723830e-07, 7.98035103e-07],
#           [6.18743115e-06, 7.51294328e-06, 9.29860380e-06, ...,
#            3.78121626e-06, 3.30919784e-06, 2.93151561e-06],
#           ...,
#           [3.78858601e-07, 4.28999442e-07, 4.92017250e-07, ...,
#            1.28304475e-06, 1.02422689e-06, 8.35176763e-07],
#           [3.68437554e-07, 4.17987792e-07, 4.80387712e-07, ...,
#            1.20543905e-06, 9.63398179e-07, 7.86453825e-07],
#           [3.54056795e-07, 4.02415225e-07, 4.63436749e-07, ...,
#            1.12204123e-06, 8.97604025e-07, 7.33429658e-07]],
#
#          [[3.48681723e-08, 4.31727898e-08, 5.47278098e-08, ...,
#            2.01381685e-08, 1.74800316e-08, 1.53781894e-08],
#           [2.22908011e-06, 2.71949875e-06, 3.38381415e-06, ...,
#            1.24902556e-06, 1.09683731e-06, 9.74746968e-07],
#           [7.00949022e-06, 8.51663208e-06, 1.05480394e-05, ...,
#            4.20281822e-06, 3.68186716e-06, 3.26465170e-06],
#           ...,
#           [3.81798088e-07, 4.32805422e-07, 4.96975531e-07, ...,
#            1.25531426e-06, 1.00386694e-06, 8.19859110e-07],
#           [3.71876354e-07, 4.22420442e-07, 4.86146121e-07, ...,
#            1.17765285e-06, 9.42986048e-07, 7.71092800e-07],
#           [3.58329828e-07, 4.07854657e-07, 4.70432184e-07, ...,
#            1.09488349e-06, 8.77737989e-07, 7.18547085e-07]],
#
#          [[4.20505479e-08, 5.20941015e-08, 6.60789681e-08, ...,
#            2.41104523e-08, 2.09329070e-08, 1.84199305e-08],
#           [2.54524684e-06, 3.10663381e-06, 3.86754118e-06, ...,
#            1.41790440e-06, 1.24531834e-06, 1.10685494e-06],
#           [7.93446361e-06, 9.64800529e-06, 1.19594197e-05, ...,
#            4.67210884e-06, 4.09644736e-06, 3.63508457e-06],
#           ...,
#           [3.86114607e-07, 4.38145236e-07, 5.03664467e-07, ...,
#            1.23675113e-06, 9.90506351e-07, 8.10027132e-07],
#           [3.76777990e-07, 4.28490466e-07, 4.93761320e-07, ...,
#            1.15852993e-06, 9.29227042e-07, 7.60973535e-07],
#           [3.63665947e-07, 4.14486152e-07, 4.78783591e-07, ...,
#            1.07486801e-06, 8.63304876e-07, 7.07908555e-07]],
#
#          ...,
#
#          [[1.33804878e-08, 1.65564646e-08, 2.09762874e-08, ...,
#            8.08008949e-09, 6.99152469e-09, 6.13358653e-09],
#           [7.21361346e-07, 8.84665383e-07, 1.10733379e-06, ...,
#            3.73594474e-07, 3.28911199e-07, 2.93005854e-07],
#           [4.14960505e-06, 5.06997776e-06, 6.32023966e-06, ...,
#            2.34511913e-06, 2.05617062e-06, 1.82478993e-06],
#           ...,
#           [6.30043871e-07, 7.18486604e-07, 8.30423460e-07, ...,
#            1.81990788e-06, 1.46436992e-06, 1.20267111e-06],
#           [5.94626954e-07, 6.79923346e-07, 7.88182490e-07, ...,
#            1.62490028e-06, 1.31075694e-06, 1.07898882e-06],
#           [5.52584083e-07, 6.33389220e-07, 7.36216919e-07, ...,
#            1.43900138e-06, 1.16322326e-06, 9.59376962e-07]],
#
#          [[1.32454323e-08, 1.63842664e-08, 2.07507487e-08, ...,
#            8.04295741e-09, 6.95767177e-09, 6.10250561e-09],
#           [6.58320289e-07, 8.07681658e-07, 1.01150715e-06, ...,
#            3.42055330e-07, 3.00999488e-07, 2.68026980e-07],
#           [3.87939372e-06, 4.74256376e-06, 5.91593016e-06, ...,
#            2.17088450e-06, 1.90411163e-06, 1.69042994e-06],
#           ...,
#           [6.85639804e-07, 7.81614858e-07, 9.03062073e-07, ...,
#            2.01329703e-06, 1.61775620e-06, 1.32707987e-06],
#           [6.53327731e-07, 7.46762396e-07, 8.65325831e-07, ...,
#            1.81665609e-06, 1.46333718e-06, 1.20310142e-06],
#           [6.10173174e-07, 6.99083216e-07, 8.12193264e-07, ...,
#            1.62056369e-06, 1.30791386e-06, 1.07723702e-06]],
#
#          [[1.28296396e-08, 1.58652824e-08, 2.00866648e-08, ...,
#            7.82990739e-09, 6.77188927e-09, 5.93836891e-09],
#           [5.63081699e-07, 6.90929937e-07, 8.65499317e-07, ...,
#            2.95611443e-07, 2.59912809e-07, 2.31267052e-07],
#           [3.69523514e-06, 4.52053700e-06, 5.64330821e-06, ...,
#            2.04101684e-06, 1.79116694e-06, 1.59095498e-06],
#           ...,
#           [7.56869042e-07, 8.62354341e-07, 9.95794380e-07, ...,
#            2.27629062e-06, 1.82547365e-06, 1.49493701e-06],
#           [7.23011965e-07, 8.25892357e-07, 9.56389272e-07, ...,
#            2.06423874e-06, 1.65925326e-06, 1.36169160e-06],
#           [6.78881122e-07, 7.77231833e-07, 9.02290310e-07, ...,
#            1.85754789e-06, 1.49566085e-06, 1.22937763e-06]]],
#
#
#         ...,
#
#
#         [[[1.01132236e-09, 1.19451615e-09, 1.43319567e-09, ...,
#            9.74367476e-10, 8.39571357e-10, 7.32901351e-10],
#           [3.36834702e-08, 3.95712085e-08, 4.71893173e-08, ...,
#            3.48108316e-08, 2.99575724e-08, 2.61174247e-08],
#           [5.30904103e-08, 6.23227479e-08, 7.42586010e-08, ...,
#            5.57376119e-08, 4.79357603e-08, 4.17658264e-08],
#           ...,
#           [4.99799683e-07, 5.66006122e-07, 6.49190326e-07, ...,
#            1.65248218e-06, 1.32264699e-06, 1.08092320e-06],
#           [4.79949279e-07, 5.44894249e-07, 6.26698920e-07, ...,
#            1.50374024e-06, 1.20654545e-06, 9.88253078e-07],
#           [4.55010564e-07, 5.17821718e-07, 5.97132669e-07, ...,
#            1.35565938e-06, 1.09019186e-06, 8.94800849e-07]],
#
#          [[6.92086333e-10, 8.17276136e-10, 9.80344583e-10, ...,
#            6.69673872e-10, 5.76928672e-10, 5.03545761e-10],
#           [3.88778894e-08, 4.56872797e-08, 5.45002656e-08, ...,
#            3.98598701e-08, 3.43165460e-08, 2.99287173e-08],
#           [7.62344925e-08, 8.95002970e-08, 1.06652053e-07, ...,
#            7.97821755e-08, 6.86269672e-08, 5.98035683e-08],
#           ...,
#           [5.12335760e-07, 5.80879089e-07, 6.67092763e-07, ...,
#            1.64522874e-06, 1.31896707e-06, 1.07947130e-06],
#           [4.90920627e-07, 5.58035708e-07, 6.42672433e-07, ...,
#            1.49235882e-06, 1.19939159e-06, 9.83845894e-07],
#           [4.65953008e-07, 5.30963177e-07, 6.13153986e-07, ...,
#            1.34561742e-06, 1.08393658e-06, 8.91007460e-07]],
#
#          [[7.66296138e-10, 9.04752606e-10, 1.08506926e-09, ...,
#            7.44272810e-10, 6.41089903e-10, 5.59460200e-10],
#           [4.79038782e-08, 5.63022553e-08, 6.71732749e-08, ...,
#            4.89408265e-08, 4.21417070e-08, 3.67590367e-08],
#           [7.38208996e-08, 8.66816023e-08, 1.03312310e-07, ...,
#            7.69290907e-08, 6.61863027e-08, 5.76875472e-08],
#           ...,
#           [5.22724292e-07, 5.93328252e-07, 6.82225732e-07, ...,
#            1.63044251e-06, 1.30928436e-06, 1.07313258e-06],
#           [5.02312957e-07, 5.71686769e-07, 6.59273041e-07, ...,
#            1.48068909e-06, 1.19206766e-06, 9.79344918e-07],
#           [4.77853803e-07, 5.45241335e-07, 6.30545685e-07, ...,
#            1.33618641e-06, 1.07825610e-06, 8.87748229e-07]],
#
#          ...,
#
#          [[4.95331665e-10, 5.85584692e-10, 7.03327563e-10, ...,
#            4.74137174e-10, 4.08458212e-10, 3.56506352e-10],
#           [2.80382899e-08, 3.34051187e-08, 4.04546938e-08, ...,
#            2.17296510e-08, 1.89229361e-08, 1.66805112e-08],
#           [1.02246275e-07, 1.21120451e-07, 1.45756900e-07, ...,
#            8.87112108e-08, 7.69081439e-08, 6.75112446e-08],
#           ...,
#           [8.39992026e-07, 9.56558551e-07, 1.10385884e-06, ...,
#            2.48302740e-06, 1.99678584e-06, 1.63896948e-06],
#           [7.84774727e-07, 8.96205620e-07, 1.03742707e-06, ...,
#            2.18543937e-06, 1.76235994e-06, 1.45021318e-06],
#           [7.27669374e-07, 8.33151432e-07, 9.67198844e-07, ...,
#            1.92002722e-06, 1.55219072e-06, 1.28016825e-06]],
#
#          [[5.63807778e-10, 6.66167288e-10, 7.99619704e-10, ...,
#            5.45279100e-10, 4.69561556e-10, 4.09687478e-10],
#           [2.82936412e-08, 3.37168373e-08, 4.08425969e-08, ...,
#            2.18715979e-08, 1.90471763e-08, 1.67906311e-08],
#           [9.71960077e-08, 1.15324589e-07, 1.39030121e-07, ...,
#            8.17100556e-08, 7.09260419e-08, 6.23321412e-08],
#           ...,
#           [8.85126838e-07, 1.00738532e-06, 1.16180945e-06, ...,
#            2.66725351e-06, 2.14199667e-06, 1.75605976e-06],
#           [8.29125611e-07, 9.46260627e-07, 1.09463963e-06, ...,
#            2.35991229e-06, 1.90005403e-06, 1.56137128e-06],
#           [7.70409713e-07, 8.81447022e-07, 1.02247623e-06, ...,
#            2.08577512e-06, 1.68302370e-06, 1.38580810e-06]],
#
#          [[6.10601791e-10, 7.20920490e-10, 8.64627869e-10, ...,
#            5.98676109e-10, 5.15278764e-10, 4.49358439e-10],
#           [2.12707878e-08, 2.53490153e-08, 3.07081720e-08, ...,
#            1.64634422e-08, 1.43355399e-08, 1.26357254e-08],
#           [1.24490100e-07, 1.47921298e-07, 1.78609426e-07, ...,
#            1.01800843e-07, 8.84602258e-08, 7.78200473e-08],
#           ...,
#           [9.33401395e-07, 1.06168216e-06, 1.22363690e-06, ...,
#            2.87186276e-06, 2.30285423e-06, 1.88547392e-06],
#           [8.76685192e-07, 9.99793315e-07, 1.15564887e-06, ...,
#            2.56069620e-06, 2.05783681e-06, 1.68826671e-06],
#           [8.16373074e-07, 9.33193007e-07, 1.08146298e-06, ...,
#            2.28113208e-06, 1.83641214e-06, 1.50907840e-06]]],
#
#
#         [[[1.02527908e-09, 1.22214028e-09, 1.48116475e-09, ...,
#            8.17327594e-10, 7.09925008e-10, 6.24360119e-10],
#           [1.51101531e-08, 1.78733135e-08, 2.14736851e-08, ...,
#            1.34158773e-08, 1.16229391e-08, 1.01960964e-08],
#           [9.14319997e-08, 1.08138856e-07, 1.29903526e-07, ...,
#            8.11996230e-08, 7.03532876e-08, 6.17206624e-08],
#           ...,
#           [4.80067854e-07, 5.43717022e-07, 6.23696565e-07, ...,
#            1.58366981e-06, 1.26770112e-06, 1.03611717e-06],
#           [4.62355757e-07, 5.24975803e-07, 6.03860371e-07, ...,
#            1.44519026e-06, 1.15970079e-06, 9.49983189e-07],
#           [4.39480004e-07, 5.00204180e-07, 5.76888510e-07, ...,
#            1.30606668e-06, 1.05044262e-06, 8.62274078e-07]],
#
#          [[1.14648568e-09, 1.36687972e-09, 1.65693526e-09, ...,
#            9.11190678e-10, 7.91528898e-10, 6.96191549e-10],
#           [2.52925805e-08, 2.99342382e-08, 3.59855612e-08, ...,
#            2.21680825e-08, 1.92168788e-08, 1.68670553e-08],
#           [1.65599488e-07, 1.95874080e-07, 2.35315341e-07, ...,
#            1.46583204e-07, 1.27028514e-07, 1.11461858e-07],
#           ...,
#           [4.92317042e-07, 5.58237673e-07, 6.41160568e-07, ...,
#            1.57762145e-06, 1.26488658e-06, 1.03530067e-06],
#           [4.73189061e-07, 5.37937296e-07, 6.19597813e-07, ...,
#            1.43507270e-06, 1.15348394e-06, 9.46287116e-07],
#           [4.50186349e-07, 5.13055397e-07, 5.92548304e-07, ...,
#            1.29677574e-06, 1.04472542e-06, 8.58874103e-07]],
#
#          [[1.51574264e-09, 1.80708781e-09, 2.19052509e-09, ...,
#            1.20639287e-09, 1.04786024e-09, 9.21566157e-10],
#           [3.52322935e-08, 4.17050039e-08, 5.01448874e-08, ...,
#            3.07634345e-08, 2.66724509e-08, 2.34146356e-08],
#           [1.92202592e-07, 2.27389037e-07, 2.73238925e-07, ...,
#            1.69260574e-07, 1.46715820e-07, 1.28765095e-07],
#           ...,
#           [5.03342278e-07, 5.71385840e-07, 6.57068142e-07, ...,
#            1.56653778e-06, 1.25809902e-06, 1.03127741e-06],
#           [4.85206897e-07, 5.52280028e-07, 6.36971151e-07, ...,
#            1.42667125e-06, 1.14872353e-06, 9.43842906e-07],
#           [4.62687581e-07, 5.27998395e-07, 6.10683685e-07, ...,
#            1.29032037e-06, 1.04138712e-06, 8.57499856e-07]],
#
#          ...,
#
#          [[4.36355091e-10, 5.17061116e-10, 6.22530361e-10, ...,
#            3.87426757e-10, 3.35179190e-10, 2.93679886e-10],
#           [9.97099470e-09, 1.18748540e-08, 1.43734633e-08, ...,
#            7.67457298e-09, 6.68879352e-09, 5.90045257e-09],
#           [7.94290784e-08, 9.41259728e-08, 1.13310826e-07, ...,
#            6.76118788e-08, 5.86878102e-08, 5.15742187e-08],
#           ...,
#           [8.12231917e-07, 9.25004940e-07, 1.06752088e-06, ...,
#            2.39823908e-06, 1.92867765e-06, 1.58312571e-06],
#           [7.59988495e-07, 8.67948643e-07, 1.00478007e-06, ...,
#            2.11456836e-06, 1.70524584e-06, 1.40324562e-06],
#           [7.05646585e-07, 8.07977813e-07, 9.38029132e-07, ...,
#            1.86052591e-06, 1.50411120e-06, 1.24053440e-06]],
#
#          [[4.66896077e-10, 5.53179336e-10, 6.65923650e-10, ...,
#            4.15887325e-10, 3.59744651e-10, 3.15158011e-10],
#           [1.17938583e-08, 1.40450114e-08, 1.69994543e-08, ...,
#            9.11014020e-09, 7.93809729e-09, 7.00102065e-09],
#           [8.38082954e-08, 9.93658702e-08, 1.19685126e-07, ...,
#            7.05818266e-08, 6.12931501e-08, 5.38862146e-08],
#           ...,
#           [8.56178758e-07, 9.74511522e-07, 1.12398834e-06, ...,
#            2.57563443e-06, 2.06860000e-06, 1.69602106e-06],
#           [8.03123555e-07, 9.16647537e-07, 1.06046275e-06, ...,
#            2.28269255e-06, 1.83799864e-06, 1.51046527e-06],
#           [7.47244428e-07, 8.54998859e-07, 9.91867751e-07, ...,
#            2.02047295e-06, 1.63042034e-06, 1.34256220e-06]],
#
#          [[4.68926176e-10, 5.55502033e-10, 6.68612554e-10, ...,
#            4.19249774e-10, 3.62587682e-10, 3.17595811e-10],
#           [1.35109435e-08, 1.60845826e-08, 1.94613357e-08, ...,
#            1.05333404e-08, 9.17388299e-09, 8.08742850e-09],
#           [7.06789578e-08, 8.38453218e-08, 1.01051555e-07, ...,
#            5.88556723e-08, 5.11339024e-08, 4.49741222e-08],
#           ...,
#           [9.02356362e-07, 1.02646311e-06, 1.18316086e-06, ...,
#            2.76948003e-06, 2.22109679e-06, 1.81877988e-06],
#           [8.48679292e-07, 9.67940309e-07, 1.11893746e-06, ...,
#            2.47319053e-06, 1.98778775e-06, 1.63099594e-06],
#           [7.91259481e-07, 9.04566150e-07, 1.04838909e-06, ...,
#            2.20593392e-06, 1.77611230e-06, 1.45969989e-06]]],
#
#
#         [[[1.66894110e-09, 1.95474725e-09, 2.32359954e-09, ...,
#            1.88018467e-09, 1.61064595e-09, 1.39831169e-09],
#           [9.21205867e-09, 1.07688152e-08, 1.27720323e-08, ...,
#            1.04559144e-08, 8.96686281e-09, 7.79180542e-09],
#           [1.44599515e-08, 1.69017920e-08, 2.00435437e-08, ...,
#            1.64410174e-08, 1.40988679e-08, 1.22506574e-08],
#           ...,
#           [4.46300362e-07, 5.05369201e-07, 5.79576522e-07, ...,
#            1.47711216e-06, 1.18231867e-06, 9.66259677e-07],
#           [4.28879247e-07, 4.86849103e-07, 5.59856403e-07, ...,
#            1.34586060e-06, 1.07988137e-06, 8.84506676e-07],
#           [4.06896959e-07, 4.62993910e-07, 5.33813761e-07, ...,
#            1.21469225e-06, 9.76827778e-07, 8.01745898e-07]],
#
#          [[1.65827208e-09, 1.94164307e-09, 2.30724750e-09, ...,
#            1.88351845e-09, 1.61283187e-09, 1.39967704e-09],
#           [1.58577471e-08, 1.85440356e-08, 2.20018901e-08, ...,
#            1.78477730e-08, 1.53121249e-08, 1.33104372e-08],
#           [1.54862558e-08, 1.81024298e-08, 2.14686082e-08, ...,
#            1.75734396e-08, 1.50716968e-08, 1.30973277e-08],
#           ...,
#           [4.58152613e-07, 5.19391278e-07, 5.96407062e-07, ...,
#            1.47305389e-06, 1.18095636e-06, 9.66527296e-07],
#           [4.39266501e-07, 4.99250859e-07, 5.74883018e-07, ...,
#            1.33762910e-06, 1.07504104e-06, 8.81837195e-07],
#           [4.17382466e-07, 4.75539792e-07, 5.49052629e-07, ...,
#            1.20780669e-06, 9.72920930e-07, 7.99740178e-07]],
#
#          [[1.31062416e-09, 1.53414381e-09, 1.82245341e-09, ...,
#            1.50019186e-09, 1.28408328e-09, 1.11397114e-09],
#           [2.13693738e-08, 2.49923708e-08, 2.96565279e-08, ...,
#            2.39808013e-08, 2.05766533e-08, 1.78890254e-08],
#           [1.47066981e-08, 1.71935230e-08, 2.03936938e-08, ...,
#            1.66331890e-08, 1.42675658e-08, 1.24003527e-08],
#           ...,
#           [4.70207709e-07, 5.33666821e-07, 6.13558768e-07, ...,
#            1.46798050e-06, 1.17886691e-06, 9.66261837e-07],
#           [4.52736401e-07, 5.15200611e-07, 5.94051755e-07, ...,
#            1.33624212e-06, 1.07580900e-06, 8.83847633e-07],
#           [4.30935131e-07, 4.91633500e-07, 5.68456301e-07, ...,
#            1.20697587e-06, 9.74007548e-07, 8.01924955e-07]],
#
#          ...,
#
#          [[1.77648007e-10, 2.07447420e-10, 2.45784199e-10, ...,
#            2.13176449e-10, 1.82128201e-10, 1.57725208e-10],
#           [8.74031869e-09, 1.02961772e-08, 1.23138735e-08, ...,
#            8.34835312e-09, 7.21435667e-09, 6.31353636e-09],
#           [5.18220418e-08, 6.07448172e-08, 7.22567322e-08, ...,
#            5.50630652e-08, 4.73686335e-08, 4.12795984e-08],
#           ...,
#           [7.46124442e-07, 8.49561218e-07, 9.80249524e-07, ...,
#            2.20803895e-06, 1.77572190e-06, 1.45756042e-06],
#           [6.96261282e-07, 7.94997959e-07, 9.20107425e-07, ...,
#            1.94257177e-06, 1.56651572e-06, 1.28904946e-06],
#           [6.45037858e-07, 7.38401980e-07, 8.57022599e-07, ...,
#            1.70607348e-06, 1.37920085e-06, 1.13746603e-06]],
#
#          [[2.00647998e-10, 2.34268466e-10, 2.77513651e-10, ...,
#            2.41557163e-10, 2.06348036e-10, 1.78677739e-10],
#           [9.35656708e-09, 1.10216742e-08, 1.31810873e-08, ...,
#            8.96280739e-09, 7.74379405e-09, 6.77564183e-09],
#           [2.62312216e-08, 3.07779295e-08, 3.66498263e-08, ...,
#            2.72701772e-08, 2.34819346e-08, 2.04816164e-08],
#           ...,
#           [7.85911539e-07, 8.94381856e-07, 1.03137165e-06, ...,
#            2.36814617e-06, 1.90205083e-06, 1.55951761e-06],
#           [7.35358583e-07, 8.39142558e-07, 9.70587166e-07, ...,
#            2.09415407e-06, 1.68626002e-06, 1.38580003e-06],
#           [6.82693724e-07, 7.80973437e-07, 9.05774129e-07, ...,
#            1.84992484e-06, 1.49285495e-06, 1.22931078e-06]],
#
#          [[2.15938240e-10, 2.52069476e-10, 2.98534114e-10, ...,
#            2.61037886e-10, 2.22952046e-10, 1.93025082e-10],
#           [8.22086399e-09, 9.68034275e-09, 1.15725092e-08, ...,
#            7.95709632e-09, 6.87114543e-09, 6.00911143e-09],
#           [2.92784659e-08, 3.43894548e-08, 4.09972678e-08, ...,
#            2.97534619e-08, 2.56452140e-08, 2.23887664e-08],
#           ...,
#           [8.25799304e-07, 9.39210452e-07, 1.08237271e-06, ...,
#            2.53879193e-06, 2.03620448e-06, 1.66744053e-06],
#           [7.74498005e-07, 8.83160567e-07, 1.02070521e-06, ...,
#            2.26128509e-06, 1.81757332e-06, 1.49138646e-06],
#           [7.20582818e-07, 8.23593723e-07, 9.54312668e-07, ...,
#            2.01284183e-06, 1.62074468e-06, 1.33206538e-06]]]],
#        shape=(81, 25, 29, 42))}

# %%
# now, 2: make boundary file 

# fout = MI['lv4_forc_dir'] + '/' + MI['lv4_swan_bnd_file'] --> 
fout = '/project/vboatwright/PFM_dir/simulations/LV4/Forc/LV4_swan.bnd'
pkl_fnm = modinfo_pkl_full
swanfuns.mk_swan_bnd_file(fout,pkl_fnm)
# Out:
# CDIP pickle file loaded

# %%
# import init_funs_forecast as initfuns

import grid_functions as grdfuns
import init_funs as initfuns

driver_path = '/project/vboatwright/PFM_dir/PFM_for_rockfish/driver/'
pyutil_path = '/project/vboatwright/PFM_dir/PFM_for_rockfish/sdpm_py_util/'
simulation_path = '/project/vboatwright/PFM_dir/simulations/'

sys.path.append(driver_path)

# driver_run_hind_LV123 is a function now
from driver_run_hind_LV123 import driver_run_hind_LV123

input_py_full = pyutil_path+'boat_model_info_devel.py'
modinfo_pkl_full = simulation_path+'phm_modinfo_testing.pkl'

PFM = initfuns.get_model_info(modinfo_pkl_full)
print(PFM)
# Out:
# {'hind_river_type': 'IBWC_raw', 'hind_lv1_archive_dir': '/project/vboatwright/pfm_hindcast_data/archive/LV1/', 'hind_lv2_archive_dir': '/project/vboatwright/pfm_hindcast_data/archive/LV2/', 'hind_lv3_archive_dir': '/project/vboatwright/pfm_hindcast_data/archive/LV3/', 'hind_lv4_archive_dir': '/project/vboatwright/pfm_hindcast_data/archive/LV4/', 'hind_river_archive_dir': '/project/vboatwright/pfm_hindcast_data/archive/river_ncs/', 'lv1_bottom_roughness': 0.0007, 'lv2_bottom_roughness': 0.0007, 'lv3_bottom_roughness': 0.0007, 'lv4_bottom_roughness': 0.0007, 'swan_wind_wave_generation': False, 'forecast_days': 1.0, 'hindcast_duration': 12, 'auto_start_hind': True, 'sim_start_time': datetime.datetime(2024, 11, 1, 0, 0), 'sim_end_time': datetime.datetime(2024, 11, 13, 0, 0), 'sim_time_1': datetime.datetime(2024, 11, 2, 0, 0), 'sim_time_2': datetime.datetime(2024, 11, 3, 0, 0), 'levels_to_run': ['LV1', 'LV2', 'LV3', 'LV4'], 'atm_hind_dir': '/project/vboatwright/pfm_hindcast_data/model_forcing/nam_grb2', 'atm_dt_hr': 3, 'server': 'rockfish', 'qtj_obs_fname_full': '/project/vboatwright/pfm_hindcast_data/model_forcing/qtj_obs_data/qtj_raw_20200101_20250901.csv', 'pb_time_switch': datetime.datetime(2025, 4, 1, 0, 0), 'nwm_dir': '/project/vboatwright/pfm_hindcast_data/model_forcing/nwm_files/', 'dt1_days_ibwc': [datetime.datetime(2025, 1, 27, 0, 0), datetime.datetime(2025, 2, 14, 0, 0), datetime.datetime(2025, 3, 13, 0, 0), datetime.datetime(2025, 3, 14, 0, 0)], 'dt1_days_nwm': [], 'dt1_days_pfm': [], 'executable_dir': '/project/vboatwright/PFM_dir/simulations/executables/', 'lv4_blank_name': 'LV4_BLANK.in', 'lv4_yaml_file': '/home/vboatwright/boat_roms/roms/ROMS/External/varinfo.yaml', 'lv4_blank_swan_name': 'LV4_SWAN_BLANK.in', 'lv4_coupling_name': 'LV4_COUPLING_BLANK.in', 'lv4_coawst_varinfo_full': '/project/vboatwright/PFM_dir/simulations/LV4/Run/roms_coawst_varinfo.dat', 'lv4_nwave_dirs': '11', 'lv4_clm_file': 'LV4_clm.nc', 'lv4_nud_file': 'LV4_nud.nc', 'lv4_river_file': 'river_20241101_20241102.nc', 'lv1_grid_file_full': '/project/vboatwright/PFM_dir/simulations/grids/GRID_SDTJRE_LV1_rx020_hmask.nc', 'lv2_grid_file_full': '/project/vboatwright/PFM_dir/simulations/grids/GRID_SDTJRE_LV2_rx020.nc', 'lv3_grid_file_full': '/project/vboatwright/PFM_dir/simulations/grids/GRID_SDTJRE_LV3_rx020.nc', 'lv4_grid_file_full': '/project/vboatwright/PFM_dir/simulations/grids/GRID_SDTJRE_LV4_mss_oct2024.nc', 'ecmwf_dir': '/project/vboatwright/pfm_hindcast_data/model_forcing/ecmwf_data/', 'ecmwf_all_pkl_name': 'ecmwf_all.pkl', 'ecmwf_pkl_roms_vars': 'ecmwf_roms_vars.pkl', 'ecmwf_pkl_on_roms_grid': 'ecmwf_on_romsgrid.pkl', 'swan_to_roms': '720.0d0', 'lv1_max_time_str': '0-00:03', 'lv2_max_time_str': '0-00:04', 'lv3_max_time_str': '0-00:06', 'lv4_max_time_str': '0-01:12', 'run_type': 'hindcast', 'lv1_run_dir': '/project/vboatwright/PFM_dir/simulations/LV1/Run', 'lv1_forc_dir': '/project/vboatwright/PFM_dir/simulations/LV1/Forc', 'lv1_tide_dir': '/project/vboatwright/PFM_dir/simulations/LV1/Tides', 'lv1_grid_dir': '/project/vboatwright/PFM_dir/simulations/grids', 'lv1_his_dir': '/project/vboatwright/PFM_dir/simulations/LV1/His', 'lv1_plot_dir': '/project/vboatwright/PFM_dir/simulations/LV1/Plots', 'lv2_run_dir': '/project/vboatwright/PFM_dir/simulations/LV2/Run', 'lv2_forc_dir': '/project/vboatwright/PFM_dir/simulations/LV2/Forc', 'lv2_grid_dir': '/project/vboatwright/PFM_dir/simulations/grids', 'lv2_his_dir': '/project/vboatwright/PFM_dir/simulations/LV2/His', 'lv2_plot_dir': '/project/vboatwright/PFM_dir/simulations/LV2/Plots', 'lv3_run_dir': '/project/vboatwright/PFM_dir/simulations/LV3_SDTJ/Run', 'lv3_forc_dir': '/project/vboatwright/PFM_dir/simulations/LV3_SDTJ/Forc', 'lv3_grid_dir': '/project/vboatwright/PFM_dir/simulations/grids', 'lv3_his_dir': '/project/vboatwright/PFM_dir/simulations/LV3_SDTJ/His', 'lv3_plot_dir': '/project/vboatwright/PFM_dir/simulations/LV3_SDTJ/Plots', 'lv4_run_dir': '/project/vboatwright/PFM_dir/simulations/LV4/Run', 'lv ...

# %%
def cdip_wave_grabber(fin,vars,fout):
    # this is the function that is parallelized
    # the input is url: the hycom url to get data from
    # dtff: the time stamp of the forecast, ie, the file we want
    # aa: a box that defines the region of interest
    # PFM: used to set the path of where the .nc files go
    # dstr_ft: the date string of the forecast model run. ie. the first
    #          time stamp of the forecast
        
    cmd_list = ['ncks','-q','-D','0','-v', vars, fin ,'-4', '-O', fout]
 
    # run ncks
#    ret1 = subprocess.call(cmd_list,stderr=subprocess.DEVNULL,stdout=subprocess.DEVNULL)
    ret1 = subprocess.call(cmd_list)
    return ret1

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

def get_cdip_data(pkl_fnm):
    # this function gets all of the new hycom data as separate files for each field (ssh,temp,salt,u,v) and each time
    # and puts each .nc file in the directory for hycom data

    PFM=initfuns.get_model_info(pkl_fnm)

    yyyymmddhh = PFM['fetch_time'].strftime("%Y%m%d%H")

    url_0 = 'https://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/model/misc/falk/forecast/F' 
    fn1s = (['2436','2428','2415','2385','2360','2335','2322','2310','2298','2285','2260','2235',	
             '2185','2135','2085','2035','1985','1885','1835','1785','1735','1685','1635','1585',
             '1545','1530','1515','1495','1475','1460','1445','1434','1422','1410','1404','1396',	
             '1388','1380','1372','1364','1356','1348','1340','1334','1330','1326','1322','1318',	
             '1314','1310','1306','1302','1298','1294','1290','1286','1285','1283','1281','1276',	
             '1271','1266','1261','1255','1245','1235','1230','1220','1210','1200','1190','1181',	
             '1161','1141','1121','1101','1081','1061','1041','1021','1001'])
    fn2 = '_ecmwf_fc.nc'
    varns = 'waveTime,waveHs,waveTp,waveDp,waveFrequency,waveDirection,waveDirectionalSpectrum,metaLatitude,metaLongitude'

    files_to_copy = []

    print(yyyymmddhh)
    
    with ThreadPoolExecutor() as executor:
        threads = []
        for ff in fn1s:
            fn = cdip_wave_grabber
            fnmin = url_0+ff+fn2
            fnmout = PFM['cdip_data_dir'] + '/' + 'cdip_' + ff + '_' + yyyymmddhh + '.nc' 
            files_to_copy.append(fnmout)
#           
#  fnmout = ('/scratch/PFM_Simulations/LV4_Forecast/Forc/cdip_data' + '/' 
#                    + 'cdip_' + ff + '_' + yyyymmddhh + '.nc')          
            args = [fnmin,varns,fnmout]
            kwargs = {} #
            # start thread by submitting it to the executor
            threads.append(executor.submit(fn, *args, **kwargs))
            
        for future in as_completed(threads):
                # retrieve the result
            result = future.result()
            #print(result)
                # report the result        

    archive_cdip = PFM['archive_cdip'] 
    if archive_cdip == 1:
        print('copying cdip .nc files to archive...')
        dir2 = PFM['cdip_archive_dir']
        for fname in files_to_copy:
            fn_end = os.path.basename(fname)
            fn_2 = dir2 + fn_end
            try:
                shutil.copy(fname, fn_2)
                #print(f"File '{source_file}' copied successfully to '{destination_directory}'")
            except FileNotFoundError:
                print(f"Error: Source file '{fname}' not found.")
            except Exception as e:
                print(f"An error occurred: {e}")

# %%
get_cdip_data(modinfo_pkl_full)
# Out:
# 2024110100

# %%
# okay it looks like the CDIP information should be correct.?
# lets check an individual file 

import netCDF4 as nc 
import datetime as datetime 
import matplotlib.dates as mdates 

path = '/project/vboatwright/pfm_hindcast_data/model_forcing/cdip_data/'
cdip_fn = f'{path}cdip_1245_2024110100.nc'

ds = nc.Dataset(cdip_fn)

wtime = ds['waveTime'][:]

d0 = datetime.datetime(1970,1,1) # UTC 
ts_array = [d0+datetime.timedelta(seconds=int(dd)) for dd in wtime]

wHs = ds['waveHs'][:]
wSpp = ds['waveDirectionalSpectrum'][:]
wfreq = ds['waveFrequency'][:]
wdir = ds['waveDirection']

plt.figure(figsize=(16,8))
plt.plot(ts_array,wHs)
plt.xlabel('Time (UTC)') 
plt.ylabel('Significant Wave Height')
myFmt = mdates.DateFormatter('%m')
plt.show()

plt.pcolormesh(wdir,wfreq,wSpp[0,:,:],shading='nearest')
plt.xlabel('Wave Direction') 
plt.ylabel('Wave Frequency')
plt.show()

# %%
wtime
# Out:
# masked_array(data=[1771470000, 1771473600, 1771477200, 1771480800,
#                    1771484400, 1771488000, 1771491600, 1771495200,
#                    1771498800, 1771502400, 1771506000, 1771509600,
#                    1771513200, 1771516800, 1771520400, 1771524000,
#                    1771527600, 1771531200, 1771534800, 1771538400,
#                    1771542000, 1771545600, 1771549200, 1771552800,
#                    1771556400, 1771560000, 1771563600, 1771567200,
#                    1771570800, 1771574400, 1771578000, 1771581600,
#                    1771585200, 1771588800, 1771592400, 1771596000,
#                    1771599600, 1771603200, 1771606800, 1771610400,
#                    1771614000, 1771617600, 1771621200, 1771624800,
#                    1771628400, 1771632000, 1771635600, 1771639200,
#                    1771642800, 1771646400, 1771650000, 1771653600,
#                    1771657200, 1771660800, 1771664400, 1771668000,
#                    1771671600, 1771675200, 1771678800, 1771682400,
#                    1771686000, 1771689600, 1771693200, 1771696800,
#                    1771700400, 1771704000, 1771707600, 1771711200,
#                    1771714800, 1771718400, 1771722000, 1771725600,
#                    1771729200, 1771732800, 1771736400, 1771740000,
#                    1771743600, 1771747200, 1771750800, 1771754400,
#                    1771758000, 1771761600, 1771765200, 1771768800,
#                    1771772400, 1771776000, 1771779600, 1771783200,
#                    1771786800, 1771790400, 1771794000, 1771797600,
#                    1771801200, 1771804800, 1771808400, 1771812000,
#                    1771815600, 1771819200, 1771822800, 1771826400,
#                    1771830000, 1771833600, 1771837200, 1771840800,
#                    1771844400, 1771848000, 1771851600, 1771855200,
#                    1771858800, 1771862400, 1771866000, 1771869600,
#                    1771873200, 1771876800, 1771880400, 1771884000,
#                    1771887600, 1771891200, 1771894800, 1771898400,
#                    1771902000, 1771905600, 1771909200, 1771912800,
#                    1771916400, 1771920000, 1771923600, 1771927200,
#                    1771930800, 1771934400, 1771938000, 1771941600,
#                    1771945200, 1771948800, 1771952400, 1771956000,
#                    1771959600, 1771963200, 1771966800, 1771970400,
#                    1771974000, 1771977600, 1771981200, 1771984800,
#                    1771988400, 1771992000, 1771995600, 1771999200,
#                    1772002800, 1772006400, 1772010000, 1772013600,
#                    1772017200, 1772020800, 1772024400, 1772028000,
#                    1772031600, 1772035200, 1772038800, 1772042400,
#                    1772046000, 1772049600, 1772053200, 1772056800,
#                    1772060400, 1772064000, 1772067600, 1772071200,
#                    1772074800, 1772078400, 1772082000, 1772085600,
#                    1772089200, 1772092800, 1772096400, 1772100000,
#                    1772103600, 1772107200, 1772110800, 1772114400,
#                    1772118000, 1772121600, 1772125200, 1772128800,
#                    1772132400, 1772136000, 1772139600, 1772143200,
#                    1772146800, 1772150400, 1772154000, 1772157600],
#              mask=False,
#        fill_value=np.int64(999999),
#             dtype=int32)
