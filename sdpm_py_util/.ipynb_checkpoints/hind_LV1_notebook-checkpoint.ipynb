# %%
from datetime import datetime, timezone, timedelta
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
#import glob
#import netCDF4 as nc
import xarray as xr
import grib2io

#import cfgrib
import urllib
#import pygrib

sys.path.append('../sdpm_py_util')
sys.path.append('../web_util')

import init_funs as initfuns
import ocn_functions as ocnfuns
import plotting_functions as pltfuns
#import atm_functions as atmfuns
import hind_functions as hindfuns
#import grid_functions as grdfuns
#import web_functions as webfuns
from get_PFM_info import get_PFM_info

#import pickle
#import os
import subprocess

# latest anaconda
# https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh
# wget https://repo.continuum.io/archive/Anaconda3-2018.12-Linux-x86_64.sh
# wget https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh

# %%
driver_path = '/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver/'
pyutil_path = '/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/'
simulation_path = '/home/vboatwright/boat_roms/PFM_dir/simulations/'

sys.path.append(driver_path)

# driver_run_hind_LV123 is a function now
from driver_run_hind_LV123 import driver_run_hind_LV123

input_py_full = pyutil_path+'phm_model_info_devel.py'
modinfo_pkl_full = simulation_path+'phm_modinfo_testing.pkl'

driver_run_hind_LV123( input_py_full, modinfo_pkl_full )
# Out:
# first, we need all the model information.
# from /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/phm_model_info_devel.py
# we create a dictionary of model info
# we got to the grid files
# grid file is: /home/vboatwright/boat_roms/PFM_dir/simulations/grids/GRID_LV3_LPL_rx020.nc
# got to atmo forcing
# got to the gridding
# LPL grid coordinates
# hindcast
# set environmemnts
# we got to the executables
# the model_info dictionary is saved to /home/vboatwright/boat_roms/PFM_dir/simulations/phm_modinfo_testing.pkl
# this file dictates how the model is run, where files are saved, etc.
# we initialized model from /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util
# ------------------------------------------------------------
#                         Model Set Up
# ------------------------------------------------------------
# hindcast
# from           : 2024-10-11 00:00
# to             : 2024-10-23 00:00
# in             : 1.0 day chunks (if hindcast)
# we will do     : 12 separate 1.0 day sims
# atm model      : nam_analysis
# ocean_model    : hycom_hind_wtide
# running levels : LV1, LV2, LV3
# restart method : 0
# where are we in driver_run_hindLV123 at start?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util
# PFM info was edited and resaved
# the model_info dictionary was resaved to /home/vboatwright/boat_roms/PFM_dir/simulations/phm_modinfo_testing.pkl
# with properly time stamped output file names
#
#
# ============================================================
# doing a sub simulation from 2024101100 to 2024101200
# ------------------------------------------------------------
# starting LV1
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util
# changing to driver dir to run hind_simulation...getting the hycom data for this simulation...we need  61  hycom nc files...
# the  61  nc files already exist, no need to download.
# ...done
# making the hycom pickle file from all hycom.nc files ...
# max and min raw hycom data (iz is top [0] to bottom [39]):
# max zeta   =  0.816 m          at  ( it, ilat, ilon)     =  ( 23,  49,  49)
# min zeta   = -0.995 m          at  ( it, ilat, ilon)     =  (  7, 203,   0)
# max u      =  0.608 m/s        at  ( it, iz, ilat, ilon) =  (  3,  8,  74,  53)
# min u      = -0.580 m/s        at  ( it, iz, ilat, ilon) =  (  4,  2,  41,  76)
# max v      =  0.585 m/s        at  ( it, iz, ilat, ilon) =  (  7,  4,  36,  90)
# min v      = -0.633 m/s        at  ( it, iz, ilat, ilon) =  (  7,  0, 148,   5)
# max temp   = 22.837 C          at  ( it, iz, ilat, ilon) =  (  8,  0,   0,  98)
# min temp   =  1.368 C          at  ( it, iz, ilat, ilon) =  (  3, 38, 170,   4)
# max dT/dz  =  1.390 C/m        at  ( it, iz, ilat, ilon) =  (  0,  0,  59,  97)
# min dT/dz  = -0.137 C/m        at  ( it, iz, ilat, ilon) =  (  0, 13, 121,  56)
# max salt   = 34.722 psu        at  ( it, iz, ilat, ilon) =  (  5, 38,  17,  39)
# min salt   = 32.592 psu        at  ( it, iz, ilat, ilon) =  (  0, 14, 153,   2)
# max dS/dz  =  0.039 psu/m      at  ( it, iz, ilat, ilon) =  (  1,  7, 157,  15)
# min dS/dz  = -0.052 psu/m      at  ( it, iz, ilat, ilon) =  (  2,  8, 163,   8)
#
# going to save a hycom pickle file to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# Hycom OCN dict saved with pickle.
# did subprocess run correctly? 0 (0=yes,1=no)
# ...done.
# this took:
# 0:00:02.548029
#
#
# starting: ocnfuns.hycom_to_roms_latlon(OCN,RMG)
# putting the hycom data in /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl on the roms grid.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_depth.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ocean_time.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_zeta_time.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ocean_time_ref.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_zeta.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_salt.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_temp.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ubar.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_urm.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vbar.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vrm.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vinfo.pkl' was deleted.
# making a new one...
# ...done.
# all 18 ocnR pickle files were made correctlysubprocess return code? 0 (0=good)
# max and min of hycom data on ROMS grid (iz is top [0] to bottom [39]):
# max zeta   =  0.816 m          at  ( it, ilat, ilon)     =  ( 23,  87,  62)
# min zeta   = -0.950 m          at  ( it, ilat, ilon)     =  (  6, 351, 141)
# max urm    =  0.613 m/s        at  ( it, iz, ilat, ilon) =  (  3,  8, 132, 100)
# min urm    = -0.655 m/s        at  ( it, iz, ilat, ilon) =  (  4,  0,  23, 150)
# max vrm    =  0.512 m/s        at  ( it, iz, ilat, ilon) =  (  7,  4,   0, 194)
# min vrm    = -0.720 m/s        at  ( it, iz, ilat, ilon) =  (  6,  0, 364,   3)
# max temp   = 22.160 C          at  ( it, iz, ilat, ilon) =  (  0,  0, 209, 191)
# min temp   =  1.402 C          at  ( it, iz, ilat, ilon) =  (  5, 38, 389,  26)
# max dT/dz  =  1.388 C/m        at  ( it, iz, ilat, ilon) =  (  0,  0,  25, 247)
# min dT/dz  = -0.348 C/m        at  ( it, iz, ilat, ilon) =  (  1,  6,   2, 240)
# max salt   = 34.722 psu        at  ( it, iz, ilat, ilon) =  (  5, 38,  35,   1)
# min salt   = 32.624 psu        at  ( it, iz, ilat, ilon) =  (  3, 13, 366,   0)
# max dS/dz  =  0.037 psu/m      at  ( it, iz, ilat, ilon) =  (  1,  7, 365,  44)
# min dS/dz  = -0.050 psu/m      at  ( it, iz, ilat, ilon) =  (  2,  8, 386,  25)
# driver_run_forecast_LV1: done with hycom_to_roms_latlon
# ...done with LV1 ocn_R
# this took:
# 0:00:51.325730
#
#
# making the depth pickle file...depth pickle file /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/roms_tmp_depth_file.pklalready exists.
# subprocess return code? 0 (0=good)
#
#
# in run_hind_LV1: what is the use_restart setting?
# 0
# going to save OCN_IC to a pickle file: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnIC_tmp_pckl_file.pklOCN_IC dict saved with pickle
# OCN IC data saved with pickle, correctly? 0 (0=yes,1=no)
# driver_run_forecast_LV1: done with ocn_r_2_ICdict
# this took:
# 0:00:29.410159
#
#
# making IC file from pickled IC: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_IC.ncOCN_IC dict loaded with pickle
#
# max and min of data in ROMS IC file (iz is bottom [0] to top [39], note: it is always 0 b/c IC):
# max zeta   =  0.720 m          at  ( it, ilat, ilon)     =  (  0, 294, 171)
# min zeta   =  0.372 m          at  ( it, ilat, ilon)     =  (  0,   0, 172)
# max ubar   =  0.196 m/s        at  ( it, ilat, ilon)     =  (  0, 244, 144)
# min ubar   = -0.245 m/s        at  ( it, ilat, ilon)     =  (  0, 309, 137)
# max vbar   =  0.270 m/s        at  ( it, ilat, ilon)     =  (  0, 325, 123)
# min vbar   = -0.172 m/s        at  ( it, ilat, ilon)     =  (  0, 166, 216)
# max u      =  0.412 m/s        at  ( it, iz, ilat, ilon) =  (  0, 31, 134, 106)
# min u      = -0.473 m/s        at  ( it, iz, ilat, ilon) =  (  0, 22, 305, 138)
# max v      =  0.482 m/s        at  ( it, iz, ilat, ilon) =  (  0, 20, 328, 119)
# min v      = -0.591 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39, 363,  11)
# max temp   = 22.141 C          at  ( it, iz, ilat, ilon) =  (  0, 39, 209, 191)
# min temp   =  0.977 C          at  ( it, iz, ilat, ilon) =  (  0,  0, 106,  41)
# max salt   = 34.716 psu        at  ( it, iz, ilat, ilon) =  (  0,  0,  37, 171)
# min salt   = 32.645 psu        at  ( it, iz, ilat, ilon) =  (  0, 29, 372,   0)
# OCN IC nc data saved, correctly? 0 (0=yes)
# ic file out is: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_IC.nc
# done makeing IC file.
# going to save OCN_BC to a pickle file to:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnBC_tmp_pckl_file.pklPrevious file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnBC_tmp_pckl_file.pkl' has been deleted successfully.
# loading /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/roms_tmp_depth_file.pkl
# OCN_BC dict saved with pickle
# OCN BC data saved with pickle, correctly? 0 (0=yes)
# this took:
# 0:00:03.640398
#
#
# making BC nc file from pickled BC: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_BC.ncOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.660 m          at  ( it, ilon)     =  (  0, 128)
# min zeta_north = -0.893 m          at  ( it, ilon)     =  (  7,  99)
# max zeta_south =  0.768 m          at  ( it, ilon)     =  ( 23,  54)
# min zeta_south = -0.722 m          at  ( it, ilon)     =  (  6, 158)
# max zeta_west  =  0.776 m          at  ( it, ilat)     =  ( 23,  70)
# min zeta_west  = -0.755 m          at  ( it, ilat)     =  (  7, 221)
# max ubar_north =  0.018 m/s        at  ( it, ilon)     =  (  2, 108)
# min ubar_north = -0.061 m/s        at  ( it, ilon)     =  (  4, 127)
# max ubar_south =  0.032 m/s        at  ( it, ilon)     =  (  5, 214)
# min ubar_south = -0.080 m/s        at  ( it, ilon)     =  (  8, 240)
# max ubar_west  =  0.028 m/s        at  ( it, ilat)     =  (  7, 130)
# min ubar_west  = -0.037 m/s        at  ( it, ilat)     =  (  5,   5)
# max vbar_north =  0.148 m/s        at  ( it, ilon)     =  (  8, 120)
# min vbar_north = -0.058 m/s        at  ( it, ilon)     =  (  2,   6)
# max vbar_south =  0.151 m/s        at  ( it, ilon)     =  (  8, 236)
# min vbar_south = -0.062 m/s        at  ( it, ilon)     =  (  2, 135)
# max vbar_west  =  0.033 m/s        at  ( it, ilat)     =  (  8, 293)
# min vbar_west  = -0.060 m/s        at  ( it, ilat)     =  (  2, 351)
# max u_north    =  0.153 m/s        at  ( it, iz, ilon) =  (  8,  32,  99)
# min u_north    = -0.330 m/s        at  ( it, iz, ilon) =  (  4,  39, 115)
# max u_south    =  0.277 m/s        at  ( it, iz, ilon) =  (  7,  33, 103)
# min u_south    = -0.452 m/s        at  ( it, iz, ilon) =  (  4,  39, 171)
# max u_west     =  0.343 m/s        at  ( it, iz, ilat) =  (  4,  35, 132)
# min u_west     = -0.443 m/s        at  ( it, iz, ilat) =  (  3,  39, 295)
# max v_north    =  0.368 m/s        at  ( it, iz, ilon) =  (  5,  36, 112)
# min v_north    = -0.538 m/s        at  ( it, iz, ilon) =  (  5,  39,   1)
# max v_south    =  0.512 m/s        at  ( it, iz, ilon) =  (  7,  35, 194)
# min v_south    = -0.448 m/s        at  ( it, iz, ilon) =  (  2,  39, 127)
# max v_west     =  0.264 m/s        at  ( it, iz, ilat) =  (  6,  34,  21)
# min v_west     = -0.691 m/s        at  ( it, iz, ilat) =  (  6,  39, 365)
# max temp_north = 17.994 C          at  ( it, iz, ilon) =  (  0,  38,  58)
# min temp_north =  1.083 C          at  ( it, iz, ilon) =  (  7,   0,   4)
# max temp_south = 21.785 C          at  ( it, iz, ilon) =  (  8,  39,  10)
# min temp_south =  1.124 C          at  ( it, iz, ilon) =  (  6,   0,   0)
# max temp_west  = 21.775 C          at  ( it, iz, ilat) =  (  8,  39,   7)
# min temp_west  =  1.072 C          at  ( it, iz, ilat) =  (  2,   0, 230)
# max salt_north = 34.708 psu        at  ( it, iz, ilon) =  (  0,   0,  22)
# min salt_north = 32.678 psu        at  ( it, iz, ilon) =  (  0,  28,  10)
# max salt_south = 34.708 psu        at  ( it, iz, ilon) =  (  6,   0,   0)
# min salt_south = 33.384 psu        at  ( it, iz, ilon) =  (  2,  26,  96)
# max salt_west  = 34.710 psu        at  ( it, iz, ilat) =  (  2,   0,  65)
# min salt_west  = 32.627 psu        at  ( it, iz, ilat) =  (  3,  29, 365)
# OCN BC nc data saved, correctly? 0 (0=yes)
# done makeing BC nc file.
# this took:
# 0:00:01.085647
#
#
# we are now getting the atm data...the  9  grb2 files already exist, no need to download.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:00.931129
#
#
# we are now converting the atm grb2 files to pickles...ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_0000_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_0000_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_0600_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_0600_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_1200_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_1200_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_1800_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_1800_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0000_000.grb2 saved to pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:02.108759
#
#
# we are now putting the hind atm data on the roms LV1 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.581479
#
#
# we are now saving ATM LV1 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.084688
#
#
# does it know server?
# rockfish
# driver_run_forecast_LV1: making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV1 simulation
# the grid file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/grids/GRID_SDTJRE_LV1_rx020_hmask.nc
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/His/LV1_ocean_his_202410110000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410110000_202410120000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_IC.nc
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# this is the blank_infile
# ./LV1_BLANK.in
# ...done
# now running roms LV1 with bash.
# using 0 nodes.
# Ni = 3, NJ = 8
# run_slurm_LV1: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/RunCompletedProcess(args=['bash', 'LV1_openmp.sh'], returncode=0, stdout=b'/home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin\n', stderr=b'')
# subprocess slurm ran correctly? 0 (0=yes)
# run_slurm_LV1: run command:  ['bash', 'LV1_openmp.sh']
# ...done.
# this took:
# 0:04:27.558130
#
#
# starting LV1 hindcast with subprocess...
# ...finished LV1 hindcast.
# return code: 0 (0=good)done with LV1
# LV1 hind ran correctly? 0 (0=yes)
# this took
# 0:06:05.625297
# ------------------------------------------------------------
# starting LV2
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV2 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.626413
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.082231
#
#
# driver_run_forcast_LV2: saving LV2_OCN_BC pickle fileinterpolating z with normal loops.
# OCN_LV 2 _BC dict saved with pickle to:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/BC_LV2_tmp_file.pkl
# return code: 0 (0=good)
# driver_run_forecast_LV2:  done with writing LV2_OCN_BC.pkl file.
# this took:
# 0:00:53.576772
#
#
# driver_run_forcast_LV2: saving LV2_OCN_BC netcdf fileOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.689 m          at  ( it, ilon)     =  ( 24,  59)
# min zeta_north = -0.796 m          at  ( it, ilon)     =  (  7, 161)
# max zeta_south =  0.668 m          at  ( it, ilon)     =  ( 24,   0)
# min zeta_south = -0.760 m          at  ( it, ilon)     =  (  6, 134)
# max zeta_west  =  0.676 m          at  ( it, ilat)     =  ( 24,  59)
# min zeta_west  = -0.765 m          at  ( it, ilat)     =  (  7, 395)
# max ubar_north =  0.114 m/s        at  ( it, ilon)     =  ( 12, 134)
# min ubar_north = -0.040 m/s        at  ( it, ilon)     =  ( 10,  45)
# max ubar_south =  0.083 m/s        at  ( it, ilon)     =  (  9, 244)
# min ubar_south = -0.082 m/s        at  ( it, ilon)     =  (  7, 254)
# max ubar_west  =  0.198 m/s        at  ( it, ilat)     =  ( 15, 338)
# min ubar_west  = -0.167 m/s        at  ( it, ilat)     =  ( 12, 338)
# max vbar_north =  0.110 m/s        at  ( it, ilon)     =  ( 14,  44)
# min vbar_north = -0.186 m/s        at  ( it, ilon)     =  ( 16, 148)
# max vbar_south =  0.147 m/s        at  ( it, ilon)     =  ( 24, 236)
# min vbar_south = -0.121 m/s        at  ( it, ilon)     =  (  3, 255)
# max vbar_west  =  0.178 m/s        at  ( it, ilat)     =  ( 22, 330)
# min vbar_west  = -0.136 m/s        at  ( it, ilat)     =  (  7, 318)
# max u_north    =  0.337 m/s        at  ( it, iz, ilon) =  ( 23,  39, 147)
# min u_north    = -0.374 m/s        at  ( it, iz, ilon) =  (  5,   0,  60)
# max u_south    =  0.303 m/s        at  ( it, iz, ilon) =  ( 24,   0,  73)
# min u_south    = -0.316 m/s        at  ( it, iz, ilon) =  ( 22,   0,  78)
# max u_west     =  1.293 m/s        at  ( it, iz, ilat) =  ( 15,   0, 338)
# min u_west     = -0.795 m/s        at  ( it, iz, ilat) =  ( 12,   0, 338)
# max v_north    =  0.285 m/s        at  ( it, iz, ilon) =  ( 22,   0,  23)
# min v_north    = -0.390 m/s        at  ( it, iz, ilon) =  (  3,  39, 146)
# max v_south    =  0.322 m/s        at  ( it, iz, ilon) =  ( 22,  19, 227)
# min v_south    = -0.424 m/s        at  ( it, iz, ilon) =  ( 23,  39,  35)
# max v_west     =  0.977 m/s        at  ( it, iz, ilat) =  (  5,   0, 318)
# min v_west     = -1.221 m/s        at  ( it, iz, ilat) =  (  7,   0, 318)
# max temp_north = 21.072 C          at  ( it, iz, ilon) =  (  0,  39, 131)
# min temp_north =  3.956 C          at  ( it, iz, ilon) =  (  0,   0,   1)
# max temp_south = 20.586 C          at  ( it, iz, ilon) =  (  0,  39,  74)
# min temp_south =  2.014 C          at  ( it, iz, ilon) =  (  4,   0,   0)
# max temp_west  = 20.992 C          at  ( it, iz, ilat) =  (  0,  39, 278)
# min temp_west  =  1.715 C          at  ( it, iz, ilat) =  (  3,   0,  23)
# max salt_north = 34.663 psu        at  ( it, iz, ilon) =  ( 24,   0,   2)
# min salt_north = 33.374 psu        at  ( it, iz, ilon) =  (  0,  24,  65)
# max salt_south = 34.604 psu        at  ( it, iz, ilon) =  (  4,   0,   0)
# min salt_south = 33.356 psu        at  ( it, iz, ilon) =  (  0,  24,   6)
# max salt_west  = 34.661 psu        at  ( it, iz, ilat) =  ( 20,   0, 389)
# min salt_west  = 33.325 psu        at  ( it, iz, ilat) =  (  5,  24,  59)
# return code: 0 (0=good)
# driver_run_forecast_L21:  done with writing LV2_OCN_BC.nc file.
# this took:
# 0:00:01.138175
#
#
# driver_run_forcast_LV2: making and saving LV2_OCN_IC pickle fileLV_1_OCN_IC dict loaded with pickle
# OCN_LV2_IC dict saved with pickle
# return code: 0 (0=good)
# driver_run_forecast_L21:  done with writing LV2_OCN_IC.pkl file.
# this took:
# 0:00:33.642568
#
#
# driver_run_forcast_LV2: saving LV2_OCN_IC netcdf fileOCN_IC dict loaded with pickle
#
# max and min of data in ROMS IC file (iz is bottom [0] to top [39], note: it is always 0 b/c IC):
# max zeta   =  0.631 m          at  ( it, ilat, ilon)     =  (  0, 344, 185)
# min zeta   =  0.447 m          at  ( it, ilat, ilon)     =  (  0,   0, 125)
# max ubar   =  0.180 m/s        at  ( it, ilat, ilon)     =  (  0, 336, 197)
# min ubar   = -0.130 m/s        at  ( it, ilat, ilon)     =  (  0, 106,  95)
# max vbar   =  0.169 m/s        at  ( it, ilat, ilon)     =  (  0, 334, 197)
# min vbar   = -0.226 m/s        at  ( it, ilat, ilon)     =  (  0, 373, 159)
# max u      =  0.339 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39, 344, 168)
# min u      = -0.313 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39,  74, 162)
# max v      =  0.220 m/s        at  ( it, iz, ilat, ilon) =  (  0, 20, 333, 194)
# min v      = -0.396 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39,  18,  44)
# max temp   = 22.141 C          at  ( it, iz, ilat, ilon) =  (  0, 39, 284,  95)
# min temp   =  1.757 C          at  ( it, iz, ilat, ilon) =  (  0,  0,  32,   4)
# max salt   = 34.709 psu        at  ( it, iz, ilat, ilon) =  (  0,  0, 365,  16)
# min salt   = 33.198 psu        at  ( it, iz, ilat, ilon) =  (  0, 27, 137, 110)
# return code: 0 (0=good)
# driver_run_forecast_L21:  done with writing LV2_OCN_IC.nc file.
# this took:
# 0:00:01.678638
#
#
# making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV2 simulation
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/His/LV2_ocean_his_202410110000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV2_ocean_rst_202410110000_202410120000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_OCEAN_IC.nc
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# ...done
# now running roms LV2 with bash.
# using 0 nodes.
# Ni = 3, NJ = 8
# working...
#  --- running LV2 ---
# run_slurm_LV2: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Run
# run_slurm_LV2: run command:  ['bash', 'LV2_openmp.sh']subprocess slurm ran correctly? 0 (0=yes)
# running ROMS took:
# 0:09:56.186850
#
#
# starting LV2 hindcast with subprocess...
# ...finished LV2 hindcast.
# return code: 0 (0=good)done with LV2
# LV2 hind ran correctly? 0 (0=yes)
# this took
# 0:11:30.796153
# ------------------------------------------------------------
# starting LV3
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV3 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.974236
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.083165
#
#
# driver_run_forcast_LV3: saving LV3_OCN_BC pickle fileinterpolating z with normal loops.
# OCN_LV 3 _BC dict saved with pickle to:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/BC_LV3_tmp_file.pkl
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_BC.pkl file.
# this took:
# 0:00:58.932332
#
#
# driver_run_forcast_LV3: saving LV3_OCN_BC netcdf fileOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.659 m          at  ( it, ilon)     =  ( 24,  26)
# min zeta_north = -0.752 m          at  ( it, ilon)     =  (  6, 221)
# max zeta_south =  0.642 m          at  ( it, ilon)     =  ( 24, 188)
# min zeta_south = -0.738 m          at  ( it, ilon)     =  (  6,  53)
# max zeta_west  =  0.666 m          at  ( it, ilat)     =  ( 24, 281)
# min zeta_west  = -0.733 m          at  ( it, ilat)     =  (  6,   0)
# max ubar_north =  0.098 m/s        at  ( it, ilon)     =  ( 21, 249)
# min ubar_north = -0.105 m/s        at  ( it, ilon)     =  ( 23, 239)
# max ubar_south =  0.064 m/s        at  ( it, ilon)     =  ( 17, 160)
# min ubar_south = -0.237 m/s        at  ( it, ilon)     =  (  8, 191)
# max ubar_west  =  0.072 m/s        at  ( it, ilat)     =  ( 15, 314)
# min ubar_west  = -0.079 m/s        at  ( it, ilat)     =  ( 24, 146)
# max vbar_north =  0.149 m/s        at  ( it, ilon)     =  ( 24, 233)
# min vbar_north = -0.218 m/s        at  ( it, ilon)     =  (  4, 246)
# max vbar_south =  0.192 m/s        at  ( it, ilon)     =  ( 15, 119)
# min vbar_south = -0.145 m/s        at  ( it, ilon)     =  (  3, 189)
# max vbar_west  =  0.025 m/s        at  ( it, ilat)     =  ( 12,   0)
# min vbar_west  = -0.119 m/s        at  ( it, ilat)     =  (  4, 303)
# max u_north    =  0.226 m/s        at  ( it, iz, ilon) =  ( 17,  39, 153)
# min u_north    = -0.252 m/s        at  ( it, iz, ilon) =  ( 24,   0, 219)
# max u_south    =  0.482 m/s        at  ( it, iz, ilon) =  ( 10,   0, 107)
# min u_south    = -0.824 m/s        at  ( it, iz, ilon) =  (  7,   0, 111)
# max u_west     =  0.281 m/s        at  ( it, iz, ilat) =  ( 15,   0, 117)
# min u_west     = -0.547 m/s        at  ( it, iz, ilat) =  (  8,  38,  65)
# max v_north    =  0.251 m/s        at  ( it, iz, ilon) =  ( 22,   0, 221)
# min v_north    = -0.353 m/s        at  ( it, iz, ilon) =  (  7,  39, 170)
# max v_south    =  0.320 m/s        at  ( it, iz, ilon) =  ( 23,   8, 116)
# min v_south    = -0.412 m/s        at  ( it, iz, ilon) =  ( 13,   0, 133)
# max v_west     =  0.429 m/s        at  ( it, iz, ilat) =  ( 20,   0, 310)
# min v_west     = -0.371 m/s        at  ( it, iz, ilat) =  (  3,  39, 282)
# max temp_north = 21.029 C          at  ( it, iz, ilon) =  (  0,  39,   0)
# min temp_north =  4.589 C          at  ( it, iz, ilon) =  ( 14,   0,   4)
# max temp_south = 19.124 C          at  ( it, iz, ilon) =  (  0,  39,  32)
# min temp_south =  2.613 C          at  ( it, iz, ilon) =  (  0,   0,  97)
# max temp_west  = 21.334 C          at  ( it, iz, ilat) =  (  0,  39, 296)
# min temp_west  =  3.156 C          at  ( it, iz, ilat) =  ( 15,   0,  97)
# max salt_north = 34.539 psu        at  ( it, iz, ilon) =  (  1,   0, 101)
# min salt_north = 33.263 psu        at  ( it, iz, ilon) =  (  0,  24, 122)
# max salt_south = 34.590 psu        at  ( it, iz, ilon) =  (  0,   0,  96)
# min salt_south = 33.438 psu        at  ( it, iz, ilon) =  ( 24,  24,   0)
# max salt_west  = 34.661 psu        at  ( it, iz, ilat) =  ( 17,   0, 341)
# min salt_west  = 33.242 psu        at  ( it, iz, ilat) =  (  1,  25, 161)
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_BC.nc file.
# this took:
# 0:00:01.151113
#
#
# driver_run_forcast_LV3: making and saving LV3_OCN_IC pickle fileLV_2_OCN_IC dict loaded with pickle
# OCN_LV3_IC dict saved with pickle
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_IC.pkl file.
# this took:
# 0:00:38.807082
#
#
# driver_run_forcast_LV3: saving LV3_OCN_IC netcdf fileOCN_IC dict loaded with pickle
#
# max and min of data in ROMS IC file (iz is bottom [0] to top [39], note: it is always 0 b/c IC):
# max zeta   =  0.539 m          at  ( it, ilat, ilon)     =  (  0, 458,   0)
# min zeta   =  0.477 m          at  ( it, ilat, ilon)     =  (  0,   0, 185)
# max ubar   =  0.052 m/s        at  ( it, ilat, ilon)     =  (  0, 396,   0)
# min ubar   = -0.124 m/s        at  ( it, ilat, ilon)     =  (  0,  48, 123)
# max vbar   =  0.060 m/s        at  ( it, ilat, ilon)     =  (  0,   0, 116)
# min vbar   = -0.181 m/s        at  ( it, ilat, ilon)     =  (  0,  78, 128)
# max u      =  0.154 m/s        at  ( it, iz, ilat, ilon) =  (  0, 11, 395,   0)
# min u      = -0.266 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39,  62,   0)
# max v      =  0.197 m/s        at  ( it, iz, ilat, ilon) =  (  0,  0, 156, 113)
# min v      = -0.384 m/s        at  ( it, iz, ilat, ilon) =  (  0,  0, 147, 131)
# max temp   = 21.334 C          at  ( it, iz, ilat, ilon) =  (  0, 39, 296,   0)
# min temp   =  1.837 C          at  ( it, iz, ilat, ilon) =  (  0,  0,  88, 111)
# max salt   = 34.704 psu        at  ( it, iz, ilat, ilon) =  (  0,  0, 317, 211)
# min salt   = 33.240 psu        at  ( it, iz, ilat, ilon) =  (  0, 26, 161,   5)
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_IC.nc file.
# this took:
# 0:00:01.729861
#
#
# making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV3 simulation
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/His/LV3_ocean_his_202410110000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV3_ocean_rst_202410110000_202410120000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_OCEAN_IC.nc
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# ...done
# now running roms LV3 with bash.
# using 1 nodes.
# Ni = 4, NJ = 12
# working...
#  --- running LV3 ---
# run_slurm_LV3: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Run
# run_slurm_LV3: run command:  ['bash', 'LV3_openmp.sh']subprocess slurm ran correctly? 0 (0=yes)
# running ROMS took:
# 0:13:26.236309
#
#
# starting LV3 hindcast with subprocess...
# ...finished LV3 hindcast.
# return code: 0 (0=good)done with LV3
# LV3 hind ran correctly? 0 (0=yes)
# this took
# 0:15:11.785839
# ------------------------------------------------------------
# done with the 2024101100 to 2024101200 sub simulation
# this took
# 0:32:48.207526
# ============================================================
# PFM info was edited and resaved
# done with a 1 day LV1 hindcast, going to the next day.
#
# PFM info was edited and resaved
# the model_info dictionary was resaved to /home/vboatwright/boat_roms/PFM_dir/simulations/phm_modinfo_testing.pkl
# with properly time stamped output file names
#
#
# ============================================================
# doing a sub simulation from 2024101200 to 2024101300
# ------------------------------------------------------------
# starting LV1
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...getting the hycom data for this simulation...we need  61  hycom nc files...
# the  61  nc files already exist, no need to download.
# ...done
# making the hycom pickle file from all hycom.nc files ...
# max and min raw hycom data (iz is top [0] to bottom [39]):
# max zeta   =  1.029 m          at  ( it, ilat, ilon)     =  ( 24,  68,  94)
# min zeta   = -1.015 m          at  ( it, ilat, ilon)     =  (  8, 203,   0)
# max u      =  0.635 m/s        at  ( it, iz, ilat, ilon) =  (  3,  8,  74,  53)
# min u      = -0.522 m/s        at  ( it, iz, ilat, ilon) =  (  4,  3,  42,  76)
# max v      =  0.553 m/s        at  ( it, iz, ilat, ilon) =  (  3,  1,   7,  94)
# min v      = -0.711 m/s        at  ( it, iz, ilat, ilon) =  (  7,  0, 146,   6)
# max temp   = 22.837 C          at  ( it, iz, ilat, ilon) =  (  0,  0,   0,  98)
# min temp   =  1.369 C          at  ( it, iz, ilat, ilon) =  (  3, 38, 170,   4)
# max dT/dz  =  1.162 C/m        at  ( it, iz, ilat, ilon) =  (  0,  0,  60,  97)
# min dT/dz  = -0.098 C/m        at  ( it, iz, ilat, ilon) =  (  8, 13, 121,  56)
# max salt   = 34.733 psu        at  ( it, iz, ilat, ilon) =  (  4, 38,  27,  30)
# min salt   = 32.509 psu        at  ( it, iz, ilat, ilon) =  (  4,  4, 177,   5)
# max dS/dz  =  0.045 psu/m      at  ( it, iz, ilat, ilon) =  (  6,  5, 100,  75)
# min dS/dz  = -0.040 psu/m      at  ( it, iz, ilat, ilon) =  (  6,  9, 155,   8)
#
# going to save a hycom pickle file to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# Hycom OCN dict saved with pickle.did subprocess run correctly? 0 (0=yes,1=no)
# ...done.
# this took:
# 0:00:02.779238
#
#
# starting: ocnfuns.hycom_to_roms_latlon(OCN,RMG)
# putting the hycom data in /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl on the roms grid.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_depth.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ocean_time.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_zeta_time.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ocean_time_ref.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_zeta.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_salt.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_temp.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ubar.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_urm.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vbar.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vrm.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vinfo.pkl' was deleted.
# making a new one...
# ...done.
# all 18 ocnR pickle files were made correctlysubprocess return code? 0 (0=good)
# max and min of hycom data on ROMS grid (iz is top [0] to bottom [39]):
# max zeta   =  1.014 m          at  ( it, ilat, ilon)     =  ( 24,  52, 245)
# min zeta   = -0.963 m          at  ( it, ilat, ilon)     =  (  7, 335, 135)
# max urm    =  0.639 m/s        at  ( it, iz, ilat, ilon) =  (  3,  8, 132, 100)
# min urm    = -0.601 m/s        at  ( it, iz, ilat, ilon) =  (  4,  0,  25, 151)
# max vrm    =  0.544 m/s        at  ( it, iz, ilat, ilon) =  (  6,  6,  43, 125)
# min vrm    = -0.796 m/s        at  ( it, iz, ilat, ilon) =  (  7,  0, 355,   4)
# max temp   = 22.096 C          at  ( it, iz, ilat, ilon) =  (  8,  0,   0,   0)
# min temp   =  1.404 C          at  ( it, iz, ilat, ilon) =  (  5, 38, 214,  10)
# max dT/dz  =  1.191 C/m        at  ( it, iz, ilat, ilon) =  (  4,  2, 148, 242)
# min dT/dz  = -0.419 C/m        at  ( it, iz, ilat, ilon) =  (  7,  4, 189, 243)
# max salt   = 34.726 psu        at  ( it, iz, ilat, ilon) =  (  4, 38, 272,  29)
# min salt   = 32.615 psu        at  ( it, iz, ilat, ilon) =  (  4,  6, 389,  14)
# max dS/dz  =  0.045 psu/m      at  ( it, iz, ilat, ilon) =  (  6,  5, 151, 205)
# min dS/dz  = -0.038 psu/m      at  ( it, iz, ilat, ilon) =  (  6,  9, 370,  18)
# driver_run_forecast_LV1: done with hycom_to_roms_latlon
# ...done with LV1 ocn_R
# this took:
# 0:00:51.653417
#
#
# making the depth pickle file...depth pickle file /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/roms_tmp_depth_file.pklalready exists.
# subprocess return code? 0 (0=good)
#
#
# in run_hind_LV1: what is the use_restart setting?
# 1
# going to use a restart file for the LV1 IC. Setting this up...going to restart LV1 from
# 2024-10-12 00:00:00
# ['/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410120000_202410130000.nc', '/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410110000_202410120000.nc']
# found the time index!
# going to restart using /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410110000_202410120000.nc and python-index 3
# PFM info was edited and resaved
# ...done setting up for restart.
# this took:
# 0:00:00.988756
#
# Going to use the file LV1_ocean_rst_202410110000_202410120000.nc to restart the simulation
# with time index 4
#
#
# going to save OCN_BC to a pickle file to:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnBC_tmp_pckl_file.pklPrevious file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnBC_tmp_pckl_file.pkl' has been deleted successfully.
# loading /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/roms_tmp_depth_file.pkl
# OCN_BC dict saved with pickle
# OCN BC data saved with pickle, correctly? 0 (0=yes)
# this took:
# 0:00:03.836879
#
#
# making BC nc file from pickled BC: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_BC.ncOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.658 m          at  ( it, ilon)     =  (  0,   0)
# min zeta_north = -0.931 m          at  ( it, ilon)     =  (  8,  95)
# max zeta_south =  0.839 m          at  ( it, ilon)     =  ( 24,  55)
# min zeta_south = -0.834 m          at  ( it, ilon)     =  (  7, 158)
# max zeta_west  =  0.789 m          at  ( it, ilat)     =  ( 24,  53)
# min zeta_west  = -0.806 m          at  ( it, ilat)     =  (  7, 223)
# max ubar_north =  0.017 m/s        at  ( it, ilon)     =  (  2, 108)
# min ubar_north = -0.059 m/s        at  ( it, ilon)     =  (  4, 127)
# max ubar_south =  0.035 m/s        at  ( it, ilon)     =  (  5, 214)
# min ubar_south = -0.080 m/s        at  ( it, ilon)     =  (  0, 240)
# max ubar_west  =  0.029 m/s        at  ( it, ilat)     =  (  7, 131)
# min ubar_west  = -0.038 m/s        at  ( it, ilat)     =  (  1,   5)
# max vbar_north =  0.148 m/s        at  ( it, ilon)     =  (  0, 120)
# min vbar_north = -0.057 m/s        at  ( it, ilon)     =  (  2,   6)
# max vbar_south =  0.193 m/s        at  ( it, ilon)     =  (  7, 236)
# min vbar_south = -0.061 m/s        at  ( it, ilon)     =  (  2, 135)
# max vbar_west  =  0.035 m/s        at  ( it, ilat)     =  (  8,   9)
# min vbar_west  = -0.060 m/s        at  ( it, ilat)     =  (  2, 366)
# max u_north    =  0.153 m/s        at  ( it, iz, ilon) =  (  0,  32,  99)
# min u_north    = -0.315 m/s        at  ( it, iz, ilon) =  (  6,  37,  34)
# max u_south    =  0.274 m/s        at  ( it, iz, ilon) =  (  0,  33, 102)
# min u_south    = -0.434 m/s        at  ( it, iz, ilon) =  (  4,  39, 158)
# max u_west     =  0.353 m/s        at  ( it, iz, ilat) =  (  3,  34, 133)
# min u_west     = -0.506 m/s        at  ( it, iz, ilat) =  (  3,  38, 293)
# max v_north    =  0.328 m/s        at  ( it, iz, ilon) =  (  5,  25, 119)
# min v_north    = -0.549 m/s        at  ( it, iz, ilon) =  (  5,  39,   0)
# max v_south    =  0.461 m/s        at  ( it, iz, ilon) =  (  0,  35, 199)
# min v_south    = -0.413 m/s        at  ( it, iz, ilon) =  (  8,  39, 129)
# max v_west     =  0.240 m/s        at  ( it, iz, ilat) =  (  5,  34,   5)
# min v_west     = -0.750 m/s        at  ( it, iz, ilat) =  (  6,  39, 366)
# max temp_north = 17.863 C          at  ( it, iz, ilon) =  (  8,  39,   0)
# min temp_north =  1.082 C          at  ( it, iz, ilon) =  (  6,   0,   4)
# max temp_south = 22.096 C          at  ( it, iz, ilon) =  (  8,  39,   0)
# min temp_south =  1.124 C          at  ( it, iz, ilon) =  (  7,   0,   0)
# max temp_west  = 22.096 C          at  ( it, iz, ilat) =  (  8,  39,   0)
# min temp_west  =  1.072 C          at  ( it, iz, ilat) =  (  3,   0, 230)
# max salt_north = 34.708 psu        at  ( it, iz, ilon) =  (  0,   0,  22)
# min salt_north = 32.616 psu        at  ( it, iz, ilon) =  (  4,  34,  14)
# max salt_south = 34.708 psu        at  ( it, iz, ilon) =  (  2,   0,   0)
# min salt_south = 33.403 psu        at  ( it, iz, ilon) =  (  4,  25, 226)
# max salt_west  = 34.710 psu        at  ( it, iz, ilat) =  (  2,   0,  65)
# min salt_west  = 32.662 psu        at  ( it, iz, ilat) =  (  4,  29, 385)
# OCN BC nc data saved, correctly? 0 (0=yes)
# done makeing BC nc file.
# this took:
# 0:00:01.066481
#
#
# we are now getting the atm data...the  9  grb2 files already exist, no need to download.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:00.918845
#
#
# we are now converting the atm grb2 files to pickles...ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0000_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0000_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0600_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0600_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_1200_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_1200_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_1800_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_1800_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241013_0000_000.grb2 saved to pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:02.126188
#
#
# we are now putting the hind atm data on the roms LV1 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.592781
#
#
# we are now saving ATM LV1 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.076444
#
#
# does it know server?
# rockfish
# driver_run_forecast_LV1: making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV1 simulation
# the grid file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/grids/GRID_SDTJRE_LV1_rx020_hmask.nc
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/His/LV1_ocean_his_202410120000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410120000_202410130000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410110000_202410120000.nc
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# this is the blank_infile
# ./LV1_BLANK.in
# ...done
# now running roms LV1 with bash.
# using 0 nodes.
# Ni = 3, NJ = 8
# run_slurm_LV1: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/RunCompletedProcess(args=['bash', 'LV1_openmp.sh'], returncode=0, stdout=b'/home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin\n', stderr=b'')
# subprocess slurm ran correctly? 0 (0=yes)
# run_slurm_LV1: run command:  ['bash', 'LV1_openmp.sh']
# ...done.
# this took:
# 0:04:28.165432
#
#
# starting LV1 hindcast with subprocess...
# ...finished LV1 hindcast.
# return code: 0 (0=good)done with LV1
# LV1 hind ran correctly? 0 (0=yes)
# this took
# 0:05:37.058261
# ------------------------------------------------------------
# starting LV2
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV2 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.604802
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# ...
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV3 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.817596
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.135420
#
#
# driver_run_forcast_LV3: saving LV3_OCN_BC pickle file
# Traceback (most recent call last):
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/ocn_functions.py", line 9215, in <module>
#     globals()[args[1]](*args[2:])
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/ocn_functions.py", line 6709, in mk_LV2_BC_dict_edges
#     his_ds = nc.Dataset(fn)
#              ^^^^^^^^^^^^^^
#   File "src/netCDF4/_netCDF4.pyx", line 2521, in netCDF4._netCDF4.Dataset.__init__
#   File "src/netCDF4/_netCDF4.pyx", line 2158, in netCDF4._netCDF4._ensure_nc_success
# FileNotFoundError: [Errno 2] No such file or directory: '/home/vboatwright/boat_roms/PFM_dir/simulations/LV2/His/LV2_ocean_his_202410140000.nc'
# return code: 1 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_BC.pkl file.
# this took:
# 0:00:01.031484
#
#
# driver_run_forcast_LV3: saving LV3_OCN_BC netcdf fileOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.689 m          at  ( it, ilon)     =  ( 24, 240)
# min zeta_north = -0.833 m          at  ( it, ilon)     =  (  7, 221)
# max zeta_south =  0.686 m          at  ( it, ilon)     =  ( 24, 185)
# min zeta_south = -0.826 m          at  ( it, ilon)     =  (  7,  50)
# max zeta_west  =  0.684 m          at  ( it, ilat)     =  ( 24, 389)
# min zeta_west  = -0.825 m          at  ( it, ilat)     =  (  7,   0)
# max ubar_north =  0.101 m/s        at  ( it, ilon)     =  ( 17, 249)
# min ubar_north = -0.126 m/s        at  ( it, ilon)     =  ( 14, 239)
# max ubar_south =  0.080 m/s        at  ( it, ilon)     =  ( 20, 191)
# min ubar_south = -0.179 m/s        at  ( it, ilon)     =  (  6, 191)
# max ubar_west  =  0.065 m/s        at  ( it, ilat)     =  (  4, 404)
# min ubar_west  = -0.079 m/s        at  ( it, ilat)     =  ( 16, 145)
# max vbar_north =  0.312 m/s        at  ( it, ilon)     =  ( 11, 233)
# min vbar_north = -0.202 m/s        at  ( it, ilon)     =  (  3, 247)
# max vbar_south =  0.261 m/s        at  ( it, ilon)     =  ( 15, 119)
# min vbar_south = -0.102 m/s        at  ( it, ilon)     =  (  6, 101)
# max vbar_west  =  0.023 m/s        at  ( it, ilat)     =  ( 24,   0)
# min vbar_west  = -0.139 m/s        at  ( it, ilat)     =  (  6, 303)
# max u_north    =  0.223 m/s        at  ( it, iz, ilon) =  ( 17,  39, 126)
# min u_north    = -0.379 m/s        at  ( it, iz, ilon) =  (  7,   0, 219)
# max u_south    =  0.294 m/s        at  ( it, iz, ilon) =  (  8,   0, 132)
# min u_south    = -0.275 m/s        at  ( it, iz, ilon) =  (  6,  39, 117)
# max u_west     =  0.287 m/s        at  ( it, iz, ilat) =  ( 15,   0, 117)
# min u_west     = -0.388 m/s        at  ( it, iz, ilat) =  (  8,  38,  56)
# max v_north    =  0.452 m/s        at  ( it, iz, ilon) =  (  6,   0, 221)
# min v_north    = -0.301 m/s        at  ( it, iz, ilon) =  (  3,  39, 185)
# max v_south    =  0.369 m/s        at  ( it, iz, ilon) =  ( 15,  10, 116)
# min v_south    = -0.410 m/s        at  ( it, iz, ilon) =  (  4,   0, 133)
# max v_west     =  0.362 m/s        at  ( it, iz, ilat) =  (  3,   0, 309)
# min v_west     = -0.373 m/s        at  ( it, iz, ilat) =  (  1,  39, 261)
# max temp_north = 20.421 C          at  ( it, iz, ilon) =  ( 23,  39,   0)
# min temp_north =  4.602 C          at  ( it, iz, ilon) =  ( 18,   0,   4)
# max temp_south = 18.837 C          at  ( it, iz, ilon) =  (  0,  39,   5)
# min temp_south =  3.154 C          at  ( it, iz, ilon) =  ( 20,   0,   0)
# max temp_west  = 20.450 C          at  ( it, iz, ilat) =  (  0,  39, 263)
# min temp_west  =  3.017 C          at  ( it, iz, ilat) =  ( 24,   0,  16)
# max salt_north = 34.534 psu        at  ( it, iz, ilon) =  (  0,   0,  83)
# min salt_north = 33.271 psu        at  ( it, iz, ilon) =  (  0,  23, 122)
# max salt_south = 34.558 psu        at  ( it, iz, ilon) =  ( 19,   0,   0)
# min salt_south = 33.425 psu        at  ( it, iz, ilon) =  ( 20,  26,  59)
# max salt_west  = 34.631 psu        at  ( it, iz, ilat) =  ( 23,   0, 344)
# min salt_west  = 33.252 psu        at  ( it, iz, ilat) =  (  1,  26, 120)
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_BC.nc file.
# this took:
# 0:00:01.145100
#
#
# going to use a restart file for the LV3 IC. Setting this up...going to restart LV3 from
# 2024-10-14 00:00:00
# ['/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV3_ocean_rst_202410120000_202410130000.nc', '/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV3_ocean_rst_202410110000_202410120000.nc']
# WARNIG the time stamp wasnt found in any restart file. CANT USE RESTART
# going to restart using none and python-index -99
# PFM info was edited and resaved
# ...done setting up for restart.
# this took:
# 0:00:00.958996
#
# Going to use the file none to restart the simulation
# with time index -98
#
#
# WARNING RESTARTING LV2 WILL NOT WORK!!!
# making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV3 simulation
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/His/LV3_ocean_his_202410140000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV3_ocean_rst_202410140000_202410150000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/none
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# ...done
# now running roms LV3 with bash.
# using 1 nodes.
# Ni = 4, NJ = 12
# working...
#  --- running LV3 ---
# run_slurm_LV3: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Run
# run_slurm_LV3: run command:  ['bash', 'LV3_openmp.sh']subprocess slurm ran correctly? 1 (0=yes)
# running ROMS took:
# 0:00:01.030241
#
# starting LV3 hindcast with subprocess...
# ...finished LV3 hindcast.
# return code: 0 (0=good)
# done with LV3
# LV3 hind ran correctly? 0 (0=yes)
# this took
# 0:00:09.205146
# ------------------------------------------------------------
# done with the 2024101400 to 2024101500 sub simulation
# this took
# 0:01:27.375424
# ============================================================
# PFM info was edited and resaved
# done with a 1 day LV1 hindcast, going to the next day.
#
# PFM info was edited and resaved
# the model_info dictionary was resaved to /home/vboatwright/boat_roms/PFM_dir/simulations/phm_modinfo_testing.pkl
# with properly time stamped output file names
#
#
# ============================================================
# doing a sub simulation from 2024101500 to 2024101600
# ------------------------------------------------------------
# starting LV1
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...getting the hycom data for this simulation...we need  61  hycom nc files...
# the  61  nc files already exist, no need to download.
# ...done
# making the hycom pickle file from all hycom.nc files ...
# max and min raw hycom data (iz is top [0] to bottom [39]):
# max zeta   =  1.037 m          at  ( it, ilat, ilon)     =  ( 15,  84,  90)
# min zeta   = -0.907 m          at  ( it, ilat, ilon)     =  ( 21,  72,  93)
# max u      =  0.608 m/s        at  ( it, iz, ilat, ilon) =  (  7,  0, 142,   9)
# min u      = -0.603 m/s        at  ( it, iz, ilat, ilon) =  (  5, 12, 149,  43)
# max v      =  0.541 m/s        at  ( it, iz, ilat, ilon) =  (  0,  7,  14,  92)
# min v      = -0.625 m/s        at  ( it, iz, ilat, ilon) =  (  4,  0, 120,  14)
# max temp   = 21.921 C          at  ( it, iz, ilat, ilon) =  (  8,  0,  94,  80)
# min temp   =  1.397 C          at  ( it, iz, ilat, ilon) =  (  0, 38,   3,   5)
# max dT/dz  =  1.139 C/m        at  ( it, iz, ilat, ilon) =  (  0,  0,  72,  92)
# min dT/dz  = -0.136 C/m        at  ( it, iz, ilat, ilon) =  (  0,  5, 114,  82)
# max salt   = 34.727 psu        at  ( it, iz, ilat, ilon) =  (  4, 37,  50,  79)
# min salt   = 32.694 psu        at  ( it, iz, ilat, ilon) =  (  0,  0, 163,   4)
# max dS/dz  =  0.051 psu/m      at  ( it, iz, ilat, ilon) =  (  4,  8, 193,  15)
# min dS/dz  = -0.049 psu/m      at  ( it, iz, ilat, ilon) =  (  4,  8, 159,  10)
#
# going to save a hycom pickle file to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# Hycom OCN dict saved with pickle.
# did subprocess run correctly? 0 (0=yes,1=no)
# ...done.
# this took:
# 0:00:02.633057
#
#
# starting: ocnfuns.hycom_to_roms_latlon(OCN,RMG)
# putting the hycom data in /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl on the roms grid.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_depth.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_v.pkl' was deleted.
# making a new one...
# Traceback (most recent call last):
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/ocn_functions.py", line 9215, in <module>
#     globals()[args[1]](*args[2:])
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/ocn_functions.py", line 3366, in make_all_tmp_pckl_ocnR_files_1hrzeta
#     ret1 = subprocess.run(cmd_list )
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/usr/lib64/python3.12/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver/driver_functions.py", line 1639, in <module>
#     globals()[args[1]](*args[2:])
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver/driver_functions.py", line 93, in run_hind_LV1
#     ret1 = subprocess.run(cmd_list)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/usr/lib64/python3.12/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# starting LV1 hindcast with subprocess...
# Traceback (most recent call last):
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver/driver_functions.py", line 1639, in <module>
#     globals()[args[1]](*args[2:])
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver/driver_functions.py", line 1572, in run_hind_simulation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      10 input_py_full = pyutil_path+'phm_model_info_devel.py'
#      11 modinfo_pkl_full = simulation_path+'phm_modinfo_testing.pkl'
# ---> 13 driver_run_hind_LV123( input_py_full, modinfo_pkl_full )
#
# File ~/boat_roms/PFM_dir/PFM_for_rockfish/driver/driver_run_hind_LV123.py:71, in driver_run_hind_LV123(input_py_full, pkl_fnm)
#      69 #            cmd_list = ['python','-W','ignore','driver_functions.py','run_hind_simulation',time1,lvl,pkl_fnm]
#      70             cmd_list = ['python','driver_functions.py','run_hind_simulation',time1,lvl,pkl_fnm]
# ---> 71             ret1 = subprocess.run(cmd_list)
#      72             print('done with ' + lvl)
#      73             print(lvl +' hind ran correctly? ' + str(ret1.returncode) + ' (0=yes)')
#
# File /usr/lib64/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /usr/lib64/python3.12/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File /usr/lib64/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /usr/lib64/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File /usr/lib64/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:

# %%
driver_path = '/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver/'
pyutil_path = '/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/'
simulation_path = '/home/vboatwright/boat_roms/PFM_dir/simulations/'

sys.path.append(driver_path)

# driver_run_hind_LV123 is a function now
from driver_run_hind_LV123 import driver_run_hind_LV123

input_py_full = pyutil_path+'phm_model_info_devel.py'
modinfo_pkl_full = simulation_path+'phm_modinfo_testing.pkl'

driver_run_hind_LV123( input_py_full, modinfo_pkl_full )
# Out:
# first, we need all the model information.
# from /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/phm_model_info_devel.py
# we create a dictionary of model info
# we got to the grid files
# grid file is: /home/vboatwright/boat_roms/PFM_dir/simulations/grids/GRID_LV3_LPL_rx020.nc
# got to atmo forcing
# got to the gridding
# LPL grid coordinates
# hindcast
# set environmemnts
# we got to the executables
# the model_info dictionary is saved to /home/vboatwright/boat_roms/PFM_dir/simulations/phm_modinfo_testing.pkl
# this file dictates how the model is run, where files are saved, etc.
# we initialized model from /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util
# ------------------------------------------------------------
#                         Model Set Up
# ------------------------------------------------------------
# hindcast
# from           : 2024-10-11 00:00
# to             : 2024-10-23 00:00
# in             : 1.0 day chunks (if hindcast)
# we will do     : 12 separate 1.0 day sims
# atm model      : nam_analysis
# ocean_model    : hycom_hind_wtide
# running levels : LV1, LV2, LV3
# restart method : 0
# where are we in driver_run_hindLV123 at start?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util
# PFM info was edited and resaved
# the model_info dictionary was resaved to /home/vboatwright/boat_roms/PFM_dir/simulations/phm_modinfo_testing.pkl
# with properly time stamped output file names
#
#
# ============================================================
# doing a sub simulation from 2024101100 to 2024101200
# ------------------------------------------------------------
# starting LV1
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util
# changing to driver dir to run hind_simulation...getting the hycom data for this simulation...we need  61  hycom nc files...
# the  61  nc files already exist, no need to download.
# ...done
# making the hycom pickle file from all hycom.nc files ...
# max and min raw hycom data (iz is top [0] to bottom [39]):
# max zeta   =  0.816 m          at  ( it, ilat, ilon)     =  ( 23,  49,  49)
# min zeta   = -0.995 m          at  ( it, ilat, ilon)     =  (  7, 203,   0)
# max u      =  0.608 m/s        at  ( it, iz, ilat, ilon) =  (  3,  8,  74,  53)
# min u      = -0.580 m/s        at  ( it, iz, ilat, ilon) =  (  4,  2,  41,  76)
# max v      =  0.585 m/s        at  ( it, iz, ilat, ilon) =  (  7,  4,  36,  90)
# min v      = -0.633 m/s        at  ( it, iz, ilat, ilon) =  (  7,  0, 148,   5)
# max temp   = 22.837 C          at  ( it, iz, ilat, ilon) =  (  8,  0,   0,  98)
# min temp   =  1.368 C          at  ( it, iz, ilat, ilon) =  (  3, 38, 170,   4)
# max dT/dz  =  1.390 C/m        at  ( it, iz, ilat, ilon) =  (  0,  0,  59,  97)
# min dT/dz  = -0.137 C/m        at  ( it, iz, ilat, ilon) =  (  0, 13, 121,  56)
# max salt   = 34.722 psu        at  ( it, iz, ilat, ilon) =  (  5, 38,  17,  39)
# min salt   = 32.592 psu        at  ( it, iz, ilat, ilon) =  (  0, 14, 153,   2)
# max dS/dz  =  0.039 psu/m      at  ( it, iz, ilat, ilon) =  (  1,  7, 157,  15)
# min dS/dz  = -0.052 psu/m      at  ( it, iz, ilat, ilon) =  (  2,  8, 163,   8)
#
# going to save a hycom pickle file to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# Hycom OCN dict saved with pickle.
# did subprocess run correctly? 0 (0=yes,1=no)
# ...done.
# this took:
# 0:00:02.541645
#
#
# starting: ocnfuns.hycom_to_roms_latlon(OCN,RMG)
# putting the hycom data in /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl on the roms grid.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_depth.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ocean_time.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_zeta_time.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ocean_time_ref.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_zeta.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_salt.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_temp.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ubar.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_urm.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vbar.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vrm.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vinfo.pkl' was deleted.
# making a new one...
# ...done.
# all 18 ocnR pickle files were made correctlysubprocess return code? 0 (0=good)
# max and min of hycom data on ROMS grid (iz is top [0] to bottom [39]):
# max zeta   =  0.816 m          at  ( it, ilat, ilon)     =  ( 23,  87,  62)
# min zeta   = -0.950 m          at  ( it, ilat, ilon)     =  (  6, 351, 141)
# max urm    =  0.613 m/s        at  ( it, iz, ilat, ilon) =  (  3,  8, 132, 100)
# min urm    = -0.655 m/s        at  ( it, iz, ilat, ilon) =  (  4,  0,  23, 150)
# max vrm    =  0.512 m/s        at  ( it, iz, ilat, ilon) =  (  7,  4,   0, 194)
# min vrm    = -0.720 m/s        at  ( it, iz, ilat, ilon) =  (  6,  0, 364,   3)
# max temp   = 22.160 C          at  ( it, iz, ilat, ilon) =  (  0,  0, 209, 191)
# min temp   =  1.402 C          at  ( it, iz, ilat, ilon) =  (  5, 38, 389,  26)
# max dT/dz  =  1.388 C/m        at  ( it, iz, ilat, ilon) =  (  0,  0,  25, 247)
# min dT/dz  = -0.348 C/m        at  ( it, iz, ilat, ilon) =  (  1,  6,   2, 240)
# max salt   = 34.722 psu        at  ( it, iz, ilat, ilon) =  (  5, 38,  35,   1)
# min salt   = 32.624 psu        at  ( it, iz, ilat, ilon) =  (  3, 13, 366,   0)
# max dS/dz  =  0.037 psu/m      at  ( it, iz, ilat, ilon) =  (  1,  7, 365,  44)
# min dS/dz  = -0.050 psu/m      at  ( it, iz, ilat, ilon) =  (  2,  8, 386,  25)
# driver_run_forecast_LV1: done with hycom_to_roms_latlon
# ...done with LV1 ocn_R
# this took:
# 0:00:50.954679
#
#
# making the depth pickle file...depth pickle file /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/roms_tmp_depth_file.pklalready exists.
# subprocess return code? 0 (0=good)
#
#
# in run_hind_LV1: what is the use_restart setting?
# 0
# going to save OCN_IC to a pickle file: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnIC_tmp_pckl_file.pklOCN_IC dict saved with pickle
# OCN IC data saved with pickle, correctly? 0 (0=yes,1=no)
# driver_run_forecast_LV1: done with ocn_r_2_ICdict
# this took:
# 0:00:30.273078
#
#
# making IC file from pickled IC: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_IC.ncOCN_IC dict loaded with pickle
#
# max and min of data in ROMS IC file (iz is bottom [0] to top [39], note: it is always 0 b/c IC):
# max zeta   =  0.720 m          at  ( it, ilat, ilon)     =  (  0, 294, 171)
# min zeta   =  0.372 m          at  ( it, ilat, ilon)     =  (  0,   0, 172)
# max ubar   =  0.196 m/s        at  ( it, ilat, ilon)     =  (  0, 244, 144)
# min ubar   = -0.245 m/s        at  ( it, ilat, ilon)     =  (  0, 309, 137)
# max vbar   =  0.270 m/s        at  ( it, ilat, ilon)     =  (  0, 325, 123)
# min vbar   = -0.172 m/s        at  ( it, ilat, ilon)     =  (  0, 166, 216)
# max u      =  0.412 m/s        at  ( it, iz, ilat, ilon) =  (  0, 31, 134, 106)
# min u      = -0.473 m/s        at  ( it, iz, ilat, ilon) =  (  0, 22, 305, 138)
# max v      =  0.482 m/s        at  ( it, iz, ilat, ilon) =  (  0, 20, 328, 119)
# min v      = -0.591 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39, 363,  11)
# max temp   = 22.141 C          at  ( it, iz, ilat, ilon) =  (  0, 39, 209, 191)
# min temp   =  0.977 C          at  ( it, iz, ilat, ilon) =  (  0,  0, 106,  41)
# max salt   = 34.716 psu        at  ( it, iz, ilat, ilon) =  (  0,  0,  37, 171)
# min salt   = 32.645 psu        at  ( it, iz, ilat, ilon) =  (  0, 29, 372,   0)
# OCN IC nc data saved, correctly? 0 (0=yes)
# ic file out is: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_IC.nc
# done makeing IC file.
# going to save OCN_BC to a pickle file to:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnBC_tmp_pckl_file.pklPrevious file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnBC_tmp_pckl_file.pkl' has been deleted successfully.
# loading /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/roms_tmp_depth_file.pkl
# OCN_BC dict saved with pickle
# OCN BC data saved with pickle, correctly? 0 (0=yes)
# this took:
# 0:00:03.733665
#
#
# making BC nc file from pickled BC: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_BC.ncOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.660 m          at  ( it, ilon)     =  (  0, 128)
# min zeta_north = -0.893 m          at  ( it, ilon)     =  (  7,  99)
# max zeta_south =  0.768 m          at  ( it, ilon)     =  ( 23,  54)
# min zeta_south = -0.722 m          at  ( it, ilon)     =  (  6, 158)
# max zeta_west  =  0.776 m          at  ( it, ilat)     =  ( 23,  70)
# min zeta_west  = -0.755 m          at  ( it, ilat)     =  (  7, 221)
# max ubar_north =  0.018 m/s        at  ( it, ilon)     =  (  2, 108)
# min ubar_north = -0.061 m/s        at  ( it, ilon)     =  (  4, 127)
# max ubar_south =  0.032 m/s        at  ( it, ilon)     =  (  5, 214)
# min ubar_south = -0.080 m/s        at  ( it, ilon)     =  (  8, 240)
# max ubar_west  =  0.028 m/s        at  ( it, ilat)     =  (  7, 130)
# min ubar_west  = -0.037 m/s        at  ( it, ilat)     =  (  5,   5)
# max vbar_north =  0.148 m/s        at  ( it, ilon)     =  (  8, 120)
# min vbar_north = -0.058 m/s        at  ( it, ilon)     =  (  2,   6)
# max vbar_south =  0.151 m/s        at  ( it, ilon)     =  (  8, 236)
# min vbar_south = -0.062 m/s        at  ( it, ilon)     =  (  2, 135)
# max vbar_west  =  0.033 m/s        at  ( it, ilat)     =  (  8, 293)
# min vbar_west  = -0.060 m/s        at  ( it, ilat)     =  (  2, 351)
# max u_north    =  0.153 m/s        at  ( it, iz, ilon) =  (  8,  32,  99)
# min u_north    = -0.330 m/s        at  ( it, iz, ilon) =  (  4,  39, 115)
# max u_south    =  0.277 m/s        at  ( it, iz, ilon) =  (  7,  33, 103)
# min u_south    = -0.452 m/s        at  ( it, iz, ilon) =  (  4,  39, 171)
# max u_west     =  0.343 m/s        at  ( it, iz, ilat) =  (  4,  35, 132)
# min u_west     = -0.443 m/s        at  ( it, iz, ilat) =  (  3,  39, 295)
# max v_north    =  0.368 m/s        at  ( it, iz, ilon) =  (  5,  36, 112)
# min v_north    = -0.538 m/s        at  ( it, iz, ilon) =  (  5,  39,   1)
# max v_south    =  0.512 m/s        at  ( it, iz, ilon) =  (  7,  35, 194)
# min v_south    = -0.448 m/s        at  ( it, iz, ilon) =  (  2,  39, 127)
# max v_west     =  0.264 m/s        at  ( it, iz, ilat) =  (  6,  34,  21)
# min v_west     = -0.691 m/s        at  ( it, iz, ilat) =  (  6,  39, 365)
# max temp_north = 17.994 C          at  ( it, iz, ilon) =  (  0,  38,  58)
# min temp_north =  1.083 C          at  ( it, iz, ilon) =  (  7,   0,   4)
# max temp_south = 21.785 C          at  ( it, iz, ilon) =  (  8,  39,  10)
# min temp_south =  1.124 C          at  ( it, iz, ilon) =  (  6,   0,   0)
# max temp_west  = 21.775 C          at  ( it, iz, ilat) =  (  8,  39,   7)
# min temp_west  =  1.072 C          at  ( it, iz, ilat) =  (  2,   0, 230)
# max salt_north = 34.708 psu        at  ( it, iz, ilon) =  (  0,   0,  22)
# min salt_north = 32.678 psu        at  ( it, iz, ilon) =  (  0,  28,  10)
# max salt_south = 34.708 psu        at  ( it, iz, ilon) =  (  6,   0,   0)
# min salt_south = 33.384 psu        at  ( it, iz, ilon) =  (  2,  26,  96)
# max salt_west  = 34.710 psu        at  ( it, iz, ilat) =  (  2,   0,  65)
# min salt_west  = 32.627 psu        at  ( it, iz, ilat) =  (  3,  29, 365)
# OCN BC nc data saved, correctly? 0 (0=yes)
# done makeing BC nc file.
# this took:
# 0:00:01.045645
#
#
# we are now getting the atm data...the  9  grb2 files already exist, no need to download.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:00.884725
#
#
# we are now converting the atm grb2 files to pickles...ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_0000_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_0000_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_0600_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_0600_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_1200_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_1200_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_1800_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241011_1800_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0000_000.grb2 saved to pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:02.093192
#
#
# we are now putting the hind atm data on the roms LV1 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.563421
#
#
# we are now saving ATM LV1 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.056833
#
#
# does it know server?
# rockfish
# driver_run_forecast_LV1: making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV1 simulation
# the grid file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/grids/GRID_SDTJRE_LV1_rx020_hmask.nc
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/His/LV1_ocean_his_202410110000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410110000_202410120000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_IC.nc
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# this is the blank_infile
# ./LV1_BLANK.in
# ...done
# now running roms LV1 with bash.
# using 0 nodes.
# Ni = 3, NJ = 8
# run_slurm_LV1: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/RunCompletedProcess(args=['bash', 'LV1_openmp.sh'], returncode=0, stdout=b'/home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin\n', stderr=b'')
# subprocess slurm ran correctly? 0 (0=yes)
# run_slurm_LV1: run command:  ['bash', 'LV1_openmp.sh']
# ...done.
# this took:
# 0:04:27.378753
#
#
# starting LV1 hindcast with subprocess...
# ...finished LV1 hindcast.
# return code: 0 (0=good)done with LV1
# LV1 hind ran correctly? 0 (0=yes)
# this took
# 0:06:05.830831
# ------------------------------------------------------------
# starting LV2
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV2 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.585864
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.058822
#
#
# driver_run_forcast_LV2: saving LV2_OCN_BC pickle fileinterpolating z with normal loops.
# OCN_LV 2 _BC dict saved with pickle to:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/BC_LV2_tmp_file.pkl
# return code: 0 (0=good)
# driver_run_forecast_LV2:  done with writing LV2_OCN_BC.pkl file.
# this took:
# 0:00:57.640123
#
#
# driver_run_forcast_LV2: saving LV2_OCN_BC netcdf fileOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.689 m          at  ( it, ilon)     =  ( 24,  59)
# min zeta_north = -0.796 m          at  ( it, ilon)     =  (  7, 161)
# max zeta_south =  0.668 m          at  ( it, ilon)     =  ( 24,   0)
# min zeta_south = -0.760 m          at  ( it, ilon)     =  (  6, 134)
# max zeta_west  =  0.676 m          at  ( it, ilat)     =  ( 24,  59)
# min zeta_west  = -0.765 m          at  ( it, ilat)     =  (  7, 395)
# max ubar_north =  0.114 m/s        at  ( it, ilon)     =  ( 12, 134)
# min ubar_north = -0.040 m/s        at  ( it, ilon)     =  ( 10,  45)
# max ubar_south =  0.083 m/s        at  ( it, ilon)     =  (  9, 244)
# min ubar_south = -0.082 m/s        at  ( it, ilon)     =  (  7, 254)
# max ubar_west  =  0.198 m/s        at  ( it, ilat)     =  ( 15, 338)
# min ubar_west  = -0.167 m/s        at  ( it, ilat)     =  ( 12, 338)
# max vbar_north =  0.110 m/s        at  ( it, ilon)     =  ( 14,  44)
# min vbar_north = -0.186 m/s        at  ( it, ilon)     =  ( 16, 148)
# max vbar_south =  0.147 m/s        at  ( it, ilon)     =  ( 24, 236)
# min vbar_south = -0.121 m/s        at  ( it, ilon)     =  (  3, 255)
# max vbar_west  =  0.178 m/s        at  ( it, ilat)     =  ( 22, 330)
# min vbar_west  = -0.136 m/s        at  ( it, ilat)     =  (  7, 318)
# max u_north    =  0.337 m/s        at  ( it, iz, ilon) =  ( 23,  39, 147)
# min u_north    = -0.374 m/s        at  ( it, iz, ilon) =  (  5,   0,  60)
# max u_south    =  0.303 m/s        at  ( it, iz, ilon) =  ( 24,   0,  73)
# min u_south    = -0.316 m/s        at  ( it, iz, ilon) =  ( 22,   0,  78)
# max u_west     =  1.293 m/s        at  ( it, iz, ilat) =  ( 15,   0, 338)
# min u_west     = -0.795 m/s        at  ( it, iz, ilat) =  ( 12,   0, 338)
# max v_north    =  0.285 m/s        at  ( it, iz, ilon) =  ( 22,   0,  23)
# min v_north    = -0.390 m/s        at  ( it, iz, ilon) =  (  3,  39, 146)
# max v_south    =  0.322 m/s        at  ( it, iz, ilon) =  ( 22,  19, 227)
# min v_south    = -0.424 m/s        at  ( it, iz, ilon) =  ( 23,  39,  35)
# max v_west     =  0.977 m/s        at  ( it, iz, ilat) =  (  5,   0, 318)
# min v_west     = -1.221 m/s        at  ( it, iz, ilat) =  (  7,   0, 318)
# max temp_north = 21.072 C          at  ( it, iz, ilon) =  (  0,  39, 131)
# min temp_north =  3.956 C          at  ( it, iz, ilon) =  (  0,   0,   1)
# max temp_south = 20.586 C          at  ( it, iz, ilon) =  (  0,  39,  74)
# min temp_south =  2.014 C          at  ( it, iz, ilon) =  (  4,   0,   0)
# max temp_west  = 20.992 C          at  ( it, iz, ilat) =  (  0,  39, 278)
# min temp_west  =  1.715 C          at  ( it, iz, ilat) =  (  3,   0,  23)
# max salt_north = 34.663 psu        at  ( it, iz, ilon) =  ( 24,   0,   2)
# min salt_north = 33.374 psu        at  ( it, iz, ilon) =  (  0,  24,  65)
# max salt_south = 34.604 psu        at  ( it, iz, ilon) =  (  4,   0,   0)
# min salt_south = 33.356 psu        at  ( it, iz, ilon) =  (  0,  24,   6)
# max salt_west  = 34.661 psu        at  ( it, iz, ilat) =  ( 20,   0, 389)
# min salt_west  = 33.325 psu        at  ( it, iz, ilat) =  (  5,  24,  59)
# return code: 0 (0=good)
# driver_run_forecast_L21:  done with writing LV2_OCN_BC.nc file.
# this took:
# 0:00:01.139173
#
#
# driver_run_forcast_LV2: making and saving LV2_OCN_IC pickle fileLV_1_OCN_IC dict loaded with pickle
# OCN_LV2_IC dict saved with pickle
# return code: 0 (0=good)
# driver_run_forecast_L21:  done with writing LV2_OCN_IC.pkl file.
# this took:
# 0:00:38.593362
#
#
# driver_run_forcast_LV2: saving LV2_OCN_IC netcdf fileOCN_IC dict loaded with pickle
#
# max and min of data in ROMS IC file (iz is bottom [0] to top [39], note: it is always 0 b/c IC):
# max zeta   =  0.631 m          at  ( it, ilat, ilon)     =  (  0, 344, 185)
# min zeta   =  0.447 m          at  ( it, ilat, ilon)     =  (  0,   0, 125)
# max ubar   =  0.180 m/s        at  ( it, ilat, ilon)     =  (  0, 336, 197)
# min ubar   = -0.130 m/s        at  ( it, ilat, ilon)     =  (  0, 106,  95)
# max vbar   =  0.169 m/s        at  ( it, ilat, ilon)     =  (  0, 334, 197)
# min vbar   = -0.226 m/s        at  ( it, ilat, ilon)     =  (  0, 373, 159)
# max u      =  0.339 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39, 344, 168)
# min u      = -0.313 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39,  74, 162)
# max v      =  0.220 m/s        at  ( it, iz, ilat, ilon) =  (  0, 20, 333, 194)
# min v      = -0.396 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39,  18,  44)
# max temp   = 22.141 C          at  ( it, iz, ilat, ilon) =  (  0, 39, 284,  95)
# min temp   =  1.757 C          at  ( it, iz, ilat, ilon) =  (  0,  0,  32,   4)
# max salt   = 34.709 psu        at  ( it, iz, ilat, ilon) =  (  0,  0, 365,  16)
# min salt   = 33.198 psu        at  ( it, iz, ilat, ilon) =  (  0, 27, 137, 110)
# return code: 0 (0=good)
# driver_run_forecast_L21:  done with writing LV2_OCN_IC.nc file.
# this took:
# 0:00:01.603913
#
#
# making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV2 simulation
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/His/LV2_ocean_his_202410110000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV2_ocean_rst_202410110000_202410120000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_OCEAN_IC.nc
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# ...done
# now running roms LV2 with bash.
# using 0 nodes.
# Ni = 3, NJ = 8
# working...
#  --- running LV2 ---
# run_slurm_LV2: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Run
# run_slurm_LV2: run command:  ['bash', 'LV2_openmp.sh']subprocess slurm ran correctly? 0 (0=yes)
# running ROMS took:
# 0:09:55.540220
#
#
# starting LV2 hindcast with subprocess...
# ...finished LV2 hindcast.
# return code: 0 (0=good)done with LV2
# LV2 hind ran correctly? 0 (0=yes)
# this took
# 0:11:38.965319
# ------------------------------------------------------------
# starting LV3
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV3 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.659793
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.061466
#
#
# driver_run_forcast_LV3: saving LV3_OCN_BC pickle fileinterpolating z with normal loops.
# OCN_LV 3 _BC dict saved with pickle to:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/BC_LV3_tmp_file.pkl
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_BC.pkl file.
# this took:
# 0:01:06.639832
#
#
# driver_run_forcast_LV3: saving LV3_OCN_BC netcdf fileOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.659 m          at  ( it, ilon)     =  ( 24,  26)
# min zeta_north = -0.752 m          at  ( it, ilon)     =  (  6, 221)
# max zeta_south =  0.642 m          at  ( it, ilon)     =  ( 24, 188)
# min zeta_south = -0.738 m          at  ( it, ilon)     =  (  6,  53)
# max zeta_west  =  0.666 m          at  ( it, ilat)     =  ( 24, 281)
# min zeta_west  = -0.733 m          at  ( it, ilat)     =  (  6,   0)
# max ubar_north =  0.098 m/s        at  ( it, ilon)     =  ( 21, 249)
# min ubar_north = -0.105 m/s        at  ( it, ilon)     =  ( 23, 239)
# max ubar_south =  0.064 m/s        at  ( it, ilon)     =  ( 17, 160)
# min ubar_south = -0.237 m/s        at  ( it, ilon)     =  (  8, 191)
# max ubar_west  =  0.072 m/s        at  ( it, ilat)     =  ( 15, 314)
# min ubar_west  = -0.079 m/s        at  ( it, ilat)     =  ( 24, 146)
# max vbar_north =  0.149 m/s        at  ( it, ilon)     =  ( 24, 233)
# min vbar_north = -0.218 m/s        at  ( it, ilon)     =  (  4, 246)
# max vbar_south =  0.192 m/s        at  ( it, ilon)     =  ( 15, 119)
# min vbar_south = -0.145 m/s        at  ( it, ilon)     =  (  3, 189)
# max vbar_west  =  0.025 m/s        at  ( it, ilat)     =  ( 12,   0)
# min vbar_west  = -0.119 m/s        at  ( it, ilat)     =  (  4, 303)
# max u_north    =  0.226 m/s        at  ( it, iz, ilon) =  ( 17,  39, 153)
# min u_north    = -0.252 m/s        at  ( it, iz, ilon) =  ( 24,   0, 219)
# max u_south    =  0.482 m/s        at  ( it, iz, ilon) =  ( 10,   0, 107)
# min u_south    = -0.824 m/s        at  ( it, iz, ilon) =  (  7,   0, 111)
# max u_west     =  0.281 m/s        at  ( it, iz, ilat) =  ( 15,   0, 117)
# min u_west     = -0.547 m/s        at  ( it, iz, ilat) =  (  8,  38,  65)
# max v_north    =  0.251 m/s        at  ( it, iz, ilon) =  ( 22,   0, 221)
# min v_north    = -0.353 m/s        at  ( it, iz, ilon) =  (  7,  39, 170)
# max v_south    =  0.320 m/s        at  ( it, iz, ilon) =  ( 23,   8, 116)
# min v_south    = -0.412 m/s        at  ( it, iz, ilon) =  ( 13,   0, 133)
# max v_west     =  0.429 m/s        at  ( it, iz, ilat) =  ( 20,   0, 310)
# min v_west     = -0.371 m/s        at  ( it, iz, ilat) =  (  3,  39, 282)
# max temp_north = 21.029 C          at  ( it, iz, ilon) =  (  0,  39,   0)
# min temp_north =  4.589 C          at  ( it, iz, ilon) =  ( 14,   0,   4)
# max temp_south = 19.124 C          at  ( it, iz, ilon) =  (  0,  39,  32)
# min temp_south =  2.613 C          at  ( it, iz, ilon) =  (  0,   0,  97)
# max temp_west  = 21.334 C          at  ( it, iz, ilat) =  (  0,  39, 296)
# min temp_west  =  3.156 C          at  ( it, iz, ilat) =  ( 15,   0,  97)
# max salt_north = 34.539 psu        at  ( it, iz, ilon) =  (  1,   0, 101)
# min salt_north = 33.263 psu        at  ( it, iz, ilon) =  (  0,  24, 122)
# max salt_south = 34.590 psu        at  ( it, iz, ilon) =  (  0,   0,  96)
# min salt_south = 33.438 psu        at  ( it, iz, ilon) =  ( 24,  24,   0)
# max salt_west  = 34.661 psu        at  ( it, iz, ilat) =  ( 17,   0, 341)
# min salt_west  = 33.242 psu        at  ( it, iz, ilat) =  (  1,  25, 161)
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_BC.nc file.
# this took:
# 0:00:01.133972
#
#
# driver_run_forcast_LV3: making and saving LV3_OCN_IC pickle fileLV_2_OCN_IC dict loaded with pickle
# OCN_LV3_IC dict saved with pickle
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_IC.pkl file.
# this took:
# 0:00:38.694480
#
#
# driver_run_forcast_LV3: saving LV3_OCN_IC netcdf fileOCN_IC dict loaded with pickle
#
# max and min of data in ROMS IC file (iz is bottom [0] to top [39], note: it is always 0 b/c IC):
# max zeta   =  0.539 m          at  ( it, ilat, ilon)     =  (  0, 458,   0)
# min zeta   =  0.477 m          at  ( it, ilat, ilon)     =  (  0,   0, 185)
# max ubar   =  0.052 m/s        at  ( it, ilat, ilon)     =  (  0, 396,   0)
# min ubar   = -0.124 m/s        at  ( it, ilat, ilon)     =  (  0,  48, 123)
# max vbar   =  0.060 m/s        at  ( it, ilat, ilon)     =  (  0,   0, 116)
# min vbar   = -0.181 m/s        at  ( it, ilat, ilon)     =  (  0,  78, 128)
# max u      =  0.154 m/s        at  ( it, iz, ilat, ilon) =  (  0, 11, 395,   0)
# min u      = -0.266 m/s        at  ( it, iz, ilat, ilon) =  (  0, 39,  62,   0)
# max v      =  0.197 m/s        at  ( it, iz, ilat, ilon) =  (  0,  0, 156, 113)
# min v      = -0.384 m/s        at  ( it, iz, ilat, ilon) =  (  0,  0, 147, 131)
# max temp   = 21.334 C          at  ( it, iz, ilat, ilon) =  (  0, 39, 296,   0)
# min temp   =  1.837 C          at  ( it, iz, ilat, ilon) =  (  0,  0,  88, 111)
# max salt   = 34.704 psu        at  ( it, iz, ilat, ilon) =  (  0,  0, 317, 211)
# min salt   = 33.240 psu        at  ( it, iz, ilat, ilon) =  (  0, 26, 161,   5)
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_IC.nc file.
# this took:
# 0:00:01.679532
#
#
# making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV3 simulation
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/His/LV3_ocean_his_202410110000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV3_ocean_rst_202410110000_202410120000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_OCEAN_IC.nc
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# ...done
# now running roms LV3 with bash.
# using 1 nodes.
# Ni = 4, NJ = 12
# working...
#  --- running LV3 ---
# run_slurm_LV3: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Run
# run_slurm_LV3: run command:  ['bash', 'LV3_openmp.sh']subprocess slurm ran correctly? 0 (0=yes)
# running ROMS took:
# 0:13:28.047947
#
#
# starting LV3 hindcast with subprocess...
# ...finished LV3 hindcast.
# return code: 0 (0=good)done with LV3
# LV3 hind ran correctly? 0 (0=yes)
# this took
# 0:15:20.710972
# ------------------------------------------------------------
# done with the 2024101100 to 2024101200 sub simulation
# this took
# 0:33:05.507287
# ============================================================
# PFM info was edited and resaved
# done with a 1 day LV1 hindcast, going to the next day.
#
# PFM info was edited and resaved
# the model_info dictionary was resaved to /home/vboatwright/boat_roms/PFM_dir/simulations/phm_modinfo_testing.pkl
# with properly time stamped output file names
#
#
# ============================================================
# doing a sub simulation from 2024101200 to 2024101300
# ------------------------------------------------------------
# starting LV1
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...getting the hycom data for this simulation...we need  61  hycom nc files...
# the  61  nc files already exist, no need to download.
# ...done
# making the hycom pickle file from all hycom.nc files ...
# max and min raw hycom data (iz is top [0] to bottom [39]):
# max zeta   =  1.029 m          at  ( it, ilat, ilon)     =  ( 24,  68,  94)
# min zeta   = -1.015 m          at  ( it, ilat, ilon)     =  (  8, 203,   0)
# max u      =  0.635 m/s        at  ( it, iz, ilat, ilon) =  (  3,  8,  74,  53)
# min u      = -0.522 m/s        at  ( it, iz, ilat, ilon) =  (  4,  3,  42,  76)
# max v      =  0.553 m/s        at  ( it, iz, ilat, ilon) =  (  3,  1,   7,  94)
# min v      = -0.711 m/s        at  ( it, iz, ilat, ilon) =  (  7,  0, 146,   6)
# max temp   = 22.837 C          at  ( it, iz, ilat, ilon) =  (  0,  0,   0,  98)
# min temp   =  1.369 C          at  ( it, iz, ilat, ilon) =  (  3, 38, 170,   4)
# max dT/dz  =  1.162 C/m        at  ( it, iz, ilat, ilon) =  (  0,  0,  60,  97)
# min dT/dz  = -0.098 C/m        at  ( it, iz, ilat, ilon) =  (  8, 13, 121,  56)
# max salt   = 34.733 psu        at  ( it, iz, ilat, ilon) =  (  4, 38,  27,  30)
# min salt   = 32.509 psu        at  ( it, iz, ilat, ilon) =  (  4,  4, 177,   5)
# max dS/dz  =  0.045 psu/m      at  ( it, iz, ilat, ilon) =  (  6,  5, 100,  75)
# min dS/dz  = -0.040 psu/m      at  ( it, iz, ilat, ilon) =  (  6,  9, 155,   8)
#
# going to save a hycom pickle file to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# Hycom OCN dict saved with pickle.
# did subprocess run correctly? 0 (0=yes,1=no)
# ...done.
# this took:
# 0:00:02.557348
#
#
# starting: ocnfuns.hycom_to_roms_latlon(OCN,RMG)
# putting the hycom data in /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl on the roms grid.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_depth.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_rho.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_u.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lat_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_lon_v.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ocean_time.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_zeta_time.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ocean_time_ref.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_zeta.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_salt.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_temp.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_ubar.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_urm.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vbar.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vrm.pkl' was deleted.
# making a new one.../home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/hycom_tmp_pckl_file.pkl
# An old '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/tmp_vinfo.pkl' was deleted.
# making a new one...
# ...done.
# all 18 ocnR pickle files were made correctlysubprocess return code? 0 (0=good)
# max and min of hycom data on ROMS grid (iz is top [0] to bottom [39]):
# max zeta   =  1.014 m          at  ( it, ilat, ilon)     =  ( 24,  52, 245)
# min zeta   = -0.963 m          at  ( it, ilat, ilon)     =  (  7, 335, 135)
# max urm    =  0.639 m/s        at  ( it, iz, ilat, ilon) =  (  3,  8, 132, 100)
# min urm    = -0.601 m/s        at  ( it, iz, ilat, ilon) =  (  4,  0,  25, 151)
# max vrm    =  0.544 m/s        at  ( it, iz, ilat, ilon) =  (  6,  6,  43, 125)
# min vrm    = -0.796 m/s        at  ( it, iz, ilat, ilon) =  (  7,  0, 355,   4)
# max temp   = 22.096 C          at  ( it, iz, ilat, ilon) =  (  8,  0,   0,   0)
# min temp   =  1.404 C          at  ( it, iz, ilat, ilon) =  (  5, 38, 214,  10)
# max dT/dz  =  1.191 C/m        at  ( it, iz, ilat, ilon) =  (  4,  2, 148, 242)
# min dT/dz  = -0.419 C/m        at  ( it, iz, ilat, ilon) =  (  7,  4, 189, 243)
# max salt   = 34.726 psu        at  ( it, iz, ilat, ilon) =  (  4, 38, 272,  29)
# min salt   = 32.615 psu        at  ( it, iz, ilat, ilon) =  (  4,  6, 389,  14)
# max dS/dz  =  0.045 psu/m      at  ( it, iz, ilat, ilon) =  (  6,  5, 151, 205)
# min dS/dz  = -0.038 psu/m      at  ( it, iz, ilat, ilon) =  (  6,  9, 370,  18)
# driver_run_forecast_LV1: done with hycom_to_roms_latlon
# ...done with LV1 ocn_R
# this took:
# 0:00:50.689191
#
#
# making the depth pickle file...depth pickle file /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/roms_tmp_depth_file.pklalready exists.
# subprocess return code? 0 (0=good)
#
#
# in run_hind_LV1: what is the use_restart setting?
# 1
# going to use a restart file for the LV1 IC. Setting this up...going to restart LV1 from
# 2024-10-12 00:00:00
# ['/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410120000_202410130000.nc', '/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410110000_202410120000.nc']
# found the time index!
# going to restart using /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410110000_202410120000.nc and python-index 3
# PFM info was edited and resaved
# ...done setting up for restart.
# this took:
# 0:00:00.928812
#
# Going to use the file LV1_ocean_rst_202410110000_202410120000.nc to restart the simulation
# with time index 4
#
#
# going to save OCN_BC to a pickle file to:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnBC_tmp_pckl_file.pklPrevious file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/ocnBC_tmp_pckl_file.pkl' has been deleted successfully.
# loading /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/roms_tmp_depth_file.pkl
# OCN_BC dict saved with pickle
# OCN BC data saved with pickle, correctly? 0 (0=yes)
# this took:
# 0:00:03.691998
#
#
# making BC nc file from pickled BC: /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_OCEAN_BC.ncOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.658 m          at  ( it, ilon)     =  (  0,   0)
# min zeta_north = -0.931 m          at  ( it, ilon)     =  (  8,  95)
# max zeta_south =  0.839 m          at  ( it, ilon)     =  ( 24,  55)
# min zeta_south = -0.834 m          at  ( it, ilon)     =  (  7, 158)
# max zeta_west  =  0.789 m          at  ( it, ilat)     =  ( 24,  53)
# min zeta_west  = -0.806 m          at  ( it, ilat)     =  (  7, 223)
# max ubar_north =  0.017 m/s        at  ( it, ilon)     =  (  2, 108)
# min ubar_north = -0.059 m/s        at  ( it, ilon)     =  (  4, 127)
# max ubar_south =  0.035 m/s        at  ( it, ilon)     =  (  5, 214)
# min ubar_south = -0.080 m/s        at  ( it, ilon)     =  (  0, 240)
# max ubar_west  =  0.029 m/s        at  ( it, ilat)     =  (  7, 131)
# min ubar_west  = -0.038 m/s        at  ( it, ilat)     =  (  1,   5)
# max vbar_north =  0.148 m/s        at  ( it, ilon)     =  (  0, 120)
# min vbar_north = -0.057 m/s        at  ( it, ilon)     =  (  2,   6)
# max vbar_south =  0.193 m/s        at  ( it, ilon)     =  (  7, 236)
# min vbar_south = -0.061 m/s        at  ( it, ilon)     =  (  2, 135)
# max vbar_west  =  0.035 m/s        at  ( it, ilat)     =  (  8,   9)
# min vbar_west  = -0.060 m/s        at  ( it, ilat)     =  (  2, 366)
# max u_north    =  0.153 m/s        at  ( it, iz, ilon) =  (  0,  32,  99)
# min u_north    = -0.315 m/s        at  ( it, iz, ilon) =  (  6,  37,  34)
# max u_south    =  0.274 m/s        at  ( it, iz, ilon) =  (  0,  33, 102)
# min u_south    = -0.434 m/s        at  ( it, iz, ilon) =  (  4,  39, 158)
# max u_west     =  0.353 m/s        at  ( it, iz, ilat) =  (  3,  34, 133)
# min u_west     = -0.506 m/s        at  ( it, iz, ilat) =  (  3,  38, 293)
# max v_north    =  0.328 m/s        at  ( it, iz, ilon) =  (  5,  25, 119)
# min v_north    = -0.549 m/s        at  ( it, iz, ilon) =  (  5,  39,   0)
# max v_south    =  0.461 m/s        at  ( it, iz, ilon) =  (  0,  35, 199)
# min v_south    = -0.413 m/s        at  ( it, iz, ilon) =  (  8,  39, 129)
# max v_west     =  0.240 m/s        at  ( it, iz, ilat) =  (  5,  34,   5)
# min v_west     = -0.750 m/s        at  ( it, iz, ilat) =  (  6,  39, 366)
# max temp_north = 17.863 C          at  ( it, iz, ilon) =  (  8,  39,   0)
# min temp_north =  1.082 C          at  ( it, iz, ilon) =  (  6,   0,   4)
# max temp_south = 22.096 C          at  ( it, iz, ilon) =  (  8,  39,   0)
# min temp_south =  1.124 C          at  ( it, iz, ilon) =  (  7,   0,   0)
# max temp_west  = 22.096 C          at  ( it, iz, ilat) =  (  8,  39,   0)
# min temp_west  =  1.072 C          at  ( it, iz, ilat) =  (  3,   0, 230)
# max salt_north = 34.708 psu        at  ( it, iz, ilon) =  (  0,   0,  22)
# min salt_north = 32.616 psu        at  ( it, iz, ilon) =  (  4,  34,  14)
# max salt_south = 34.708 psu        at  ( it, iz, ilon) =  (  2,   0,   0)
# min salt_south = 33.403 psu        at  ( it, iz, ilon) =  (  4,  25, 226)
# max salt_west  = 34.710 psu        at  ( it, iz, ilat) =  (  2,   0,  65)
# min salt_west  = 32.662 psu        at  ( it, iz, ilat) =  (  4,  29, 385)
# OCN BC nc data saved, correctly? 0 (0=yes)
# done makeing BC nc file.
# this took:
# 0:00:01.058566
#
#
# we are now getting the atm data...the  9  grb2 files already exist, no need to download.return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.100828
#
#
# we are now converting the atm grb2 files to pickles...ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0000_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0000_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0600_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_0600_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_1200_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_1200_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_1800_000.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241012_1800_003.grb2 saved to pickle.
# ATM grb2 file /home/vboatwright/boat_roms/PFM_dir/model_forcing/nam_grb2/nam_218_20241013_0000_000.grb2 saved to pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:02.168074
#
#
# we are now putting the hind atm data on the roms LV1 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.547816
#
#
# we are now saving ATM LV1 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/Forc/LV1_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.063759
#
#
# does it know server?
# rockfish
# driver_run_forecast_LV1: making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV1 simulation
# the grid file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/grids/GRID_SDTJRE_LV1_rx020_hmask.nc
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/His/LV1_ocean_his_202410120000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410120000_202410130000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV1_ocean_rst_202410110000_202410120000.nc
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# this is the blank_infile
# ./LV1_BLANK.in
# ...done
# now running roms LV1 with bash.
# using 0 nodes.
# Ni = 3, NJ = 8
# run_slurm_LV1: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV1/RunCompletedProcess(args=['bash', 'LV1_openmp.sh'], returncode=0, stdout=b'/home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin\n', stderr=b'')
# subprocess slurm ran correctly? 0 (0=yes)
# run_slurm_LV1: run command:  ['bash', 'LV1_openmp.sh']
# ...done.
# this took:
# 0:04:28.407824
#
#
# starting LV1 hindcast with subprocess...
# ...finished LV1 hindcast.
# return code: 0 (0=good)done with LV1
# LV1 hind ran correctly? 0 (0=yes)
# this took
# 0:05:36.002453
# ------------------------------------------------------------
# starting LV2
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV2 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.557075
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# ...
# subprocess slurm ran correctly? 1 (0=yes)
# run_slurm_LV1: run command:  ['bash', 'LV1_openmp.sh']
# ...done.
# this took:
# 0:00:01.527364
#
# starting LV1 hindcast with subprocess...
# ...finished LV1 hindcast.
# return code: 0 (0=good)
# done with LV1
# LV1 hind ran correctly? 0 (0=yes)
# this took
# 0:02:10.856376
# ------------------------------------------------------------
# starting LV2
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV2 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.616529
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Forc/LV2_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.055377
#
#
# driver_run_forcast_LV2: saving LV2_OCN_BC pickle file
# Traceback (most recent call last):
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/ocn_functions.py", line 9215, in <module>
#     globals()[args[1]](*args[2:])
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/ocn_functions.py", line 6709, in mk_LV2_BC_dict_edges
#     his_ds = nc.Dataset(fn)
#              ^^^^^^^^^^^^^^
#   File "src/netCDF4/_netCDF4.pyx", line 2521, in netCDF4._netCDF4.Dataset.__init__
#   File "src/netCDF4/_netCDF4.pyx", line 2158, in netCDF4._netCDF4._ensure_nc_success
# FileNotFoundError: [Errno 2] No such file or directory: '/home/vboatwright/boat_roms/PFM_dir/simulations/LV1/His/LV1_ocean_his_202410220000.nc'
# return code: 1 (0=good)
# driver_run_forecast_LV2:  done with writing LV2_OCN_BC.pkl file.
# this took:
# 0:00:01.026383
#
#
# driver_run_forcast_LV2: saving LV2_OCN_BC netcdf fileOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.689 m          at  ( it, ilon)     =  (  0,  59)
# min zeta_north = -0.921 m          at  ( it, ilon)     =  (  7, 155)
# max zeta_south =  0.685 m          at  ( it, ilon)     =  ( 24, 245)
# min zeta_south = -0.870 m          at  ( it, ilon)     =  (  7, 134)
# max zeta_west  =  0.689 m          at  ( it, ilat)     =  ( 24,  80)
# min zeta_west  = -0.878 m          at  ( it, ilat)     =  (  7, 397)
# max ubar_north =  0.100 m/s        at  ( it, ilon)     =  ( 20,  44)
# min ubar_north = -0.061 m/s        at  ( it, ilon)     =  ( 13,  29)
# max ubar_south =  0.061 m/s        at  ( it, ilon)     =  (  0, 244)
# min ubar_south = -0.132 m/s        at  ( it, ilon)     =  (  8, 254)
# max ubar_west  =  0.171 m/s        at  ( it, ilat)     =  (  2, 338)
# min ubar_west  = -0.251 m/s        at  ( it, ilat)     =  (  5, 338)
# max vbar_north =  0.132 m/s        at  ( it, ilon)     =  ( 16,  26)
# min vbar_north = -0.176 m/s        at  ( it, ilon)     =  (  6, 147)
# max vbar_south =  0.197 m/s        at  ( it, ilon)     =  ( 23, 236)
# min vbar_south = -0.162 m/s        at  ( it, ilon)     =  (  3, 251)
# max vbar_west  =  0.205 m/s        at  ( it, ilat)     =  ( 24, 331)
# min vbar_west  = -0.042 m/s        at  ( it, ilat)     =  (  6, 186)
# max u_north    =  0.317 m/s        at  ( it, iz, ilon) =  (  0,  39, 150)
# min u_north    = -0.203 m/s        at  ( it, iz, ilon) =  ( 21,   0,  27)
# max u_south    =  0.325 m/s        at  ( it, iz, ilon) =  (  1,   0,  73)
# min u_south    = -0.370 m/s        at  ( it, iz, ilon) =  (  6,  39, 231)
# max u_west     =  0.840 m/s        at  ( it, iz, ilat) =  (  1,   0, 338)
# min u_west     = -1.485 m/s        at  ( it, iz, ilat) =  (  5,   0, 338)
# max v_north    =  0.395 m/s        at  ( it, iz, ilon) =  ( 12,   0,  23)
# min v_north    = -0.372 m/s        at  ( it, iz, ilon) =  (  3,  39, 152)
# max v_south    =  0.344 m/s        at  ( it, iz, ilon) =  ( 12,  38, 233)
# min v_south    = -0.461 m/s        at  ( it, iz, ilon) =  (  2,  39,  47)
# max v_west     =  0.632 m/s        at  ( it, iz, ilat) =  ( 17,   0, 318)
# min v_west     = -0.409 m/s        at  ( it, iz, ilat) =  ( 20,   0, 317)
# max temp_north = 20.127 C          at  ( it, iz, ilon) =  (  0,  39, 140)
# min temp_north =  3.973 C          at  ( it, iz, ilon) =  (  0,   2,   2)
# max temp_south = 20.443 C          at  ( it, iz, ilon) =  (  0,  38,  65)
# min temp_south =  2.174 C          at  ( it, iz, ilon) =  (  7,   0,   0)
# max temp_west  = 20.268 C          at  ( it, iz, ilat) =  (  0,  38, 281)
# min temp_west  =  1.846 C          at  ( it, iz, ilat) =  ( 19,   0,  24)
# max salt_north = 34.663 psu        at  ( it, iz, ilon) =  (  2,   0,   2)
# min salt_north = 33.381 psu        at  ( it, iz, ilon) =  (  8,  25,  71)
# max salt_south = 34.603 psu        at  ( it, iz, ilon) =  (  7,   0,   0)
# min salt_south = 33.366 psu        at  ( it, iz, ilon) =  (  3,  23,  11)
# max salt_west  = 34.661 psu        at  ( it, iz, ilat) =  ( 23,   0, 392)
# min salt_west  = 33.331 psu        at  ( it, iz, ilat) =  (  0,  24,  65)
# return code: 0 (0=good)
# driver_run_forecast_L21:  done with writing LV2_OCN_BC.nc file.
# this took:
# 0:00:01.148661
#
#
# going to use a restart file for the LV2 IC. Setting this up...going to restart LV2 from
# 2024-10-22 00:00:00
# ['/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV2_ocean_rst_202410110000_202410120000.nc', '/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV2_ocean_rst_202410120000_202410130000.nc']
# WARNIG the time stamp wasnt found in any restart file. CANT USE RESTART
# going to restart using none and python-index -99
# PFM info was edited and resaved
# ...done setting up for restart.
# this took:
# 0:00:00.948604
#
# Going to use the file none to restart the simulation
# with time index -98
#
#
# WARNING RESTARTING LV2 WILL NOT WORK!!!
# making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV2 simulation
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/His/LV2_ocean_his_202410220000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV2_ocean_rst_202410220000_202410230000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/none
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# ...done
# now running roms LV2 with bash.
# using 0 nodes.
# Ni = 3, NJ = 8
# working...
#  --- running LV2 ---
# run_slurm_LV2: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV2/Run
# run_slurm_LV2: run command:  ['bash', 'LV2_openmp.sh']subprocess slurm ran correctly? 1 (0=yes)
# running ROMS took:
# 0:00:00.459692
#
#
# starting LV2 hindcast with subprocess...
# ...finished LV2 hindcast.
# return code: 0 (0=good)done with LV2
# LV2 hind ran correctly? 0 (0=yes)
# this took
# 0:00:08.147194
# ------------------------------------------------------------
# starting LV3
# where are we in driver_run_hindLV123 to process cmd_list?
# /home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver
# changing to driver dir to run hind_simulation...we are now putting the hind atm data on the roms LV3 grid...the nam atm pickle files exist, will load and interpolate onto the roms grid...
#
# ATM on roms grid dict saved with pickle.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.649689
#
#
# we are now saving ATM LV2 to /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_ATM_FORCING.nc ...Previous file '/home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Forc/LV3_ATM_FORCING.nc' has been deleted successfully.
# return code: 0 (0=good)
# ...done.
# this took:
# 0:00:01.054472
#
#
# driver_run_forcast_LV3: saving LV3_OCN_BC pickle file
# Traceback (most recent call last):
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/ocn_functions.py", line 9215, in <module>
#     globals()[args[1]](*args[2:])
#   File "/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/ocn_functions.py", line 6709, in mk_LV2_BC_dict_edges
#     his_ds = nc.Dataset(fn)
#              ^^^^^^^^^^^^^^
#   File "src/netCDF4/_netCDF4.pyx", line 2521, in netCDF4._netCDF4.Dataset.__init__
#   File "src/netCDF4/_netCDF4.pyx", line 2158, in netCDF4._netCDF4._ensure_nc_success
# FileNotFoundError: [Errno 2] No such file or directory: '/home/vboatwright/boat_roms/PFM_dir/simulations/LV2/His/LV2_ocean_his_202410220000.nc'
# return code: 1 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_BC.pkl file.
# this took:
# 0:00:00.995866
#
#
# driver_run_forcast_LV3: saving LV3_OCN_BC netcdf fileOCN_BC dict loaded with pickle
#
# max and min of data in ROMS BC file (iz is bottom [0] to top [39]):
# max zeta_north =  0.689 m          at  ( it, ilon)     =  ( 24, 240)
# min zeta_north = -0.833 m          at  ( it, ilon)     =  (  7, 221)
# max zeta_south =  0.686 m          at  ( it, ilon)     =  ( 24, 185)
# min zeta_south = -0.826 m          at  ( it, ilon)     =  (  7,  50)
# max zeta_west  =  0.684 m          at  ( it, ilat)     =  ( 24, 389)
# min zeta_west  = -0.825 m          at  ( it, ilat)     =  (  7,   0)
# max ubar_north =  0.101 m/s        at  ( it, ilon)     =  ( 17, 249)
# min ubar_north = -0.126 m/s        at  ( it, ilon)     =  ( 14, 239)
# max ubar_south =  0.080 m/s        at  ( it, ilon)     =  ( 20, 191)
# min ubar_south = -0.179 m/s        at  ( it, ilon)     =  (  6, 191)
# max ubar_west  =  0.065 m/s        at  ( it, ilat)     =  (  4, 404)
# min ubar_west  = -0.079 m/s        at  ( it, ilat)     =  ( 16, 145)
# max vbar_north =  0.312 m/s        at  ( it, ilon)     =  ( 11, 233)
# min vbar_north = -0.202 m/s        at  ( it, ilon)     =  (  3, 247)
# max vbar_south =  0.261 m/s        at  ( it, ilon)     =  ( 15, 119)
# min vbar_south = -0.102 m/s        at  ( it, ilon)     =  (  6, 101)
# max vbar_west  =  0.023 m/s        at  ( it, ilat)     =  ( 24,   0)
# min vbar_west  = -0.139 m/s        at  ( it, ilat)     =  (  6, 303)
# max u_north    =  0.223 m/s        at  ( it, iz, ilon) =  ( 17,  39, 126)
# min u_north    = -0.379 m/s        at  ( it, iz, ilon) =  (  7,   0, 219)
# max u_south    =  0.294 m/s        at  ( it, iz, ilon) =  (  8,   0, 132)
# min u_south    = -0.275 m/s        at  ( it, iz, ilon) =  (  6,  39, 117)
# max u_west     =  0.287 m/s        at  ( it, iz, ilat) =  ( 15,   0, 117)
# min u_west     = -0.388 m/s        at  ( it, iz, ilat) =  (  8,  38,  56)
# max v_north    =  0.452 m/s        at  ( it, iz, ilon) =  (  6,   0, 221)
# min v_north    = -0.301 m/s        at  ( it, iz, ilon) =  (  3,  39, 185)
# max v_south    =  0.369 m/s        at  ( it, iz, ilon) =  ( 15,  10, 116)
# min v_south    = -0.410 m/s        at  ( it, iz, ilon) =  (  4,   0, 133)
# max v_west     =  0.362 m/s        at  ( it, iz, ilat) =  (  3,   0, 309)
# min v_west     = -0.373 m/s        at  ( it, iz, ilat) =  (  1,  39, 261)
# max temp_north = 20.421 C          at  ( it, iz, ilon) =  ( 23,  39,   0)
# min temp_north =  4.602 C          at  ( it, iz, ilon) =  ( 18,   0,   4)
# max temp_south = 18.837 C          at  ( it, iz, ilon) =  (  0,  39,   5)
# min temp_south =  3.154 C          at  ( it, iz, ilon) =  ( 20,   0,   0)
# max temp_west  = 20.450 C          at  ( it, iz, ilat) =  (  0,  39, 263)
# min temp_west  =  3.017 C          at  ( it, iz, ilat) =  ( 24,   0,  16)
# max salt_north = 34.534 psu        at  ( it, iz, ilon) =  (  0,   0,  83)
# min salt_north = 33.271 psu        at  ( it, iz, ilon) =  (  0,  23, 122)
# max salt_south = 34.558 psu        at  ( it, iz, ilon) =  ( 19,   0,   0)
# min salt_south = 33.425 psu        at  ( it, iz, ilon) =  ( 20,  26,  59)
# max salt_west  = 34.631 psu        at  ( it, iz, ilat) =  ( 23,   0, 344)
# min salt_west  = 33.252 psu        at  ( it, iz, ilat) =  (  1,  26, 120)
# return code: 0 (0=good)
# driver_run_forecast_LV3:  done with writing LV3_OCN_BC.nc file.
# this took:
# 0:00:01.111730
#
#
# going to use a restart file for the LV3 IC. Setting this up...going to restart LV3 from
# 2024-10-22 00:00:00
# ['/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV3_ocean_rst_202410120000_202410130000.nc', '/home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV3_ocean_rst_202410110000_202410120000.nc']
# WARNIG the time stamp wasnt found in any restart file. CANT USE RESTART
# going to restart using none and python-index -99
# PFM info was edited and resaved
# ...done setting up for restart.
# this took:
# 0:00:00.926079
#
# Going to use the file none to restart the simulation
# with time index -98
#
#
# WARNING RESTARTING LV2 WILL NOT WORK!!!
# making .in and .sh...
#  --- making dot_in and dot_sh ---
# for this LV3 simulation
# history file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/His/LV3_ocean_his_202410220000.nc
# restart file made will be:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/LV3_ocean_rst_202410220000_202410230000.nc
# the ini file used is:
# /home/vboatwright/boat_roms/PFM_dir/simulations/restart_data/none
# we are using
# /home/vboatwright/boat_roms/PFM_dir/simulations/executables/ROMS_realistic.bin
# ...done
# now running roms LV3 with bash.
# using 1 nodes.
# Ni = 4, NJ = 12
# working...
#  --- running LV3 ---
# run_slurm_LV3: current directory is now:  /home/vboatwright/boat_roms/PFM_dir/simulations/LV3/Run
# run_slurm_LV3: run command:  ['bash', 'LV3_openmp.sh']subprocess slurm ran correctly? 1 (0=yes)
# running ROMS took:
# 0:00:01.061658
#
# starting LV3 hindcast with subprocess...
# ...finished LV3 hindcast.
# return code: 0 (0=good)
# done with LV3
# LV3 hind ran correctly? 0 (0=yes)
# this took
# 0:00:08.795791
# ------------------------------------------------------------
# done with the 2024102200 to 2024102300 sub simulation
# this took
# 0:02:27.799524
# ============================================================
# PFM info was edited and resaved
# done with a 1 day LV1 hindcast, going to the next day.
#
#
#
# ============================================================
# done with full simulation. this took
# 1:22:51.503289
# each sub simulation took:
# [datetime.timedelta(seconds=1985, microseconds=507287), datetime.timedelta(seconds=1872, microseconds=301391), datetime.timedelta(seconds=94, microseconds=31913), datetime.timedelta(seconds=109, microseconds=502059), datetime.timedelta(seconds=95, microseconds=916385), datetime.timedelta(seconds=114, microseconds=434615), datetime.timedelta(seconds=95, microseconds=157898), datetime.timedelta(seconds=113, microseconds=662319), datetime.timedelta(seconds=133, microseconds=729620), datetime.timedelta(seconds=98, microseconds=153714), datetime.timedelta(seconds=111, microseconds=189922), datetime.timedelta(seconds=147, microseconds=799524)]

# %%
driver_path = '/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/driver/'
pyutil_path = '/home/vboatwright/boat_roms/PFM_dir/PFM_for_rockfish/sdpm_py_util/'
simulation_path = '/home/vboatwright/boat_roms/PFM_dir/simulations/'

sys.path.append(driver_path)

# driver_run_hind_LV123 is a function now
from driver_run_hind_LV123 import driver_run_hind_LV123

input_py_full = pyutil_path+'phm_model_info_devel.py'
modinfo_pkl_full = simulation_path+'phm_modinfo_testing.pkl'

driver_run_hind_LV123( input_py_full, modinfo_pkl_full )

# %%
b = [[0] * 4 for i in range(3)]
b[0][0] = datetime.now()
print(b)

# %%
initfuns.initialize_model(input_py_full,modinfo_pkl_full)

# %%
import glob
PFM = get_PFM_info()
txt0 = PFM['restart_files_dir'] + '/LV1*.nc'
print(txt0)
rst_files = glob.glob(PFM['restart_files_dir'] + '/LV1*.nc')
print(rst_files)

# %%
pltfuns.make_all_his_figures('LV1')

# %%
a = [1,2,3,4,5,6]
b = [0,0,1,1,0,1]

c = [a[i] for i in range(len(a)) if b[i] == 1]

print(c)

# %%
# first step is to get the filename lists,
# l1 is the files to get
# l2 is the names that will be saved
# l3 is the commands to get all l1 and save as l2
# l4 is the pickle file names that we will save

# get the lists
t1str = '2024101100'
t2str = '2024101200'
l1,l2,l3,l4 = hindfuns.get_nam_hindcast_filelists(t1str,t2str)
print(len(l1))
print(l1[0])
print(l2[0])
print(l3[0])
print(l4[0])

l5 = hindfuns.list_to_dict_of_chunks(l3, chunk_size=5)
print(l5)
print(len(l5))
print(l5[2])
print(l5.values())

# %%
_ = hindfuns.get_nam_hindcast_grb2s_v2(t1str,t2str)

# %%
ret = ocnfuns.get_hycom_hind_data(t1str)
print(sum(ret))

# %%
i_nam = np.arange(5)
j_nam = np.arange(10)
I,J = np.meshgrid(i_nam,j_nam)
print(I)
print(J)
nj,ni = np.shape(I)
print(nj)
print(ni)

# %%
#fn_in = '/scratch/PHM_Simulations/grb2_data/nam_218_20241201_0000_000.grb2' # l2
#fn_out = '/scratch/PHM_Simulations/grb2_data/nam_218_20241201_0000_000.pckl' # l4

for j in np.arange(len(l2)):
    fn_in = l2[j]
    fn_out = l4[j]
    hindfuns.grb2_to_pickle(fn_in,fn_out)

# %%
# nam pickle to nam on roms pickle...
fest = hindfuns.nam_pkls_2_romsatm_pkl(t1str,t2str,'1')

# %%
cmd_list = ['python','-W','ignore','atm_functions.py','atm_roms_dict_to_netcdf',str(1)]
os.chdir('../sdpm_py_util')
ret5 = subprocess.run(cmd_list)   
os.chdir('../driver')

# %%
fname_out = '/scratch/PHM_Simulations/LV1_Forecast/Forc/atm_tmp_LV1_pckl_file.pkl'
atm = hindfuns.load_pickle_file(fname_out)
print(atm['rain'][:,0,0])
#print(np.shape(atm['rain']))
#print(atm['ocean_time'])
vars = ['rain','Tair','Qair','Pair','Uwind','Vwind','lwrad','lwrad_down','swrad']
print(atm['ocean_time'][0])
print(np.shape(atm['ocean_time']))

for var in vars:
    fig, ax = plt.subplots()
    p1 = ax.contourf(atm['lon'],atm['lat'],atm[var][0,:,:],levels=20)
    fig.colorbar(p1,ax=ax)
    plt.title(var)

# %%
fname_out = '/scratch/PFM_Simulations/LV1_Forecast/Forc/atm_tmp_LV1_pckl_file.pkl'
atm = hindfuns.load_pickle_file(fname_out)
#print(np.shape(atm['rain']))
#print(atm['ocean_time'])
vars = ['rain','Tair','Qair','Pair','Uwind','Vwind','lwrad','lwrad_down','swrad']
print(atm['ocean_time'][0])
print(np.shape(atm['ocean_time']))
for var in vars:
    fig, ax = plt.subplots()
    p1 = ax.contourf(atm['lon'],atm['lat'],atm[var][0,:,:],levels=20)
    fig.colorbar(p1,ax=ax)
    plt.title(var)

# %%
grbs = pygrib.open(data)
print(grbs.keys())  # Print available keys/fields

# %%
fn = "/scratch/PHM_Simulations/grb2_data/nam_218_20241201_0000_000.grb2"
ds = xr.open_dataset(fn, engine='cfgrib',filter_by_keys={'stepType': 'instant', 'typeOfLevel': 'surface'})

# %%
# this uses grib2io. This was really slow because in this method I need to 
# download the .grb2 files first. Will try xarray and cfgrib.

# %%
grb2_out = "/scratch/PHM_Simulations/grb2_data/nam_218_20241201_0600_003.grb2"


ds = xr.open_dataset(grb2_out, engine='cfgrib',filter_by_keys={'stepType': 'instant', 'typeOfLevel': 'surface'})
#ds = cfgrib.open_file(grb2_out)
#ds = grib2io.open(grb2_out)

print(ds)
lon = ds.variables['longitude'].data[:]
lat = ds.variables['latitude'].data[:]
time = ds.variables['time']
dt = ds.variables['step']
print(np.shape(lon))
print(time.data)
print(dt.data)

# %%
PFM=get_PFM_info()
fname_atm  = PFM['lv1_forc_dir'] + '/' + PFM['atm_tmp_pckl_file']
with open(fname_atm,'rb') as fp:
    print('loading ' + fname_atm + ' ...')
    ATM = pickle.load(fp)

print(ATM.keys())    
print(np.shape(ATM['Tair']))
fig, ax = plt.subplots()
pp=ax.plot(ATM['lon'])
pp=ax.plot(ATM['lat'])

fig, ax = plt.subplots()
ax.imshow(ATM['Tair'][0,:,:], origin='lower')

# %%
cmd_list = ['python','-W','ignore','atm_functions.py','get_atm_data_on_roms_grid',str(1)]
os.chdir('../sdpm_py_util')
ret5 = subprocess.run(cmd_list)   
print('return code: ' + str(ret5.returncode) + ' (0=good)')  
os.chdir('../driver')

# %%
pltfuns.plot_all_fields_in_one(str(1))

# %%
fn_pkl = '/scratch/PFM_Simulations/LV1_Forecast/Forc/hycom_tmp_pckl_file.pkl'
ocnfuns.make_all_tmp_pckl_ocnR_files_1hrzeta(fn_pkl)

# %%
cmd_list = ['python','ocn_functions.py','make_all_tmp_pckl_ocnR_files_1hrzeta',fn_pkl]
os.chdir('../sdpm_py_util')
ret1 = subprocess.run(cmd_list)     
#ocnfuns.make_all_tmp_pckl_ocnR_files(fn_pckl)
os.chdir('../driver')

# %%
PFM = get_PFM_info()
print( PFM['atm_model'])
print( PFM['forecast_days'])

# %%
fn_atm = '/scratch/PFM_Simulations/LV1_Forecast/Forc/LV1_ATM_FORCING.nc'
ds = nc.Dataset(fn_atm)
print(ds)
print(ds.variables['tair_time'][:])

fig, ax = plt.subplots()
pp=ax.plot(ds.variables['tair_time'][:],'o')

# %%
atmfuns.get_atm_data_on_roms_grid_to_atmnc('4')

# %%
# Create an initial dataset and save it to a NetCDF file
#ds1 = xr.Dataset({'var1': ('x', np.arange(5))}, coords={'x': np.arange(5)})
ATM_R = dict()
ATM_R['Tair'] = np.ones((5,2,3))
ATM_R['Pair'] = np.ones((5,2,3))
ATM_R['lat'] = np.ones((2,3))
ATM_R['lon'] = np.ones((2,3))
ATM_R['tair_time'] = np.array([1,2,3,4,5])
ATM_R['pair_time'] = ATM_R['tair_time']
ATM_R['ocean_time'] = ATM_R['tair_time']
ATM_R['ocean_time_ref'] = datetime.now()

ATM_R['vinfo'] = dict()
ATM_R['vinfo']['lon'] = {'long_name':'longitude',
                'units':'degrees_east'}
ATM_R['vinfo']['lat'] = {'long_name':'latitude',
                'units':'degrees_north'}
ATM_R['vinfo']['Tair'] = {'long_name':'surface air temperature',
                'units':'degrees C',
                'coordinates':'lat,lon',
                'time':'tair_time'}
ATM_R['vinfo']['Pair'] = {'long_name':'surface air pressure',
                'units':'degrees C',
                'coordinates':'lat,lon',
                'time':'tair_time'}
ATM_R['vinfo']['ocean_time'] = {'long_name':'atmospheric forcing time',
                    'units':'days',
                    'field': 'time, scalar, series'}
ATM_R['vinfo']['tair_time'] = {'long_name':'atmospheric temp forcing time',
                    'units':'days',
                    'field': 'time, scalar, series'}
ATM_R['vinfo']['pair_time'] = {'long_name':'atmospheric pressure forcing time',
                    'units':'days',
                    'field': 'time, scalar, series'}



ds1 = xr.Dataset(
    data_vars = dict(
        Tair       = (["tair_time","er","xr"],ATM_R['Tair'],ATM_R['vinfo']['Tair']),
    ),
    coords=dict(
        lat =(["er","xr"],ATM_R['lat'], ATM_R['vinfo']['lat']),
        lon =(["er","xr"],ATM_R['lon'], ATM_R['vinfo']['lon']),
        ocean_time = (["time"],ATM_R['ocean_time'], ATM_R['vinfo']['ocean_time']),
        tair_time = (["tair_time"],ATM_R['tair_time'], ATM_R['vinfo']['tair_time']),
    ),
    attrs={'type':'atmospheric forcing file fields for surface fluxes',
        'time info':'ocean time is from '+ ATM_R['ocean_time_ref'].strftime("%Y/%m/%d %H:%M:%S") },
    )

ds2 = xr.Dataset(
    data_vars = dict(
        Pair       = (["pair_time","er","xr"],ATM_R['Pair'],ATM_R['vinfo']['Pair']),
    ),
    coords=dict(
        lat =(["er","xr"],ATM_R['lat'], ATM_R['vinfo']['lat']),
        lon =(["er","xr"],ATM_R['lon'], ATM_R['vinfo']['lon']),
        ocean_time = (["time"],ATM_R['ocean_time'], ATM_R['vinfo']['ocean_time']),
        pair_time = (["pair_time"],ATM_R['pair_time'], ATM_R['vinfo']['pair_time']),
    ),
    attrs={'type':'atmospheric forcing file fields for surface fluxes',
        'time info':'ocean time is from '+ ATM_R['ocean_time_ref'].strftime("%Y/%m/%d %H:%M:%S") },
    )



fn = '/home/mspydell/research/test_files/test_file.nc'
ds1.to_netcdf(fn)

# Open the existing NetCDF file in append mode and write the new dataset
ds2.to_netcdf(fn, mode='a')

# %%
lvl = 'LV2'
print(lvl[2])

# %%
#fn_his = '/scratch/PFM_Simulations/LV1_Forecast/His/LV1_ocean_his_202502120000.nc'
#fn_his = '/scratch/PFM_Simulations/LV2_Forecast/His/LV2_ocean_his_202502120000.nc'
#fn_his = '/scratch/PFM_Simulations/LV3_Forecast/His/LV3_ocean_his_202502120000.nc'
fn_his = '/scratch/PFM_Simulations/LV4_Forecast/His/LV4_ocean_his_202502190000.nc'
#fn_his = '/dataSIO/PFM_Simulations/Archive2.5/LV4_His/LV4_ocean_his_202502120000.nc'
fn_grd = '/scratch/PFM_Simulations/Grids/GRID_SDTJRE_LV4_mss_oct2024.nc'
dir_out = '/scratch/PFM_Simulations/LV4_Forecast/Plots'

webfuns.plot_his_figures_fromnc(fn_his,fn_grd,dir_out)

# %%
atmfuns.get_atm_data_on_roms_grid_v2('4')

# %%
PFM = get_PFM_info()
fin = PFM['lv1_forc_dir'] + '/' + PFM['lv1_atm_file']
ds  = nc.Dataset(fin)
#print(ds.variables.keys())
tw = ds['wind_time'][:]
dtw = np.round( 24 * np.diff(tw) )
print(dtw)
print(dtw[0])
tst = int(dtw[0])
if tst == 1:
    print('worked')

# %%
yyyymmddhh0 = '2025020600'
res = atmfuns.get_ecmwf_forecast_grbs(yyyymmddhh0)
#print(res)

# %%
fns, fns_tot, fns_out, cmd_list = atmfuns.get_ecmwf_grib_files_lists(yyyymmddhh0)
ds = cfgrib.open_file(fns_out[1])
print(sorted(ds.variables))

# %%
#yyyymmddhh0 = '2025020400'
ATM = atmfuns.ecmwf_grib_2_dict_all(yyyymmddhh0)

# %%
dir_out = '/scratch/PFM_Simulations/ecmwf_data/'
fn_in = 'ecmwf_all.pkl'

atmfuns.ecmwf_to_roms_vars(dir_out + fn_in)
atmfuns.get_atm_data_on_roms_grid('1')
atmfuns.atm_roms_dict_to_netcdf('1')

# %%
pltfuns.load_and_plot_atm('1')

# %%
fig, ax = plt.subplots()
pp=ax.plot(ATM2['ocean_time_ref'] + ATM2['rain_time'] * timedelta(days=1),ATM2['rain'][:,-1,-1],'k')

fig, ax = plt.subplots()
pp=ax.plot(ATM2['ocean_time_ref'] + ATM2['rain_time'] * timedelta(days=1) - timedelta(hours=8),ATM2['swrad'][:,-1,-1],'k')

fig, ax = plt.subplots()
pp=ax.plot(ATM2['ocean_time_ref'] + ATM2['ocean_time'] * timedelta(days=1) - timedelta(hours=8),ATM2['Tair'][:,-1,-1],'k')

# %%
print(ATM['ssr'][0:24,0,0])

# %%
fig, ax = plt.subplots()
pp=ax.plot(ATM['time'],ATM['tp'][:,-1,-1],'k')

#t2 = datetime_to_romstime(ATM['time'])
#print(t2)

# %%
def datetime_to_romstime(tdt):
    PFM = get_PFM_info()
    t_ref = PFM['modtime0'] 
    nt = len(tdt)
    t_rom2 = np.zeros((nt))
    for cnt in np.arange(nt):
        t_rom = tdt[cnt] - t_ref # now a timedelta object
        t_rom2[cnt] = t_rom.total_seconds() # now seconds past
        t_rom2[cnt] = t_rom2[cnt] / (3600 * 24) # now days past

    return t_rom2

# %%
E  = 6.11 * np.power(10, 7.5 * ATM['d2m'] / (237.7 + ATM['d2m']) )
Es = 6.11 * np.power(10, 7.5 * ATM['t2m'] / (237.7 + ATM['t2m']) )


a = 10
e = np.array([2, 3, 1])
b = np.array([5,6,7])

result = np.power(a, e)
c = b/e
print(c)

print(result)

# %%
yyyymmddhh0 = '2025020300'
fns, fns_tot, fns_out, cmd_list = atmfuns.get_ecmwf_grib_files_lists(yyyymmddhh0)
ds = cfgrib.open_file(fns_out[1])
print(sorted(ds.variables))

print(fns[0:5])
print(cmd_list[0])

atmfuns.ecmwf_grabber(cmd_list[1])

# %%
ds = cfgrib.open_file(fns_out[1])
print(sorted(ds.variables))

# %%
'''
https://syntool.cdip.ucsd.edu/thredds/catalog/raw/ECMWF_TMP/FALK/catalog.html
https://syntool.cdip.ucsd.edu/thredds/catalog/raw/ECMWF_TMP/FALK/2025/01/28/catalog.html
https://syntool.cdip.ucsd.edu/thredds/catalog/raw/ECMWF_TMP/FALK/2025/01/28/catalog.html?dataset=RAW/ECMWF_TMP/FALK/2025/01/28/T1S0128182025020318001
User: syntool
Pass: cdip
TS is for the 06 and 18 hr forecasts
T1S0128062025012808001	 TD mmddhh yyyymmddhh 001 or 011 if initial one?
T1S0128062025012807001	   forecast   valid 
T1S0128062025012806011     start time  time

TD is for the 00 and 12 hr forecasts
T1D0128002025012802001	TS mmddhh 
T1D0128002025012801001	
T1D0128002025012800011  first time
T1D0128122025021212001  last time 10+ day forecast?
'''
fn = 'T1D0128002025012800011'
#fn_in = 'https://syntool.cdip.ucsd.edu/thredds/catalog/raw/ECMWF_TMP/FALK/2025/01/28/' + fn
#fn_in = 'https://syntool.cdip.ucsd.edu/thredds/catalog/raw/ECMWF_TMP/FALK/2025/01/28/catalog.html?dataset=RAW/ECMWF_TMP/FALK/2025/01/28/' + fn 
fn_in = 'https://syntool.cdip.ucsd.edu/thredds/fileServer/raw/ECMWF_TMP/FALK/2025/01/28/' + fn #T1D0128002025012801001

fn_out = '/scratch/PFM_Simulations/ecmwf_data/' + fn
#wget --user user --password pass http://example.com/

cmd_lst = ['wget','--user','syntool','--password','cdip','-O',fn_out,fn_in]
ret1 = subprocess.call(cmd_lst)

# %%
import cfgrib
#import xarray as xr
#fn = 'T1D0128002025012800011'
fn = 'T1S0127182025012718011'
fn_out = '/scratch/PFM_Simulations/ecmwf_data/' + fn
#ds = xr.open_dataset(fn_out, engine='cfgrib')
#ds = cfgrib.open_file(fn_out)
A = ecmwf_grib_2_dict(fn_out)

#print(A['valid_time'])
#print(A['latitude'])
#print(A['longitude'])
#print(A['tp'][:,0])

fig, ax = plt.subplots()
#p1 = ax.imshow(A['t2m'])
#lvls = [1.25, 1.5]
p1 = ax.contourf(A['longitude'],A['latitude'],A['t2m'], levels=20)
#ax.plot(ixs,iys,'r')
#ax.invert_yaxis()
fig.colorbar(p1,ax=ax)

fng = '/scratch/PFM_Simulations/Grids/GRID_SDTJRE_LV1_rx020_hmask.nc'
RMG = grdfuns.roms_grid_to_dict(fng)
pp=ax.plot(RMG['lon_rho'][0,:],RMG['lat_rho'][0,:],'k')
pp=ax.plot(RMG['lon_rho'][-1,:],RMG['lat_rho'][-1,:],'k')
pp=ax.plot(RMG['lon_rho'][:,0],RMG['lat_rho'][:,0],'k')
pp=ax.plot(RMG['lon_rho'][:,-1],RMG['lat_rho'][:,-1],'k')

# %%
def ecmwf_grib_2_dict(fn_in):
    AA = dict()
    # these are the 2d variables we need in the ecmwf grib file
    # see https://code.usgs.gov/coawstmodel/COAWST/-/blob/v3.7-marsh/Tools/mfiles/rutgers/forcing/d_ecmwf2roms.m
    var_e = ['d2m','t2m','msl','u10','v10','e','tp','slhf','sshf','ssr','strd'] # need 'str' !!!
    var_info = dict()
    var_info['valid_time'] = 'time since 1970-1-1 in seconds'
    var_info['time'] = 'time stamp in datetime'
    var_info['latitude'] = 'vector of latatides at 0.1 deg resolution'
    var_info['longitude'] = 'vector of longitudes at 0.1 deg resolution'
    var_info['d2m'] = '2 m dew point temp in K'
    var_info['t2m'] = '2 m temp in K'
    var_info['msl'] = 'mean sea level pressure'
    var_info['u10'] = '10 m east west velocity in m/s'
    var_info['v10'] = '10 m north south velocity in m/s'
    var_info['e'] = 'evaporation in m, over 1 or 3 hr?'
    var_info['tp'] = 'total precipitation in m, over 1 or 3 hr?'
    var_info['slhf'] = 'surface latent heat flux in J/m2, over 1 or 3 hr?'
    var_info['sshf'] = 'surface sensible heat flux in J/m2, over?'
    var_info['ssr'] = 'net surface shortwave radiation in J/m2, over?'
    var_info['str'] = 'net surface thermal (long wave) radiation in J/m2, over?'
    var_info['strd'] = 'surface thermal radiation downward'
    AA['var_info'] = var_info
    ds = cfgrib.open_file(fn_in)
    AA['valid_time'] = ds.variables['valid_time'].data
    AA['latitude'] = ds.variables['latitude'].data[:]
    AA['longitude'] = ds.variables['longitude'].data[:]
    for vnm in var_e:
        AA[vnm] = ds.variables[vnm].data[:,:]

    tsec = AA['valid_time']
    time = datetime(year=1970,month=1,day=1) + tsec * timedelta(seconds=1)
    AA['time'] = time
    return AA

# %%
ds = cfgrib.open_file()


print(sorted(ds.variables))
dum=ds.variables['valid_time'] # number of seconds past 1970-1-1.
#dum=ds.variables['time'] # this is the intialization time, seconds past 1970-1-1, of the forecast
#dum=ds.variables['e'] # evaportation m or water 
#dum=ds.variables['latitude'] # a 91x1 vector at 0.1 deg resolution
#dum=ds.variables['longitude'] # a 91x1 vector at 0.1 deg resolution
#dum=ds.variables['d2m'] #  282 ? dew point temp 2m? K
#dum=ds.variables['t2m']  # 285 2m temp K
#dum=ds.variables['q']  # specific humidity kg kg^-1 (4e-6)
#dum=ds.variables['msl']  # mean sea level pressure Pa
#dum=ds.variables['u10'] # 10 m u m/s
#dum=ds.variables['v10'] # 10 m v m/s
#dum = ds.variables['ssrd'] # surface solor radiation down J/m^2 (over what time?)
#dum = ds.variables['strd'] # surface thermal radiation down J/m^2 (over what time?)
#dum = ds.variables['ssr'] # net solor radiation  J/m^2 (over what time?)
#dum = ds.variables['str'] # net thermal radiation  J/m^2 (over what time?)
#dum = ds.variables['sshf'] # sensible heat flux  J/m^2 (over what time?)
#dum = ds.variables['slhf'] # latent heat flux  J/m^2 (over what time?)
#dum = ds.variables['tcc'] # total cloud cover 0-1.
#dum = ds.variables['step'] # 0, not sure
#dum = ds.variables['tp'] # total precipitation meters 

t_valid=ds.variables['valid_time'].data
#t_valid=ds.variables['time'].data

print(t_valid)
print(t_valid/24/60/60)
t_ref = datetime(year=1970,month=1,day=1)
print(datetime.now()-t_ref)
tt = t_ref + t_valid * timedelta(seconds=1)

print(tt)

# %%
yyyymmddhh = '2024101012'
cl,fnout = ocnfuns.get_hind_nc_cmd_list(yyyymmddhh)
print(cl[-2])
print(fnout[-2])

print(len(fnout))

# %%
def get_hycom_hind_nc_names(yyyymmddhh):
    # this gets the list of nc files on the hycom server that we need to get.
    t1 = datetime.strptime(yyyymmddhh,'%Y%m%d%H')
    t2 = t1 + timedelta(days=1)
    yyyymmddhh_2 = t2.strftime("%Y%m%d%H")

    yyyy = yyyymmddhh[0:4]
    yyyy2 = yyyymmddhh_2[0:4]

    # for the 1st day we use
    ocn_name = 'https://tds.hycom.org/thredds/dodsC/ESPC-D-V02/'
    #            https://tds.hycom.org/thredds/dodsC/ESPC-D-V02/ssh/2024
    #https://tds.hycom.org/thredds/dodsC/FMRC_ESPC-D-V02_ssh/runs/FMRC_ESPC-D-V02_ssh_RUN_2025-01-08T12:00:00Z

    # and we need the first time of the next day too for boundary conditions
    
    var_names = ['s3z','t3z','u3z','v3z','ssh']

    ncfiles1 = [] # list of urls for the 1st day

    # first do the 1st day
    for bb in var_names:
        ffn = ocn_name + bb + '/' + yyyy 
        ncfiles1.append(ffn)

    return ncfiles1

# %%
PFM=get_PFM_info()
print(PFM['fetch_time'])

# %%
yyyymmddhh = '2024101012'
fns = get_hycom_hind_nc_names(yyyymmddhh)
print(fns[0])

# %%
#fns2 = ocnfuns.hycom_to_out(fns)
#print(fns2[0])
yyyymmddhh = PFM['fetch_time'].strftime("%Y%m%d%H")
print(yyyymmddhh)

cmd_list, nc_out = ocnfuns.get_hind_nc_cmd_list(yyyymmddhh)
ret = ocnfuns.get_hycom_hind_data(yyyymmddhh)
print(sum(ret))

# %%
ocnfuns.hycom_hind_ncfiles_to_pickle()

PFM = get_PFM_info()
fn_pckl = PFM['lv1_forc_dir'] + '/' + PFM['lv1_ocn_tmp_pckl_file']
os.chdir('../sdpm_py_util')
print('putting the hycom data in ' + fn_pckl + ' on the roms grid...')
cmd_list = ['python','-W','ignore','ocn_functions.py','make_all_tmp_pckl_ocnR_files_1hrzeta',fn_pckl]
os.chdir('../sdpm_py_util')
ret1 = subprocess.run(cmd_list)     
#ocnfuns.make_all_tmp_pckl_ocnR_files(fn_pckl)
os.chdir('../driver')
print('subprocess return code? ' + str(ret1.returncode) +  ' (0=good)')

# %%
cmd_list = ['python','-W','ignore','ocn_functions.py','print_maxmin_HYrm_pickles']
os.chdir('../sdpm_py_util')
ret1 = subprocess.run(cmd_list)     
os.chdir('../driver')
print('driver_run_forecast_LV1: done with hycom_to_roms_latlon')

# %%
print('making the depth pickle file...')
fname_depths = PFM['lv1_forc_dir'] + '/' + PFM['lv1_depth_file']
cmd_list = ['python','-W','ignore','ocn_functions.py','make_rom_depths_1hrzeta',fname_depths]
os.chdir('../sdpm_py_util')
ret6 = subprocess.run(cmd_list)     
os.chdir('../driver')
print('subprocess return code? ' + str(ret6.returncode) +  ' (0=good)')

# %%
ocnIC_pckl = PFM['lv1_forc_dir'] + '/' + PFM['lv1_ocnIC_tmp_pckl_file']
ic_file_out = PFM['lv1_forc_dir'] + '/' + PFM['lv1_ini_file']
bc_file_out = PFM['lv1_forc_dir'] + '/' + PFM['lv1_bc_file']
ocnBC_pckl = PFM['lv1_forc_dir'] + '/' + PFM['lv1_ocnBC_tmp_pckl_file']
fn_atm_out = PFM['lv1_forc_dir'] + '/' + PFM['lv1_atm_file'] # LV1 atm forcing filename

# %%
t01=datetime.now()
print('going to save OCN_IC to a pickle file: ' + ocnIC_pckl)
os.chdir('../sdpm_py_util')
cmd_list = ['python','-W','ignore','ocn_functions.py','ocnr_2_ICdict_from_tmppkls',ocnIC_pckl]
ret3 = subprocess.run(cmd_list)     
os.chdir('../driver')
print('OCN IC data saved with pickle, correctly? ' + str(ret3.returncode) + ' (0=yes,1=no)')

print('driver_run_forecast_LV1: done with ocn_r_2_ICdict')
t02 = datetime.now()
print('this took:')
print(t02-t01)
print('\n')

print('making IC file from pickled IC: '+ ic_file_out)
t03 = datetime.now()
cmd_list = ['python','-W','ignore','ocn_functions.py','ocn_roms_IC_dict_to_netcdf_pckl',ocnIC_pckl,ic_file_out]
os.chdir('../sdpm_py_util')
ret4 = subprocess.run(cmd_list)     
os.chdir('../driver')
print('OCN IC nc data saved, correctly? ' + str(ret4.returncode) + ' (0=yes)')

# %%
print('going to save OCN_BC to a pickle file to:')
t01 = datetime.now()
t04 = datetime.now()
ocnBC_pckl = PFM['lv1_forc_dir'] + '/' + PFM['lv1_ocnBC_tmp_pckl_file']
print(ocnBC_pckl) 
os.chdir('../sdpm_py_util')
cmd_list = ['python','-W','ignore','ocn_functions.py','ocnr_2_BCdict_1hrzeta_from_tmppkls',ocnBC_pckl]
ret4 = subprocess.run(cmd_list)     
os.chdir('../driver')
print('OCN BC data saved with pickle, correctly? ' + str(ret4.returncode) + ' (0=yes)')
    
t02 = datetime.now()
print('this took:')
print(t02-t01)
print('\n')


print('making BC nc file from pickled BC: '+ bc_file_out)
t01 = datetime.now()
cmd_list = ['python','-W','ignore','ocn_functions.py','ocn_roms_BC_dict_to_netcdf_pckl_1hrzeta',ocnBC_pckl,bc_file_out]
os.chdir('../sdpm_py_util')
ret5 = subprocess.run(cmd_list)     
os.chdir('../driver')
print('OCN BC nc data saved, correctly? ' + str(ret5.returncode) + ' (0=yes)')

print('done makeing BC nc file.')

# %%
import cfgrib

#grb2_in = "https://www.ncei.noaa.gov/data/north-american-mesoscale-model/access/analysis/202412/20241231/nam_218_20241231_0000_000.grb2" 
#grb2_in = "https://www.ncei.noaa.gov/thredds/catalog/model-namanl/202412/20241231/nam_218_20241231_0000_000.grb2"
grb2_out = "/scratch/PHM_Simulations/grb2_data/nam_218_20241201_0600_003.grb2"


ds = xr.open_dataset(grb2_out, engine='cfgrib')
#ds = cfgrib.open_file(grb2_out)


#with open(grb2_out, 'rb') as f:
#    grbs = grib2io.open(f)


#g = grib2io.open(grb2_out)

print(ds)

#strt = 0
#g.seek(strt)
#print('GRIB2 file poistion: ',g.tell())
#msgs = g.read(500)
#print('Number of messages read: ',len(msgs))
#for msg in msgs:
#    print(msg)

#for a in np.arange(0,1):
#print(g['LWRAD'])

# %%
# the variables and levels we need
vars=['PRMSL','RH','TMP','UGRD','VGRD','APCP','DSWRF','USWRF','DLWRF','ULWRF']
lev =['mean sea level','2 m above ground','2 m above ground','10 m above ground','10 m above ground','surface','surface','surface','surface','surface']

apcp = g.select(shortName='APCP',level='surface')[0]
print('\nprinting apcp')
#print(g.select(shortName='APCP',level='surface'))
print(apcp)
print(apcp.validDate,type(apcp.validDate))
print(apcp.duration,type(apcp.duration))
# note, this is not a regular grid. It is on the native grid.

#print(lats[:,0])
#print(lons[0,:])

tmp = g.select(shortName='TMP',level='2 m above ground')[0]
print('\nprinting tmp')
print(tmp)

lats, lons = tmp.grid()

rh = g.select(shortName='RH',level='2 m above ground')[0]
print('\nprinting rh')
print(rh.data[0:10,0])


pmsl = g.select(shortName='PRMSL',level='mean sea level')[0]
print('\nprinting pmsl')
print(pmsl)
u10 = g.select(shortName='UGRD',level='10 m above ground')
print('\nprinting u10')
print(u10)
#pmsl = g.select(shortName=vars[0])[0]
#print(pmsl)
#pmsl_data = pmsl.data
#print(pmsl_data[0:10,0:10])

# %%
fng = '/scratch/PFM_Simulations/Grids/GRID_SDTJRE_LV1_rx020_hmask.nc'
RMG = grdfuns.roms_grid_to_dict(fng)

fig, ax = plt.subplots()

y1=lats[:,0]
x1=lons[:,0]
y2=lats[:,-1]
x2=lons[:,-1]
y3=lats[0,:]
x3=lons[0,:]
y4=lats[-1,:]
x4=lons[-1,:]

lt_mn = 118
lt_mx = 191
ln_mn = 129
ln_mx = 185
lons2 = lons[lt_mn:lt_mx,ln_mn:ln_mx]
lats2 = lats[lt_mn:lt_mx,ln_mn:ln_mx]

p1=ax.plot(x1,y1)
p1=ax.plot(x2,y2)
p1=ax.plot(x3,y3)
p1=ax.plot(x4,y4)
p1=ax.plot(RMG['lon_rho'][0,:],RMG['lat_rho'][0,:],'k')
p1=ax.plot(RMG['lon_rho'][-1,:],RMG['lat_rho'][-1,:],'k')
p1=ax.plot(RMG['lon_rho'][:,0],RMG['lat_rho'][:,0],'k')
p1=ax.plot(RMG['lon_rho'][:,-1],RMG['lat_rho'][:,-1],'k')

p1=ax.plot(lons2[0,:],lats2[0,:],'r')
p1=ax.plot(lons2[-1,:],lats2[-1,:],'r')
p1=ax.plot(lons2[:,0],lats2[:,0],'r')
p1=ax.plot(lons2[:,-1],lats2[:,-1],'r')

fig, ax = plt.subplots()
p1=ax.plot(RMG['lon_rho'][0,:],RMG['lat_rho'][0,:],'k')
p1=ax.plot(RMG['lon_rho'][-1,:],RMG['lat_rho'][-1,:],'k')
p1=ax.plot(RMG['lon_rho'][:,0],RMG['lat_rho'][:,0],'k')
p1=ax.plot(RMG['lon_rho'][:,-1],RMG['lat_rho'][:,-1],'k')

p1=ax.plot(lons2[0,:],lats2[0,:],'r')
p1=ax.plot(lons2[-1,:],lats2[-1,:],'r')
p1=ax.plot(lons2[:,0],lats2[:,0],'r')
p1=ax.plot(lons2[:,-1],lats2[:,-1],'r')

# %%
#tnow = datetime.now()
#hr = tnow.hour

hr = 24
hr = hr % 24
hr2 = hr % 6
hr1 = hr-hr2

print(hr1,hr2)

t1str = '2024120100'
t2str = '2024120200'
l1,l2,l3,l4 = hindfuns.get_nam_hindcast_filelists(t1str,t2str)
print(l3)
print(l4)

#res2 = hindfuns.get_nam_hindcast_grb2s(t1str,t2str)

# %%
cmd_list = ['python','-W','ignore','atm_functions.py','get_atm_data_as_dict']
os.chdir('../sdpm_py_util')
ret5 = subprocess.run(cmd_list)   
print('return code: ' + str(ret5.returncode) + ' (0=good)')  
os.chdir('../sdpm_py_util')

# %%
#url = "https://www.ncei.noaa.gov/data/global-forecast-system/access/grid-005-degree/analysis/20240309/2024030900/gfs_3_20240309_0000_000.grb2"
#url = l1[0]
#ds = xr.open_dataset(url, engine="cfgrib",backend_kwargs={"indexpath": ""})
#data = urllib.request.urlopen(url)
# this is approximately 1 Mb/sec
# ncei should be done in chunks of 5. 
for cmd in l3:
    t0=datetime.now()
    print('\ngetting:')
    print(cmd)
    ret1 = subprocess.call(cmd) 
    print('return code:')
    print(ret1)
    print('this took:')
    print(datetime.now()-t0)

#hindfuns.get_nam_hindcast_grb2s_v2(t1str,t2str)
